# %%
# Install required libraries
# !pip install transformers datasets trl torch accelerate bitsandbytes wandb
# Out:
# Requirement already satisfied: transformers in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (4.49.0)
# Requirement already satisfied: datasets in /home/avallala2023/.local/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: trl in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (0.15.2)
# Requirement already satisfied: torch in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: accelerate in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: bitsandbytes in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (0.45.3)
# Requirement already satisfied: wandb in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (0.19.7)
# Requirement already satisfied: filelock in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /home/avallala2023/.local/lib/python3.10/site-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /home/avallala2023/.local/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/avallala2023/.local/lib/python3.10/site-packages (from transformers) (4.67.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/avallala2023/.local/lib/python3.10/site-packages (from datasets) (18.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/avallala2023/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in /home/avallala2023/.local/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/avallala2023/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /home/avallala2023/.local/lib/python3.10/site-packages (from datasets) (3.11.2)
# Requirement already satisfied: rich in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from trl) (13.9.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.8.61)
# Requirement already satisfied: psutil in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from wandb) (3.10.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: pydantic<3,>=2.6 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from wandb) (2.10.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from wandb) (2.22.0)
# Requirement already satisfied: setproctitle in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from wandb) (1.3.5)
# Requirement already satisfied: setuptools in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from wandb) (75.8.0)
# Requirement already satisfied: six>=1.4.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/avallala2023/.local/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/avallala2023/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/avallala2023/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/avallala2023/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/avallala2023/.local/lib/python3.10/site-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/avallala2023/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.17.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/avallala2023/.local/lib/python3.10/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from pydantic<3,>=2.6->wandb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/avallala2023/.local/lib/python3.10/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from rich->trl) (2.15.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)

# %%
# Import necessary modules
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, pipeline
from datasets import load_dataset
from trl import SFTConfig, SFTTrainer, setup_chat_format
import torch
import os

# Detect device (GPU, MPS, or CPU)
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)

# %% [markdown]
# ***Quick Check For Resources - Runtime***

# %%
# !nvidia-smi
# Out:
# Tue Mar  4 14:03:19 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.107.02             Driver Version: 550.107.02     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A5500               On  |   00000000:01:00.0 Off |                  Off |
# | 30%   52C    P2             71W /  230W |     284MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A5500               On  |   00000000:2E:00.0 Off |                  Off |
# | 30%   40C    P8             24W /  230W |      14MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA RTX A5500               On  |   00000000:41:00.0 Off |                  Off |
# | 30%   41C    P8             24W /  230W |      14MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA RTX A5500               On  |   00000000:61:00.0 Off |                  Off |
# | 30%   39C    P8             22W /  230W |      14MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      9404      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A     10602      C   /usr/NX/bin/nxnode.bin                        266MiB |
# |    1   N/A  N/A      9404      G   /usr/lib/xorg/Xorg                              4MiB |
# |    2   N/A  N/A      9404      G   /usr/lib/xorg/Xorg                              4MiB |
# |    3   N/A  N/A      9404      G   /usr/lib/xorg/Xorg                              4MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# Load the model and tokenizer
model_name = "HuggingFaceTB/SmolLM2-360M"
model = AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path=model_name)
tokenizer = AutoTokenizer.from_pretrained(pretrained_model_name_or_path=model_name)

# Set up chat format for the model and tokenizer
model, tokenizer = setup_chat_format(model=model, tokenizer=tokenizer)

# Test the base model with a simple prompt
prompt = "Explain AGI ?"
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0 if device == "cuda" else -1)
print(pipe(prompt, max_new_tokens=200))
# Out:
# Device set to use cuda:0
# [{'generated_text': 'Explain AGI ?\n\nA. AGI is a measure of the ability of a machine to perform a task.\n\nB. AGI is a measure of the ability of a machine to perform a task.\n\nC. AGI is a measure of the ability of a machine to perform a task.\n\nD. AGI is a measure of the ability of a machine to perform a task.\n\nAnswer: B\n\nQuestion 10. Which of the following is not a type of AGI?\n\nA. Machine learning\n\nB. Natural language processing\n\nC. Computer vision\n\nD. Speech recognition\n\nAnswer: B\n\nQuestion 11. Which of the following is not a type of AGI?\n\nA. Machine learning\n\nB. Natural language processing\n\nC. Computer vision\n\nD. Speech recognition\n\nAnswer: C\n\nQuestion 12. Which of the following is not a type of A'}]

# %%
# Load the dataset
ds = load_dataset("akhilfau/Instruction_fine_tuning_camel_ai_physics")

# Tokenization function with batch handling
def tokenize_function(examples):
    # Apply strip to each string in the batch
    prompts = [p.strip() for p in examples["prompt"]]
    responses = [r.strip() for r in examples["response"]]

    # Apply chat template for each prompt-response pair
    texts = [
        tokenizer.apply_chat_template(
            [{"role": "system", "content": "You are a helpful physics tutor."},{"role": "user", "content": p}, {"role": "assistant", "content": r}],
            tokenize=False
        )
        for p, r in zip(prompts, responses)
    ]

    # Tokenize the combined texts
    return tokenizer(texts, truncation=True, padding="max_length", max_length=512)

# Apply the tokenization function to the dataset
ds = ds.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]

# %%
import torch
from transformers import TrainingArguments
from trl import SFTTrainer

# Check if bf16 is available
use_bf16 = torch.cuda.is_bf16_supported()

# Estimate total training steps
dataset_size = len(ds["train"])  # Adjust based on dataset size
batch_size = 4  # Adjust based on available GPU memory
grad_accum_steps = 4  # Simulate larger batch without using more memory
total_steps = (dataset_size // (batch_size * grad_accum_steps)) * 3  # 3 epochs

# Training Arguments
training_args = TrainingArguments(
    per_device_train_batch_size=batch_size,
    gradient_accumulation_steps=grad_accum_steps,
    warmup_steps=100,  # More warmup steps for stability
    max_steps=total_steps,  # Train across full dataset
    learning_rate=2e-4,
    fp16=not use_bf16,  # Use FP16 if bf16 is not available
    bf16=use_bf16,  # Use BF16 if supported
    logging_steps=100,  # Reduce logging frequency for better efficiency
    save_steps=1000,  # Save every 1000 steps
    save_total_limit=2,  # Keep last 2 checkpoints
    optim="adamw_8bit",  # Memory-efficient optimizer
    weight_decay=0.01,
    lr_scheduler_type="linear",
    seed=3407,
    output_dir="outputs",
    report_to="wandb",  # Log to W&B
)

# Initialize Trainer
trainer = SFTTrainer(
    model=model,
    processing_class=tokenizer,
    train_dataset=ds["train"],
    args=training_args,
)

# Train
trainer.train()
# Out:
# Converting train dataset to ChatML:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Applying chat template to train dataset:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/20000 [00:00<?, ? examples/s]
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: akhilvallala0115 (akhilvallala0115-florida-atlantic-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/avallala2023/Desktop/Thesis/Instruction Fine Tuning/wandb/run-20250304_140340-5br3u9tc</code>
# Syncing run <strong><a href='https://wandb.ai/akhilvallala0115-florida-atlantic-university/huggingface/runs/5br3u9tc' target="_blank">outputs</a></strong> to <a href='https://wandb.ai/akhilvallala0115-florida-atlantic-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/akhilvallala0115-florida-atlantic-university/huggingface' target="_blank">https://wandb.ai/akhilvallala0115-florida-atlantic-university/huggingface</a>
#  View run at <a href='https://wandb.ai/akhilvallala0115-florida-atlantic-university/huggingface/runs/5br3u9tc' target="_blank">https://wandb.ai/akhilvallala0115-florida-atlantic-university/huggingface/runs/5br3u9tc</a>
# /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='3750' max='3750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3750/3750 2:35:45, Epoch 11/13]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.226500</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.187100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.175400</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.149400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.145900</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.144400</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.121900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.116000</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.117500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.098900</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.090200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.092600</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.079300</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.066100</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.069000</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.060900</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.046300</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.048200</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.045300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.031300</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.032600</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.032300</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.021500</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.022000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.022500</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.015700</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.015700</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.015800</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.012400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.011900</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.012000</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.010300</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.009700</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.009800</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.008500</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.008500</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# TrainOutput(global_step=3750, training_loss=0.06364278049468994, metrics={'train_runtime': 9350.6445, 'train_samples_per_second': 25.667, 'train_steps_per_second': 0.401, 'total_flos': 2.316340113702912e+17, 'train_loss': 0.06364278049468994})

# %%
# Save model and tokenizer to a local directory
save_directory = "/content/Instruction_fine_tuned_on_camel_ai_physics"
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)

# # Zip the directory
# import shutil
# shutil.make_archive(save_directory, 'zip', save_directory)

# # Download the zip file
# from google.colab import files
# files.download(f"{save_directory}.zip")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Save model and tokenizer to a local directory
#       2 save_directory = "/content/Instruction_fine_tuned_on_camel_ai_physics"
# ----> 3 model.save_pretrained(save_directory)
#       4 tokenizer.save_pretrained(save_directory)
#       6 # Zip the directory
#
# File ~/anaconda3/envs/Thesis/lib/python3.10/site-packages/transformers/modeling_utils.py:2777, in PreTrainedModel.save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    2774     logger.error(f"Provided path ({save_directory}) should be a directory, not a file")
#    2775     return
# -> 2777 os.makedirs(save_directory, exist_ok=True)
#    2779 if push_to_hub:
#    2780     commit_message = kwargs.pop("commit_message", None)
#
# File ~/anaconda3/envs/Thesis/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File ~/anaconda3/envs/Thesis/lib/python3.10/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
# Change to a directory in your home folder
save_directory = "./Instruction_fine_tuned_on_camel_ai_physics"

# Save model and tokenizer
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)

print(f"✅ Model saved to {save_directory}")
# Out:
# ✅ Model saved to ./Instruction_fine_tuned_on_camel_ai_physics

# %%
from huggingface_hub import login

# Replace 'your_huggingface_token' with your actual token
hf_token = "hf_token"

# Log in to Hugging Face
login(token=hf_token)

print("✅ Successfully logged in to Hugging Face!")
# Out:
# ✅ Successfully logged in to Hugging Face!

# %%
from huggingface_hub import upload_folder
from transformers import AutoModel, AutoTokenizer

# Define model repository name
repo_name = "akhilfau/Instruction_fine_tuned_on_camel_ai_physics"

# Save model and tokenizer locally
save_directory = "./Instruction_fine_tuned_on_camel_ai_physics"
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)

# Upload to Hugging Face Hub
upload_folder(
    folder_path=save_directory,  # Path to local model directory
    repo_id=repo_name,           # Your Hugging Face repository name
    repo_type="model"            # Specify it as a model repository
)

print(f"✅ Model successfully uploaded: https://huggingface.co/{repo_name}")
# Out:
# model.safetensors:   0%|          | 0.00/1.45G [00:00<?, ?B/s]
# ✅ Model successfully uploaded: https://huggingface.co/akhilfau/Instruction_fine_tuned_on_camel_ai_physics

# %%
from huggingface_hub import create_repo, upload_folder, login
# Create the repository (if it doesn't exist)
create_repo(repo_id=repo_name, repo_type="model", exist_ok=True)
# Out:
# RepoUrl('https://huggingface.co/akhilfau/Instruction_fine_tuned_on_camel_ai_physics', endpoint='https://huggingface.co', repo_type='model', repo_id='akhilfau/Instruction_fine_tuned_on_camel_ai_physics')

# %%
MODEL="akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel-ai-physics"  # Model name
OUTPUT_DIR="/content/360M_supervised"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:conceptual_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [2025-03-05 11:54:00,402] [    INFO]: PyTorch version 2.4.1 available. (config.py:54)
# [2025-03-05 11:54:02,442] [    INFO]: Test gather tensor (parallelism.py:133)
# [2025-03-05 11:54:02,517] [    INFO]: gathered_tensor tensor([0], device='cuda:0'), should be [0] (parallelism.py:136)
# [2025-03-05 11:54:02,517] [    INFO]: --- LOADING MODEL --- (pipeline.py:168)
# [2025-03-05 11:54:02,799] [    INFO]: Tokenizer truncation and padding size set to the left side. (transformers_model.py:539)
# [2025-03-05 11:54:03,050] [    INFO]: Setting model parallel to True since the number of local processes is 1 and the number of GPUs is 4 (transformers_model.py:402)
# [2025-03-05 11:54:03,050] [    INFO]: Model parallel was set to True, setting max memory per GPU to {0: 10169221120, 1: 15557066752, 2: 15557066752, 3: 15573843968} and device map to auto (transformers_model.py:417)
# [2025-03-05 11:54:04,150] [    INFO]: --- LOADING TASKS --- (pipeline.py:195)
# [2025-03-05 11:54:04,150] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:136)
# [2025-03-05 11:54:04,152] [    INFO]: lighteval/mmlu conceptual_physics (lighteval_task.py:187)
# [2025-03-05 11:54:05,081] [    INFO]: --- INIT SEEDS --- (pipeline.py:224)
# [2025-03-05 11:54:05,081] [    INFO]: --- RUNNING MODEL --- (pipeline.py:267)
# [2025-03-05 11:54:05,081] [    INFO]: Running RequestType.LOGLIKELIHOOD requests (pipeline.py:271)
# 0it [00:00, ?it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#   7%|██▉                                         | 1/15 [00:00<00:05,  2.75it/s]
#  27%|███████████▋                                | 4/15 [00:00<00:01,  9.65it/s]
#  47%|████████████████████▌                       | 7/15 [00:00<00:00, 14.10it/s]
#  67%|████████████████████████████▋              | 10/15 [00:00<00:00, 17.05it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 15.47it/s]
# 1it [00:00,  1.03it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#  20%|████████▊                                   | 3/15 [00:00<00:00, 24.09it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:00, 24.47it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:00<00:00, 24.59it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:00<00:00, 24.69it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 24.70it/s]
# 2it [00:01,  1.32it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#  20%|████████▊                                   | 3/15 [00:00<00:00, 24.68it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:00, 25.15it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:00<00:00, 24.74it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:00<00:00, 23.91it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 24.16it/s]
# 3it [00:02,  1.44it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#  20%|████████▊                                   | 3/15 [00:00<00:00, 25.00it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:00, 25.38it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:00<00:00, 25.29it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:00<00:00, 25.41it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 25.09it/s]
# 4it [00:02,  1.43it/s]
# [2025-03-05 11:54:08,053] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:299)
# [2025-03-05 11:54:08,060] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:342)
# [2025-03-05 11:54:08,060] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# |                Task                 |Version|Metric|Value |   |Stderr|
# |-------------------------------------|------:|------|-----:|---|-----:|
# |all                                  |       |acc   |0.2681|±  | 0.029|
# |leaderboard:mmlu:conceptual_physics:0|      0|acc   |0.2681|±  | 0.029|
#
# [2025-03-05 11:54:08,072] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:332)
# [2025-03-05 11:54:08,072] [    INFO]: Saving experiment tracker (evaluation_tracker.py:154)
# [2025-03-05 11:54:08,072] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/main_accelerate.py:207 in accelerate                                     │
# │                                                                              │
# │   204 │                                                                      │
# │   205 │   results = pipeline.get_results()                                   │
# │   206 │                                                                      │
# │ ❱ 207 │   pipeline.save_and_push_results()                                   │
# │   208 │                                                                      │
# │   209 │   return results                                                     │
# │   210                                                                        │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │               accelerator = <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x72d39c9bc850>                           │ │
# │ │                 cache_dir = None                                         │ │
# │ │              custom_tasks = None                                         │ │
# │ │ dataset_loading_processes = 1                                            │ │
# │ │                env_config = EnvConfig(cache_dir=None, token=None)        │ │
# │ │        evaluation_tracker = <lighteval.logging.evaluation_tracker.Evalu… │ │
# │ │                             object at 0x72d39a133340>                    │ │
# │ │                    job_id = 0                                            │ │
# │ │               max_samples = None                                         │ │
# │ │                model_args = 'pretrained=akhilfau/fine-tuned-smolLM2-360… │ │
# │ │           model_args_dict = {                                            │ │
# │ │                             │   'pretrained':                            │ │
# │ │                             'akhilfau/fine-tuned-smolLM2-360M-with-LoRA… │ │
# │ │                             │   'accelerator':                           │ │
# │ │                             <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x72d39c9bc850>,                          │ │
# │ │                             │   'use_chat_template': False,              │ │
# │ │                             │   'compile': False                         │ │
# │ │                             }                                            │ │
# │ │              model_config = TransformersModelConfig(                     │ │
# │ │                             │                                            │ │
# │ │                             pretrained='akhilfau/fine-tuned-smolLM2-360… │ │
# │ │                             │                                            │ │
# │ │                             accelerator=<accelerate.accelerator.Acceler… │ │
# │ │                             object at 0x72d39c9bc850>,                   │ │
# │ │                             │   tokenizer=None,                          │ │
# │ │                             │                                            │ │
# │ │                             multichoice_continuations_start_space=None,  │ │
# │ │                             │   pairwise_tokenization=False,             │ │
# │ │                             │   subfolder=None,                          │ │
# │ │                             │   revision='main',                         │ │
# │ │                             │   batch_size=-1,                           │ │
# │ │                             │   max_gen_toks=256,                        │ │
# │ │                             │   max_length=None,                         │ │
# │ │                             │   add_special_tokens=True,                 │ │
# │ │                             │   model_parallel=True,                     │ │
# │ │                             │   dtype=None,                              │ │
# │ │                             │   device='cuda',                           │ │
# │ │                             │   quantization_config=None,                │ │
# │ │                             │   trust_remote_code=False,                 │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   compile=False,                           │ │
# │ │                             │                                            │ │
# │ │                             generation_parameters=GenerationParameters(  │ │
# │ │                             │   │   early_stopping=None,                 │ │
# │ │                             │   │   repetition_penalty=None,             │ │
# │ │                             │   │   frequency_penalty=None,              │ │
# │ │                             │   │   length_penalty=None,                 │ │
# │ │                             │   │   presence_penalty=None,               │ │
# │ │                             │   │   max_new_tokens=None,                 │ │
# │ │                             │   │   min_new_tokens=None,                 │ │
# │ │                             │   │   seed=None,                           │ │
# │ │                             │   │   stop_tokens=None,                    │ │
# │ │                             │   │   temperature=None,                    │ │
# │ │                             │   │   top_k=None,                          │ │
# │ │                             │   │   min_p=None,                          │ │
# │ │                             │   │   top_p=None,                          │ │
# │ │                             │   │   truncate_prompt=None                 │ │
# │ │                             │   ),                                       │ │
# │ │                             │   generation_config=None                   │ │
# │ │                             )                                            │ │
# │ │         num_fewshot_seeds = 1                                            │ │
# │ │                output_dir = '/content/360M_supervised'                   │ │
# │ │       override_batch_size = 16                                           │ │
# │ │                  pipeline = <lighteval.pipeline.Pipeline object at       │ │
# │ │                             0x72d39a132770>                              │ │
# │ │           pipeline_params = PipelineParameters(                          │ │
# │ │                             │                                            │ │
# │ │                             launcher_type=<ParallelismManager.ACCELERAT… │ │
# │ │                             1>,                                          │ │
# │ │                             │   env_config=EnvConfig(                    │ │
# │ │                             │   │   cache_dir=None,                      │ │
# │ │                             │   │   token=None                           │ │
# │ │                             │   ),                                       │ │
# │ │                             │   job_id=0,                                │ │
# │ │                             │   dataset_loading_processes=1,             │ │
# │ │                             │   nanotron_checkpoint_path=None,           │ │
# │ │                             │   custom_tasks_directory=None,             │ │
# │ │                             │   override_batch_size=16,                  │ │
# │ │                             │   num_fewshot_seeds=1,                     │ │
# │ │                             │   max_samples=None,                        │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   system_prompt=None                       │ │
# │ │                             )                                            │ │
# │ │                public_run = False                                        │ │
# │ │               push_to_hub = False                                        │ │
# │ │       push_to_tensorboard = False                                        │ │
# │ │                   results = {                                            │ │
# │ │                             │   'config_general': {                      │ │
# │ │                             │   │   'lighteval_sha': '?',                │ │
# │ │                             │   │   'num_fewshot_seeds': 1,              │ │
# │ │                             │   │   'override_batch_size': 16,           │ │
# │ │                             │   │   'max_samples': None,                 │ │
# │ │                             │   │   'job_id': 0,                         │ │
# │ │                             │   │   'start_time': 80782.593353599,       │ │
# │ │                             │   │   'end_time': 80788.211824232,         │ │
# │ │                             │   │   'total_evaluation_time_secondes':    │ │
# │ │                             '5.618470632995013',                         │ │
# │ │                             │   │   'model_name':                        │ │
# │ │                             'akhilfau/fine-tuned-smolLM2-360M-with-LoRA… │ │
# │ │                             │   │   'model_sha':                         │ │
# │ │                             'dac3187866a397c41b9c0a8c26c74f374ab68174',  │ │
# │ │                             │   │   ... +3                               │ │
# │ │                             │   },                                       │ │
# │ │                             │   'results': {                             │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics:0':     │ │
# │ │                             defaultdict(<class 'float'>, {               │ │
# │ │                             │   │   │   'acc': 0.2680851063829787,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.02895734278834235                          │ │
# │ │                             │   │   }),                                  │ │
# │ │                             │   │   'all': {                             │ │
# │ │                             │   │   │   'acc': 0.2680851063829787,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.02895734278834235                          │ │
# │ │                             │   │   }                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'versions': {                            │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics:0': 0   │ │
# │ │                             │   },                                       │ │
# │ │                             │   'config_tasks': {                        │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics':       │ │
# │ │                             LightevalTaskConfig(                         │ │
# │ │                             │   │   │   name='mmlu:conceptual_physics',  │ │
# │ │                             │   │   │   prompt_function=<function        │ │
# │ │                             mmlu_harness at 0x72d39ab804c0>,             │ │
# │ │                             │   │   │   hf_repo='lighteval/mmlu',        │ │
# │ │                             │   │   │   hf_subset='conceptual_physics',  │ │
# │ │                             │   │   │   metric=(                         │ │
# │ │                             │   │   │   │   SampleLevelMetric(           │ │
# │ │                             │   │   │   │   │   metric_name='acc',       │ │
# │ │                             │   │   │   │   │   higher_is_better=True,   │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             category=<MetricCategory.MULTICHOICE: '8'>,  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             use_case=<MetricUseCase.ACCURACY: '1'>,      │ │
# │ │                             │   │   │   │   │   sample_level_fn=<bound   │ │
# │ │                             method LoglikelihoodAcc.compute of           │ │
# │ │                             <lighteval.metrics.metrics_sample.Loglikeli… │ │
# │ │                             object at 0x72d39c920880>>,                  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             corpus_level_fn=<function mean at            │ │
# │ │                             0x72d595fe7db0>                              │ │
# │ │                             │   │   │   │   ),                           │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   hf_revision=None,                │ │
# │ │                             │   │   │   hf_filter=None,                  │ │
# │ │                             │   │   │   hf_avail_splits=(                │ │
# │ │                             │   │   │   │   'auxiliary_train',           │ │
# │ │                             │   │   │   │   'test',                      │ │
# │ │                             │   │   │   │   'validation',                │ │
# │ │                             │   │   │   │   'dev'                        │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   trust_dataset=True,              │ │
# │ │                             │   │   │   evaluation_splits=('test',),     │ │
# │ │                             │   │   │   few_shots_split='dev',           │ │
# │ │                             │   │   │   few_shots_select='sequential',   │ │
# │ │                             │   │   │   generation_size=1,               │ │
# │ │                             │   │   │   generation_grammar=None,         │ │
# │ │                             │   │   │   stop_sequence=('\n',),           │ │
# │ │                             │   │   │   num_samples=None,                │ │
# │ │                             │   │   │   suite=('leaderboard', 'mmlu'),   │ │
# │ │                             │   │   │   original_num_docs=235,           │ │
# │ │                             │   │   │   effective_num_docs=235,          │ │
# │ │                             │   │   │                                    │ │
# │ │                             must_remove_duplicate_docs=False,            │ │
# │ │                             │   │   │   version=0                        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_tasks': {                       │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics:0':     │ │
# │ │                             CompiledDetail(                              │ │
# │ │                             │   │   │   hashes={                         │ │
# │ │                             │   │   │   │   'hash_examples':             │ │
# │ │                             '8300977a79386993',                          │ │
# │ │                             │   │   │   │   'hash_full_prompts':         │ │
# │ │                             '8300977a79386993',                          │ │
# │ │                             │   │   │   │   'hash_input_tokens':         │ │
# │ │                             '760a4d1dc23d371c',                          │ │
# │ │                             │   │   │   │   'hash_cont_tokens':          │ │
# │ │                             'bb3ae17ffc27f96d'                           │ │
# │ │                             │   │   │   },                               │ │
# │ │                             │   │   │   truncated=0,                     │ │
# │ │                             │   │   │   non_truncated=235,               │ │
# │ │                             │   │   │   padded=910,                      │ │
# │ │                             │   │   │   non_padded=30,                   │ │
# │ │                             │   │   │   effective_few_shots=0.0,         │ │
# │ │                             │   │   │   num_truncated_few_shots=0        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_general': {                     │ │
# │ │                             │   │   'hashes': {                          │ │
# │ │                             │   │   │   'hash_examples':                 │ │
# │ │                             'bb7fd366ab0a193d',                          │ │
# │ │                             │   │   │   'hash_full_prompts':             │ │
# │ │                             'bb7fd366ab0a193d',                          │ │
# │ │                             │   │   │   'hash_input_tokens':             │ │
# │ │                             '25febb4ecee25e02',                          │ │
# │ │                             │   │   │   'hash_cont_tokens':              │ │
# │ │                             '819d5b6dcaeadda2'                           │ │
# │ │                             │   │   },                                   │ │
# │ │                             │   │   'truncated': 0,                      │ │
# │ │                             │   │   'non_truncated': 235,                │ │
# │ │                             │   │   'padded': 910,                       │ │
# │ │                             │   │   'non_padded': 30,                    │ │
# │ │                             │   │   'num_truncated_few_shots': 0         │ │
# │ │                             │   }                                        │ │
# │ │                             }                                            │ │
# │ │               results_org = None                                         │ │
# │ │              save_details = False                                        │ │
# │ │             system_prompt = None                                         │ │
# │ │                     tasks = 'leaderboard|mmlu:conceptual_physics|0|0'    │ │
# │ │                     torch = <module 'torch' from                         │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ │         use_chat_template = False                                        │ │
# │ │                      yaml = <module 'yaml' from                          │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/pipeline.py:334 in save_and_push_results                                 │
# │                                                                              │
# │   331 │   def save_and_push_results(self):                                   │
# │   332 │   │   logger.info("--- SAVING AND PUSHING RESULTS ---")              │
# │   333 │   │   if self.is_main_process():                                     │
# │ ❱ 334 │   │   │   self.evaluation_tracker.save()                             │
# │   335 │                                                                      │
# │   336 │   def _init_final_dict(self):                                        │
# │   337 │   │   if self.is_main_process():                                     │
# │                                                                              │
# │ ╭─────────────────────────── locals ────────────────────────────╮            │
# │ │ self = <lighteval.pipeline.Pipeline object at 0x72d39a132770> │            │
# │ ╰───────────────────────────────────────────────────────────────╯            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/logging/evaluation_tracker.py:187 in save                                │
# │                                                                              │
# │   184 │   │   │   details_datasets[task_name] = dataset                      │
# │   185 │   │                                                                  │
# │   186 │   │   # We save results at every case                                │
# │ ❱ 187 │   │   self.save_results(date_id, results_dict)                       │
# │   188 │   │                                                                  │
# │   189 │   │   if self.should_save_details:                                   │
# │   190 │   │   │   self.save_details(date_id, details_datasets)               │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │     column_names = [                                                     │ │
# │ │                    │   'example',                                        │ │
# │ │                    │   'instruction',                                    │ │
# │ │                    │   'full_prompt',                                    │ │
# │ │                    │   'num_effective_few_shots',                        │ │
# │ │                    │   'num_asked_few_shots',                            │ │
# │ │                    │   'predictions',                                    │ │
# │ │                    │   'input_tokens',                                   │ │
# │ │                    │   'cont_tokens',                                    │ │
# │ │                    │   'truncated',                                      │ │
# │ │                    │   'padded',                                         │ │
# │ │                    │   ... +6                                            │ │
# │ │                    ]                                                     │ │
# │ │   config_general = {                                                     │ │
# │ │                    │   'lighteval_sha': '?',                             │ │
# │ │                    │   'num_fewshot_seeds': 1,                           │ │
# │ │                    │   'override_batch_size': 16,                        │ │
# │ │                    │   'max_samples': None,                              │ │
# │ │                    │   'job_id': 0,                                      │ │
# │ │                    │   'start_time': 80782.593353599,                    │ │
# │ │                    │   'end_time': 80788.211824232,                      │ │
# │ │                    │   'total_evaluation_time_secondes':                 │ │
# │ │                    '5.618470632995013',                                  │ │
# │ │                    │   'model_name':                                     │ │
# │ │                    'akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel… │ │
# │ │                    │   'model_sha':                                      │ │
# │ │                    'dac3187866a397c41b9c0a8c26c74f374ab68174',           │ │
# │ │                    │   ... +2                                            │ │
# │ │                    }                                                     │ │
# │ │          dataset = Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 235                                     │ │
# │ │                    })                                                    │ │
# │ │          date_id = '2025-03-05T11-54-08.072940'                          │ │
# │ │ details_datasets = {                                                     │ │
# │ │                    │   'leaderboard|mmlu:conceptual_physics|0':          │ │
# │ │                    Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 235                                     │ │
# │ │                    })                                                    │ │
# │ │                    }                                                     │ │
# │ │     results_dict = {                                                     │ │
# │ │                    │   'config_general': {                               │ │
# │ │                    │   │   'lighteval_sha': '?',                         │ │
# │ │                    │   │   'num_fewshot_seeds': 1,                       │ │
# │ │                    │   │   'override_batch_size': 16,                    │ │
# │ │                    │   │   'max_samples': None,                          │ │
# │ │                    │   │   'job_id': 0,                                  │ │
# │ │                    │   │   'start_time': 80782.593353599,                │ │
# │ │                    │   │   'end_time': 80788.211824232,                  │ │
# │ │                    │   │   'total_evaluation_time_secondes':             │ │
# │ │                    '5.618470632995013',                                  │ │
# │ │                    │   │   'model_name':                                 │ │
# │ │                    'akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel… │ │
# │ │                    │   │   'model_sha':                                  │ │
# │ │                    'dac3187866a397c41b9c0a8c26c74f374ab68174',           │ │
# │ │                    │   │   ... +2                                        │ │
# │ │                    │   },                                                │ │
# │ │                    │   'results': defaultdict(<function                  │ │
# │ │                    MetricsLogger.<lambda>.<locals>.<lambda> at           │ │
# │ │                    0x72d39a139cf0>, {                                    │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics|0':      │ │
# │ │                    defaultdict(<class 'float'>, {                        │ │
# │ │                    │   │   │   'acc': 0.2680851063829787,                │ │
# │ │                    │   │   │   'acc_stderr': 0.02895734278834235         │ │
# │ │                    │   │   }),                                           │ │
# │ │                    │   │   'all': {                                      │ │
# │ │                    │   │   │   'acc': 0.2680851063829787,                │ │
# │ │                    │   │   │   'acc_stderr': 0.02895734278834235         │ │
# │ │                    │   │   }                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'versions': {                                     │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics|0': 0    │ │
# │ │                    │   },                                                │ │
# │ │                    │   'config_tasks': {                                 │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics':        │ │
# │ │                    LightevalTaskConfig(                                  │ │
# │ │                    │   │   │   name='mmlu:conceptual_physics',           │ │
# │ │                    │   │   │   prompt_function=<function mmlu_harness at │ │
# │ │                    0x72d39ab804c0>,                                      │ │
# │ │                    │   │   │   hf_repo='lighteval/mmlu',                 │ │
# │ │                    │   │   │   hf_subset='conceptual_physics',           │ │
# │ │                    │   │   │   metric=(                                  │ │
# │ │                    │   │   │   │   SampleLevelMetric(                    │ │
# │ │                    │   │   │   │   │   metric_name='acc',                │ │
# │ │                    │   │   │   │   │   higher_is_better=True,            │ │
# │ │                    │   │   │   │   │                                     │ │
# │ │                    category=<MetricCategory.MULTICHOICE: '8'>,           │ │
# │ │                    │   │   │   │   │   use_case=<MetricUseCase.ACCURACY: │ │
# │ │                    '1'>,                                                 │ │
# │ │                    │   │   │   │   │   sample_level_fn=<bound method     │ │
# │ │                    LoglikelihoodAcc.compute of                           │ │
# │ │                    <lighteval.metrics.metrics_sample.LoglikelihoodAcc    │ │
# │ │                    object at 0x72d39c920880>>,                           │ │
# │ │                    │   │   │   │   │   corpus_level_fn=<function mean at │ │
# │ │                    0x72d595fe7db0>                                       │ │
# │ │                    │   │   │   │   ),                                    │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   hf_revision=None,                         │ │
# │ │                    │   │   │   hf_filter=None,                           │ │
# │ │                    │   │   │   hf_avail_splits=(                         │ │
# │ │                    │   │   │   │   'auxiliary_train',                    │ │
# │ │                    │   │   │   │   'test',                               │ │
# │ │                    │   │   │   │   'validation',                         │ │
# │ │                    │   │   │   │   'dev'                                 │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   trust_dataset=True,                       │ │
# │ │                    │   │   │   evaluation_splits=('test',),              │ │
# │ │                    │   │   │   few_shots_split='dev',                    │ │
# │ │                    │   │   │   few_shots_select='sequential',            │ │
# │ │                    │   │   │   generation_size=1,                        │ │
# │ │                    │   │   │   generation_grammar=None,                  │ │
# │ │                    │   │   │   stop_sequence=('\n',),                    │ │
# │ │                    │   │   │   num_samples=None,                         │ │
# │ │                    │   │   │   suite=('leaderboard', 'mmlu'),            │ │
# │ │                    │   │   │   original_num_docs=235,                    │ │
# │ │                    │   │   │   effective_num_docs=235,                   │ │
# │ │                    │   │   │   must_remove_duplicate_docs=False,         │ │
# │ │                    │   │   │   version=0                                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   },                                                │ │
# │ │                    │   'summary_tasks': defaultdict(<class               │ │
# │ │                    'lighteval.logging.info_loggers.DetailsLogger.Compil… │ │
# │ │                    {                                                     │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics|0':      │ │
# │ │                    CompiledDetail(                                       │ │
# │ │                    │   │   │   hashes={                                  │ │
# │ │                    │   │   │   │   'hash_examples': '8300977a79386993',  │ │
# │ │                    │   │   │   │   'hash_full_prompts':                  │ │
# │ │                    '8300977a79386993',                                   │ │
# │ │                    │   │   │   │   'hash_input_tokens':                  │ │
# │ │                    '760a4d1dc23d371c',                                   │ │
# │ │                    │   │   │   │   'hash_cont_tokens':                   │ │
# │ │                    'bb3ae17ffc27f96d'                                    │ │
# │ │                    │   │   │   },                                        │ │
# │ │                    │   │   │   truncated=0,                              │ │
# │ │                    │   │   │   non_truncated=235,                        │ │
# │ │                    │   │   │   padded=910,                               │ │
# │ │                    │   │   │   non_padded=30,                            │ │
# │ │                    │   │   │   effective_few_shots=0.0,                  │ │
# │ │                    │   │   │   num_truncated_few_shots=0                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'summary_general': {                              │ │
# │ │                    │   │   'hashes': {                                   │ │
# │ │                    │   │   │   'hash_examples': 'bb7fd366ab0a193d',      │ │
# │ │                    │   │   │   'hash_full_prompts': 'bb7fd366ab0a193d',  │ │
# │ │                    │   │   │   'hash_input_tokens': '25febb4ecee25e02',  │ │
# │ │                    │   │   │   'hash_cont_tokens': '819d5b6dcaeadda2'    │ │
# │ │                    │   │   },                                            │ │
# │ │                    │   │   'truncated': 0,                               │ │
# │ │                    │   │   'non_truncated': 235,                         │ │
# │ │                    │   │   'padded': 910,                                │ │
# │ │                    │   │   'non_padded': 30,                             │ │
# │ │                    │   │   'num_truncated_few_shots': 0                  │ │
# │ │                    │   }                                                 │ │
# │ │                    }                                                     │ │
# │ │             self = <lighteval.logging.evaluation_tracker.EvaluationTrac… │ │
# │ │                    object at 0x72d39a133340>                             │ │
# │ │     task_details = [                                                     │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about conceptual phys'+86,   │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+6,                                              │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+86,                                             │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-1.4375, False),                         │ │
# │ │                    │   │   │   (-1.3125, True),                          │ │
# │ │                    │   │   │   (-1.8125, False),                         │ │
# │ │                    │   │   │   (-1.6875, False)                          │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ]                                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   cont_tokens=[[330], [389], [340], [422]],     │ │
# │ │                    │   │   truncated=[0, 0, 0, 0],                       │ │
# │ │                    │   │   padded=[10, 10, 10, 10],                      │ │
# │ │                    │   │   gold=[],                                      │ │
# │ │                    │   │   pred_logits=[],                               │ │
# │ │                    │   │   choices=[' A', ' B', ' C', ' D'],             │ │
# │ │                    │   │   gold_index=[1],                               │ │
# │ │                    │   │   metrics={'acc': 1},                           │ │
# │ │                    │   │   specifics=None                                │ │
# │ │                    │   ),                                                │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about conceptual phys'+158,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+6,                                              │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+158,                                            │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-1.140625, True),                        │ │
# │ │                    │   │   │   (-1.515625, False),                       │ │
# │ │                    │   │   │   (-1.640625, False),                       │ │
# │ │                    │   │   │   (-1.890625, False)                        │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# ...
# │ │                      │   │   │   hf_revision=None,                       │ │
# │ │                      │   │   │   hf_filter=None,                         │ │
# │ │                      │   │   │   hf_avail_splits=(                       │ │
# │ │                      │   │   │   │   'auxiliary_train',                  │ │
# │ │                      │   │   │   │   'test',                             │ │
# │ │                      │   │   │   │   'validation',                       │ │
# │ │                      │   │   │   │   'dev'                               │ │
# │ │                      │   │   │   ),                                      │ │
# │ │                      │   │   │   trust_dataset=True,                     │ │
# │ │                      │   │   │   evaluation_splits=('test',),            │ │
# │ │                      │   │   │   few_shots_split='dev',                  │ │
# │ │                      │   │   │   few_shots_select='sequential',          │ │
# │ │                      │   │   │   generation_size=1,                      │ │
# │ │                      │   │   │   generation_grammar=None,                │ │
# │ │                      │   │   │   stop_sequence=('\n',),                  │ │
# │ │                      │   │   │   num_samples=None,                       │ │
# │ │                      │   │   │   suite=('leaderboard', 'mmlu'),          │ │
# │ │                      │   │   │   original_num_docs=235,                  │ │
# │ │                      │   │   │   effective_num_docs=235,                 │ │
# │ │                      │   │   │   must_remove_duplicate_docs=False,       │ │
# │ │                      │   │   │   version=0                               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   },                                              │ │
# │ │                      │   'summary_tasks': defaultdict(<class             │ │
# │ │                      'lighteval.logging.info_loggers.DetailsLogger.Comp… │ │
# │ │                      {                                                   │ │
# lu:conceptual_physics|0':    │ │ 'leaderboard|mm
# │ │                      CompiledDetail(                                     │ │
# │ │                      │   │   │   hashes={                                │ │
# │ │                      │   │   │   │   'hash_examples':                    │ │
# │ │                      '8300977a79386993',                                 │ │
# │ │                      │   │   │   │   'hash_full_prompts':                │ │
# │ │                      '8300977a79386993',                                 │ │
# │ │                      │   │   │   │   'hash_input_tokens':                │ │
# │ │                      '760a4d1dc23d371c',                                 │ │
# │ │                      │   │   │   │   'hash_cont_tokens':                 │ │
# │ │                      'bb3ae17ffc27f96d'                                  │ │
# │ │                      │   │   │   },                                      │ │
# │ │                      │   │   │   truncated=0,                            │ │
# │ │                      │   │   │   non_truncated=235,                      │ │
# │ │                      │   │   │   padded=910,                             │ │
# │ │                      │   │   │   non_padded=30,                          │ │
# │ │                      │   │   │   effective_few_shots=0.0,                │ │
# │ │                      │   │   │   num_truncated_few_shots=0               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   }),                                             │ │
# │ │                      │   'summary_general': {                            │ │
# │ │                      │   │   'hashes': {                                 │ │
# │ │                      │   │   │   'hash_examples': 'bb7fd366ab0a193d',    │ │
# │ │                      │   │   │   'hash_full_prompts':                    │ │
# │ │                      'bb7fd366ab0a193d',                                 │ │
# │ │                      │   │   │   'hash_input_tokens':                    │ │
# │ │                      '25febb4ecee25e02',                                 │ │
# │ │                      │   │   │   'hash_cont_tokens': '819d5b6dcaeadda2'  │ │
# │ │                      │   │   },                                          │ │
# │ │                      │   │   'truncated': 0,                             │ │
# │ │                      │   │   'non_truncated': 235,                       │ │
# │ │                      │   │   'padded': 910,                              │ │
# │ │                      │   │   'non_padded': 30,                           │ │
# │ │                      │   │   'num_truncated_few_shots': 0                │ │
# │ │                      │   }                                               │ │
# │ │                      }                                                   │ │
# │ │               self = <lighteval.logging.evaluation_tracker.EvaluationTr… │ │
# │ │                      object at 0x72d39a133340>                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /spec.py:1589 in mkdirs                                                      │
# │                                                                              │
# │   1586 │                                                                     │
# │   1587 │   def mkdirs(self, path, exist_ok=False):                           │
# │   1588 │   │   """Alias of `AbstractFileSystem.makedirs`."""                 │
# │ ❱ 1589 │   │   return self.makedirs(path, exist_ok=exist_ok)                 │
# │   1590 │                                                                     │
# │   1591 │   def listdir(self, path, detail=True, **kwargs):                   │
# │   1592 │   │   """Alias of `AbstractFileSystem.ls`."""                       │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = PosixPath('/content/360M_supervised/results/akhilfau/fine-tu… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x72d39a132800>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /implementations/local.py:52 in makedirs                                     │
# │                                                                              │
# │    49 │                                                                      │
# │    50 │   def makedirs(self, path, exist_ok=False):                          │
# │    51 │   │   path = self._strip_protocol(path)                              │
# │ ❱  52 │   │   os.makedirs(path, exist_ok=exist_ok)                           │
# │    53 │                                                                      │
# │    54 │   def rmdir(self, path):                                             │
# │    55 │   │   path = self._strip_protocol(path)                              │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = '/content/360M_supervised/results/akhilfau/fine-tuned-smolLM… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x72d39a132800>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     head = '/content/360M_supervised/results/akhilfau'                   │ │
# │ │     mode = 511                                                           │ │
# │ │     name = '/content/360M_supervised/results/akhilfau/fine-tuned-smolLM… │ │
# │ │     tail = 'fine-tuned-smolLM2-360M-with-LoRA-on-camel-ai-physics'       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭──────────────────────── locals ────────────────────────╮                   │
# │ │ exist_ok = True                                        │                   │
# │ │     head = '/content/360M_supervised/results'          │                   │
# │ │     mode = 511                                         │                   │
# │ │     name = '/content/360M_supervised/results/akhilfau' │                   │
# │ │     tail = 'akhilfau'                                  │                   │
# │ ╰────────────────────────────────────────────────────────╯                   │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭─────────────────── locals ────────────────────╮                            │
# │ │ exist_ok = True                               │                            │
# │ │     head = '/content/360M_supervised'         │                            │
# │ │     mode = 511                                │                            │
# │ │     name = '/content/360M_supervised/results' │                            │
# │ │     tail = 'results'                          │                            │
# │ ╰───────────────────────────────────────────────╯                            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭─────────────── locals ────────────────╮                                    │
# │ │ exist_ok = True                       │                                    │
# │ │     head = '/content'                 │                                    │
# │ │     mode = 511                        │                                    │
# │ │     name = '/content/360M_supervised' │                                    │
# │ │     tail = '360M_supervised'          │                                    │
# │ ╰───────────────────────────────────────╯                                    │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:225 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    222 │   │   if tail == cdir:           # xxx/newdir/. exists if xxx/newdi │
# │    223 │   │   │   return                                                    │
# │    224 │   try:                                                              │
# │ ❱  225 │   │   mkdir(name, mode)                                             │
# │    226 │   except OSError:                                                   │
# │    227 │   │   # Cannot rely on checking for EEXIST, since the operating sys │
# │    228 │   │   # could give priority to other errors like EACCES or EROFS    │
# │                                                                              │
# │ ╭─────── locals ────────╮                                                    │
# │ │ exist_ok = True       │                                                    │
# │ │     head = '/'        │                                                    │
# │ │     mode = 511        │                                                    │
# │ │     name = '/content' │                                                    │
# │ │     tail = 'content'  │                                                    │
# │ ╰───────────────────────╯                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
MODEL="HuggingFaceTB/SmolLM2-360M"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:conceptual_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [2025-03-05 11:51:27,587] [    INFO]: PyTorch version 2.4.1 available. (config.py:54)
# [2025-03-05 11:51:29,550] [    INFO]: Test gather tensor (parallelism.py:133)
# [2025-03-05 11:51:29,623] [    INFO]: gathered_tensor tensor([0], device='cuda:0'), should be [0] (parallelism.py:136)
# [2025-03-05 11:51:29,623] [    INFO]: --- LOADING MODEL --- (pipeline.py:168)
# [2025-03-05 11:51:29,774] [    INFO]: Tokenizer truncation and padding size set to the left side. (transformers_model.py:539)
# [2025-03-05 11:51:30,032] [    INFO]: Setting model parallel to True since the number of local processes is 1 and the number of GPUs is 4 (transformers_model.py:402)
# [2025-03-05 11:51:30,033] [    INFO]: Model parallel was set to True, setting max memory per GPU to {0: 10169221120, 1: 15557066752, 2: 15557066752, 3: 15573843968} and device map to auto (transformers_model.py:417)
# [2025-03-05 11:51:30,576] [    INFO]: --- LOADING TASKS --- (pipeline.py:195)
# [2025-03-05 11:51:30,576] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:136)
# [2025-03-05 11:51:30,578] [    INFO]: lighteval/mmlu conceptual_physics (lighteval_task.py:187)
# [2025-03-05 11:51:31,586] [    INFO]: --- INIT SEEDS --- (pipeline.py:224)
# [2025-03-05 11:51:31,586] [    INFO]: --- RUNNING MODEL --- (pipeline.py:267)
# [2025-03-05 11:51:31,586] [    INFO]: Running RequestType.LOGLIKELIHOOD requests (pipeline.py:271)
# 0it [00:00, ?it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#   7%|██▉                                         | 1/15 [00:00<00:05,  2.68it/s]
#  27%|███████████▋                                | 4/15 [00:00<00:01,  9.63it/s]
#  47%|████████████████████▌                       | 7/15 [00:00<00:00, 14.25it/s]
#  67%|████████████████████████████▋              | 10/15 [00:00<00:00, 17.42it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 15.72it/s]
# 1it [00:00,  1.05it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#  20%|████████▊                                   | 3/15 [00:00<00:00, 27.14it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:00, 27.25it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:00<00:00, 27.34it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:00<00:00, 27.28it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 27.37it/s]
# 2it [00:01,  1.40it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#  20%|████████▊                                   | 3/15 [00:00<00:00, 27.63it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:00, 27.72it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:00<00:00, 27.63it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:00<00:00, 27.62it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 27.71it/s]
# 3it [00:02,  1.57it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#  20%|████████▊                                   | 3/15 [00:00<00:00, 27.97it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:00, 28.41it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:00<00:00, 28.61it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:00<00:00, 28.58it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 28.56it/s]
# 4it [00:02,  1.56it/s]
# [2025-03-05 11:51:34,326] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:299)
# [2025-03-05 11:51:34,332] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:342)
# [2025-03-05 11:51:34,333] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# |                Task                 |Version|Metric|Value |   |Stderr|
# |-------------------------------------|------:|------|-----:|---|-----:|
# |all                                  |       |acc   |0.2851|±  |0.0295|
# |leaderboard:mmlu:conceptual_physics:0|      0|acc   |0.2851|±  |0.0295|
#
# [2025-03-05 11:51:34,345] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:332)
# [2025-03-05 11:51:34,345] [    INFO]: Saving experiment tracker (evaluation_tracker.py:154)
# [2025-03-05 11:51:34,345] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/main_accelerate.py:207 in accelerate                                     │
# │                                                                              │
# │   204 │                                                                      │
# │   205 │   results = pipeline.get_results()                                   │
# │   206 │                                                                      │
# │ ❱ 207 │   pipeline.save_and_push_results()                                   │
# │   208 │                                                                      │
# │   209 │   return results                                                     │
# │   210                                                                        │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │               accelerator = <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x778b61fc8790>                           │ │
# │ │                 cache_dir = None                                         │ │
# │ │              custom_tasks = None                                         │ │
# │ │ dataset_loading_processes = 1                                            │ │
# │ │                env_config = EnvConfig(cache_dir=None, token=None)        │ │
# │ │        evaluation_tracker = <lighteval.logging.evaluation_tracker.Evalu… │ │
# │ │                             object at 0x778b5f74ffd0>                    │ │
# │ │                    job_id = 0                                            │ │
# │ │               max_samples = None                                         │ │
# │ │                model_args = 'pretrained=HuggingFaceTB/SmolLM2-360M'      │ │
# │ │           model_args_dict = {                                            │ │
# │ │                             │   'pretrained':                            │ │
# │ │                             'HuggingFaceTB/SmolLM2-360M',                │ │
# │ │                             │   'accelerator':                           │ │
# │ │                             <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x778b61fc8790>,                          │ │
# │ │                             │   'use_chat_template': False,              │ │
# │ │                             │   'compile': False                         │ │
# │ │                             }                                            │ │
# │ │              model_config = TransformersModelConfig(                     │ │
# │ │                             │   pretrained='HuggingFaceTB/SmolLM2-360M', │ │
# │ │                             │                                            │ │
# │ │                             accelerator=<accelerate.accelerator.Acceler… │ │
# │ │                             object at 0x778b61fc8790>,                   │ │
# │ │                             │   tokenizer=None,                          │ │
# │ │                             │                                            │ │
# │ │                             multichoice_continuations_start_space=None,  │ │
# │ │                             │   pairwise_tokenization=False,             │ │
# │ │                             │   subfolder=None,                          │ │
# │ │                             │   revision='main',                         │ │
# │ │                             │   batch_size=-1,                           │ │
# │ │                             │   max_gen_toks=256,                        │ │
# │ │                             │   max_length=None,                         │ │
# │ │                             │   add_special_tokens=True,                 │ │
# │ │                             │   model_parallel=True,                     │ │
# │ │                             │   dtype=None,                              │ │
# │ │                             │   device='cuda',                           │ │
# │ │                             │   quantization_config=None,                │ │
# │ │                             │   trust_remote_code=False,                 │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   compile=False,                           │ │
# │ │                             │                                            │ │
# │ │                             generation_parameters=GenerationParameters(  │ │
# │ │                             │   │   early_stopping=None,                 │ │
# │ │                             │   │   repetition_penalty=None,             │ │
# │ │                             │   │   frequency_penalty=None,              │ │
# │ │                             │   │   length_penalty=None,                 │ │
# │ │                             │   │   presence_penalty=None,               │ │
# │ │                             │   │   max_new_tokens=None,                 │ │
# │ │                             │   │   min_new_tokens=None,                 │ │
# │ │                             │   │   seed=None,                           │ │
# │ │                             │   │   stop_tokens=None,                    │ │
# │ │                             │   │   temperature=None,                    │ │
# │ │                             │   │   top_k=None,                          │ │
# │ │                             │   │   min_p=None,                          │ │
# │ │                             │   │   top_p=None,                          │ │
# │ │                             │   │   truncate_prompt=None                 │ │
# │ │                             │   ),                                       │ │
# │ │                             │   generation_config=None                   │ │
# │ │                             )                                            │ │
# │ │         num_fewshot_seeds = 1                                            │ │
# │ │                output_dir = '/content/360M_output'                       │ │
# │ │       override_batch_size = 16                                           │ │
# │ │                  pipeline = <lighteval.pipeline.Pipeline object at       │ │
# │ │                             0x778b5f74e710>                              │ │
# │ │           pipeline_params = PipelineParameters(                          │ │
# │ │                             │                                            │ │
# │ │                             launcher_type=<ParallelismManager.ACCELERAT… │ │
# │ │                             1>,                                          │ │
# │ │                             │   env_config=EnvConfig(                    │ │
# │ │                             │   │   cache_dir=None,                      │ │
# │ │                             │   │   token=None                           │ │
# │ │                             │   ),                                       │ │
# │ │                             │   job_id=0,                                │ │
# │ │                             │   dataset_loading_processes=1,             │ │
# │ │                             │   nanotron_checkpoint_path=None,           │ │
# │ │                             │   custom_tasks_directory=None,             │ │
# │ │                             │   override_batch_size=16,                  │ │
# │ │                             │   num_fewshot_seeds=1,                     │ │
# │ │                             │   max_samples=None,                        │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   system_prompt=None                       │ │
# │ │                             )                                            │ │
# │ │                public_run = False                                        │ │
# │ │               push_to_hub = False                                        │ │
# │ │       push_to_tensorboard = False                                        │ │
# │ │                   results = {                                            │ │
# │ │                             │   'config_general': {                      │ │
# │ │                             │   │   'lighteval_sha': '?',                │ │
# │ │                             │   │   'num_fewshot_seeds': 1,              │ │
# │ │                             │   │   'override_batch_size': 16,           │ │
# │ │                             │   │   'max_samples': None,                 │ │
# │ │                             │   │   'job_id': 0,                         │ │
# │ │                             │   │   'start_time': 80629.701571604,       │ │
# │ │                             │   │   'end_time': 80634.484458863,         │ │
# │ │                             │   │   'total_evaluation_time_secondes':    │ │
# │ │                             '4.7828872589889215',                        │ │
# │ │                             │   │   'model_name':                        │ │
# │ │                             'HuggingFaceTB/SmolLM2-360M',                │ │
# │ │                             │   │   'model_sha':                         │ │
# │ │                             'f8027fd0eaeea54caa13c31d31b9fdc459c38b49',  │ │
# │ │                             │   │   ... +3                               │ │
# │ │                             │   },                                       │ │
# │ │                             │   'results': {                             │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics:0':     │ │
# │ │                             defaultdict(<class 'float'>, {               │ │
# │ │                             │   │   │   'acc': 0.2851063829787234,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.029513196625539345                         │ │
# │ │                             │   │   }),                                  │ │
# │ │                             │   │   'all': {                             │ │
# │ │                             │   │   │   'acc': 0.2851063829787234,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.029513196625539345                         │ │
# │ │                             │   │   }                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'versions': {                            │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics:0': 0   │ │
# │ │                             │   },                                       │ │
# │ │                             │   'config_tasks': {                        │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics':       │ │
# │ │                             LightevalTaskConfig(                         │ │
# │ │                             │   │   │   name='mmlu:conceptual_physics',  │ │
# │ │                             │   │   │   prompt_function=<function        │ │
# │ │                             mmlu_harness at 0x778b6019c550>,             │ │
# │ │                             │   │   │   hf_repo='lighteval/mmlu',        │ │
# │ │                             │   │   │   hf_subset='conceptual_physics',  │ │
# │ │                             │   │   │   metric=(                         │ │
# │ │                             │   │   │   │   SampleLevelMetric(           │ │
# │ │                             │   │   │   │   │   metric_name='acc',       │ │
# │ │                             │   │   │   │   │   higher_is_better=True,   │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             category=<MetricCategory.MULTICHOICE: '8'>,  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             use_case=<MetricUseCase.ACCURACY: '1'>,      │ │
# │ │                             │   │   │   │   │   sample_level_fn=<bound   │ │
# │ │                             method LoglikelihoodAcc.compute of           │ │
# │ │                             <lighteval.metrics.metrics_sample.Loglikeli… │ │
# │ │                             object at 0x778b61f34820>>,                  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             corpus_level_fn=<function mean at            │ │
# │ │                             0x778d5b5f35f0>                              │ │
# │ │                             │   │   │   │   ),                           │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   hf_revision=None,                │ │
# │ │                             │   │   │   hf_filter=None,                  │ │
# │ │                             │   │   │   hf_avail_splits=(                │ │
# │ │                             │   │   │   │   'auxiliary_train',           │ │
# │ │                             │   │   │   │   'test',                      │ │
# │ │                             │   │   │   │   'validation',                │ │
# │ │                             │   │   │   │   'dev'                        │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   trust_dataset=True,              │ │
# │ │                             │   │   │   evaluation_splits=('test',),     │ │
# │ │                             │   │   │   few_shots_split='dev',           │ │
# │ │                             │   │   │   few_shots_select='sequential',   │ │
# │ │                             │   │   │   generation_size=1,               │ │
# │ │                             │   │   │   generation_grammar=None,         │ │
# │ │                             │   │   │   stop_sequence=('\n',),           │ │
# │ │                             │   │   │   num_samples=None,                │ │
# │ │                             │   │   │   suite=('leaderboard', 'mmlu'),   │ │
# │ │                             │   │   │   original_num_docs=235,           │ │
# │ │                             │   │   │   effective_num_docs=235,          │ │
# │ │                             │   │   │                                    │ │
# │ │                             must_remove_duplicate_docs=False,            │ │
# │ │                             │   │   │   version=0                        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_tasks': {                       │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics:0':     │ │
# │ │                             CompiledDetail(                              │ │
# │ │                             │   │   │   hashes={                         │ │
# │ │                             │   │   │   │   'hash_examples':             │ │
# │ │                             '8300977a79386993',                          │ │
# │ │                             │   │   │   │   'hash_full_prompts':         │ │
# │ │                             '8300977a79386993',                          │ │
# │ │                             │   │   │   │   'hash_input_tokens':         │ │
# │ │                             '760a4d1dc23d371c',                          │ │
# │ │                             │   │   │   │   'hash_cont_tokens':          │ │
# │ │                             'bb3ae17ffc27f96d'                           │ │
# │ │                             │   │   │   },                               │ │
# │ │                             │   │   │   truncated=0,                     │ │
# │ │                             │   │   │   non_truncated=235,               │ │
# │ │                             │   │   │   padded=910,                      │ │
# │ │                             │   │   │   non_padded=30,                   │ │
# │ │                             │   │   │   effective_few_shots=0.0,         │ │
# │ │                             │   │   │   num_truncated_few_shots=0        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_general': {                     │ │
# │ │                             │   │   'hashes': {                          │ │
# │ │                             │   │   │   'hash_examples':                 │ │
# │ │                             'bb7fd366ab0a193d',                          │ │
# │ │                             │   │   │   'hash_full_prompts':             │ │
# │ │                             'bb7fd366ab0a193d',                          │ │
# │ │                             │   │   │   'hash_input_tokens':             │ │
# │ │                             '25febb4ecee25e02',                          │ │
# │ │                             │   │   │   'hash_cont_tokens':              │ │
# │ │                             '819d5b6dcaeadda2'                           │ │
# │ │                             │   │   },                                   │ │
# │ │                             │   │   'truncated': 0,                      │ │
# │ │                             │   │   'non_truncated': 235,                │ │
# │ │                             │   │   'padded': 910,                       │ │
# │ │                             │   │   'non_padded': 30,                    │ │
# │ │                             │   │   'num_truncated_few_shots': 0         │ │
# │ │                             │   }                                        │ │
# │ │                             }                                            │ │
# │ │               results_org = None                                         │ │
# │ │              save_details = False                                        │ │
# │ │             system_prompt = None                                         │ │
# │ │                     tasks = 'leaderboard|mmlu:conceptual_physics|0|0'    │ │
# │ │                     torch = <module 'torch' from                         │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ │         use_chat_template = False                                        │ │
# │ │                      yaml = <module 'yaml' from                          │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/pipeline.py:334 in save_and_push_results                                 │
# │                                                                              │
# │   331 │   def save_and_push_results(self):                                   │
# │   332 │   │   logger.info("--- SAVING AND PUSHING RESULTS ---")              │
# │   333 │   │   if self.is_main_process():                                     │
# │ ❱ 334 │   │   │   self.evaluation_tracker.save()                             │
# │   335 │                                                                      │
# │   336 │   def _init_final_dict(self):                                        │
# │   337 │   │   if self.is_main_process():                                     │
# │                                                                              │
# │ ╭─────────────────────────── locals ────────────────────────────╮            │
# │ │ self = <lighteval.pipeline.Pipeline object at 0x778b5f74e710> │            │
# │ ╰───────────────────────────────────────────────────────────────╯            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/logging/evaluation_tracker.py:187 in save                                │
# │                                                                              │
# │   184 │   │   │   details_datasets[task_name] = dataset                      │
# │   185 │   │                                                                  │
# │   186 │   │   # We save results at every case                                │
# │ ❱ 187 │   │   self.save_results(date_id, results_dict)                       │
# │   188 │   │                                                                  │
# │   189 │   │   if self.should_save_details:                                   │
# │   190 │   │   │   self.save_details(date_id, details_datasets)               │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │     column_names = [                                                     │ │
# │ │                    │   'example',                                        │ │
# │ │                    │   'instruction',                                    │ │
# │ │                    │   'full_prompt',                                    │ │
# │ │                    │   'num_effective_few_shots',                        │ │
# │ │                    │   'num_asked_few_shots',                            │ │
# │ │                    │   'predictions',                                    │ │
# │ │                    │   'input_tokens',                                   │ │
# │ │                    │   'cont_tokens',                                    │ │
# │ │                    │   'truncated',                                      │ │
# │ │                    │   'padded',                                         │ │
# │ │                    │   ... +6                                            │ │
# │ │                    ]                                                     │ │
# │ │   config_general = {                                                     │ │
# │ │                    │   'lighteval_sha': '?',                             │ │
# │ │                    │   'num_fewshot_seeds': 1,                           │ │
# │ │                    │   'override_batch_size': 16,                        │ │
# │ │                    │   'max_samples': None,                              │ │
# │ │                    │   'job_id': 0,                                      │ │
# │ │                    │   'start_time': 80629.701571604,                    │ │
# │ │                    │   'end_time': 80634.484458863,                      │ │
# │ │                    │   'total_evaluation_time_secondes':                 │ │
# │ │                    '4.7828872589889215',                                 │ │
# │ │                    │   'model_name': 'HuggingFaceTB/SmolLM2-360M',       │ │
# │ │                    │   'model_sha':                                      │ │
# │ │                    'f8027fd0eaeea54caa13c31d31b9fdc459c38b49',           │ │
# │ │                    │   ... +2                                            │ │
# │ │                    }                                                     │ │
# │ │          dataset = Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 235                                     │ │
# │ │                    })                                                    │ │
# │ │          date_id = '2025-03-05T11-51-34.345193'                          │ │
# │ │ details_datasets = {                                                     │ │
# │ │                    │   'leaderboard|mmlu:conceptual_physics|0':          │ │
# │ │                    Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 235                                     │ │
# │ │                    })                                                    │ │
# │ │                    }                                                     │ │
# │ │     results_dict = {                                                     │ │
# │ │                    │   'config_general': {                               │ │
# │ │                    │   │   'lighteval_sha': '?',                         │ │
# │ │                    │   │   'num_fewshot_seeds': 1,                       │ │
# │ │                    │   │   'override_batch_size': 16,                    │ │
# │ │                    │   │   'max_samples': None,                          │ │
# │ │                    │   │   'job_id': 0,                                  │ │
# │ │                    │   │   'start_time': 80629.701571604,                │ │
# │ │                    │   │   'end_time': 80634.484458863,                  │ │
# │ │                    │   │   'total_evaluation_time_secondes':             │ │
# │ │                    '4.7828872589889215',                                 │ │
# │ │                    │   │   'model_name': 'HuggingFaceTB/SmolLM2-360M',   │ │
# │ │                    │   │   'model_sha':                                  │ │
# │ │                    'f8027fd0eaeea54caa13c31d31b9fdc459c38b49',           │ │
# │ │                    │   │   ... +2                                        │ │
# │ │                    │   },                                                │ │
# │ │                    │   'results': defaultdict(<function                  │ │
# │ │                    MetricsLogger.<lambda>.<locals>.<lambda> at           │ │
# │ │                    0x778b5f755cf0>, {                                    │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics|0':      │ │
# │ │                    defaultdict(<class 'float'>, {                        │ │
# │ │                    │   │   │   'acc': 0.2851063829787234,                │ │
# │ │                    │   │   │   'acc_stderr': 0.029513196625539345        │ │
# │ │                    │   │   }),                                           │ │
# │ │                    │   │   'all': {                                      │ │
# │ │                    │   │   │   'acc': 0.2851063829787234,                │ │
# │ │                    │   │   │   'acc_stderr': 0.029513196625539345        │ │
# │ │                    │   │   }                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'versions': {                                     │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics|0': 0    │ │
# │ │                    │   },                                                │ │
# │ │                    │   'config_tasks': {                                 │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics':        │ │
# │ │                    LightevalTaskConfig(                                  │ │
# │ │                    │   │   │   name='mmlu:conceptual_physics',           │ │
# │ │                    │   │   │   prompt_function=<function mmlu_harness at │ │
# │ │                    0x778b6019c550>,                                      │ │
# │ │                    │   │   │   hf_repo='lighteval/mmlu',                 │ │
# │ │                    │   │   │   hf_subset='conceptual_physics',           │ │
# │ │                    │   │   │   metric=(                                  │ │
# │ │                    │   │   │   │   SampleLevelMetric(                    │ │
# │ │                    │   │   │   │   │   metric_name='acc',                │ │
# │ │                    │   │   │   │   │   higher_is_better=True,            │ │
# │ │                    │   │   │   │   │                                     │ │
# │ │                    category=<MetricCategory.MULTICHOICE: '8'>,           │ │
# │ │                    │   │   │   │   │   use_case=<MetricUseCase.ACCURACY: │ │
# │ │                    '1'>,                                                 │ │
# │ │                    │   │   │   │   │   sample_level_fn=<bound method     │ │
# │ │                    LoglikelihoodAcc.compute of                           │ │
# │ │                    <lighteval.metrics.metrics_sample.LoglikelihoodAcc    │ │
# │ │                    object at 0x778b61f34820>>,                           │ │
# │ │                    │   │   │   │   │   corpus_level_fn=<function mean at │ │
# │ │                    0x778d5b5f35f0>                                       │ │
# │ │                    │   │   │   │   ),                                    │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   hf_revision=None,                         │ │
# │ │                    │   │   │   hf_filter=None,                           │ │
# │ │                    │   │   │   hf_avail_splits=(                         │ │
# │ │                    │   │   │   │   'auxiliary_train',                    │ │
# │ │                    │   │   │   │   'test',                               │ │
# │ │                    │   │   │   │   'validation',                         │ │
# │ │                    │   │   │   │   'dev'                                 │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   trust_dataset=True,                       │ │
# │ │                    │   │   │   evaluation_splits=('test',),              │ │
# │ │                    │   │   │   few_shots_split='dev',                    │ │
# │ │                    │   │   │   few_shots_select='sequential',            │ │
# │ │                    │   │   │   generation_size=1,                        │ │
# │ │                    │   │   │   generation_grammar=None,                  │ │
# │ │                    │   │   │   stop_sequence=('\n',),                    │ │
# │ │                    │   │   │   num_samples=None,                         │ │
# │ │                    │   │   │   suite=('leaderboard', 'mmlu'),            │ │
# │ │                    │   │   │   original_num_docs=235,                    │ │
# │ │                    │   │   │   effective_num_docs=235,                   │ │
# │ │                    │   │   │   must_remove_duplicate_docs=False,         │ │
# │ │                    │   │   │   version=0                                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   },                                                │ │
# │ │                    │   'summary_tasks': defaultdict(<class               │ │
# │ │                    'lighteval.logging.info_loggers.DetailsLogger.Compil… │ │
# │ │                    {                                                     │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics|0':      │ │
# │ │                    CompiledDetail(                                       │ │
# │ │                    │   │   │   hashes={                                  │ │
# │ │                    │   │   │   │   'hash_examples': '8300977a79386993',  │ │
# │ │                    │   │   │   │   'hash_full_prompts':                  │ │
# │ │                    '8300977a79386993',                                   │ │
# │ │                    │   │   │   │   'hash_input_tokens':                  │ │
# │ │                    '760a4d1dc23d371c',                                   │ │
# │ │                    │   │   │   │   'hash_cont_tokens':                   │ │
# │ │                    'bb3ae17ffc27f96d'                                    │ │
# │ │                    │   │   │   },                                        │ │
# │ │                    │   │   │   truncated=0,                              │ │
# │ │                    │   │   │   non_truncated=235,                        │ │
# │ │                    │   │   │   padded=910,                               │ │
# │ │                    │   │   │   non_padded=30,                            │ │
# │ │                    │   │   │   effective_few_shots=0.0,                  │ │
# │ │                    │   │   │   num_truncated_few_shots=0                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'summary_general': {                              │ │
# │ │                    │   │   'hashes': {                                   │ │
# │ │                    │   │   │   'hash_examples': 'bb7fd366ab0a193d',      │ │
# │ │                    │   │   │   'hash_full_prompts': 'bb7fd366ab0a193d',  │ │
# │ │                    │   │   │   'hash_input_tokens': '25febb4ecee25e02',  │ │
# │ │                    │   │   │   'hash_cont_tokens': '819d5b6dcaeadda2'    │ │
# │ │                    │   │   },                                            │ │
# │ │                    │   │   'truncated': 0,                               │ │
# │ │                    │   │   'non_truncated': 235,                         │ │
# │ │                    │   │   'padded': 910,                                │ │
# │ │                    │   │   'non_padded': 30,                             │ │
# │ │                    │   │   'num_truncated_few_shots': 0                  │ │
# │ │                    │   }                                                 │ │
# │ │                    }                                                     │ │
# │ │             self = <lighteval.logging.evaluation_tracker.EvaluationTrac… │ │
# │ │                    object at 0x778b5f74ffd0>                             │ │
# │ │     task_details = [                                                     │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about conceptual phys'+86,   │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+6,                                              │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+86,                                             │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-1.9140625, False),                      │ │
# │ │                    │   │   │   (-1.5390625, False),                      │ │
# │ │                    │   │   │   (-1.6640625, False),                      │ │
# │ │                    │   │   │   (-1.4140625, True)                        │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ]                                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   cont_tokens=[[330], [389], [340], [422]],     │ │
# │ │                    │   │   truncated=[0, 0, 0, 0],                       │ │
# │ │                    │   │   padded=[10, 10, 10, 10],                      │ │
# │ │                    │   │   gold=[],                                      │ │
# │ │                    │   │   pred_logits=[],                               │ │
# │ │                    │   │   choices=[' A', ' B', ' C', ' D'],             │ │
# │ │                    │   │   gold_index=[1],                               │ │
# │ │                    │   │   metrics={'acc': 0},                           │ │
# │ │                    │   │   specifics=None                                │ │
# │ │                    │   ),                                                │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about conceptual phys'+158,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+6,                                              │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+158,                                            │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-1.46875, True),                         │ │
# │ │                    │   │   │   (-1.59375, False),                        │ │
# │ │                    │   │   │   (-1.46875, False),                        │ │
# │ │                    │   │   │   (-1.59375, False)                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# ...
# │ │                      │   │   │   hf_filter=None,                         │ │
# │ │                      │   │   │   hf_avail_splits=(                       │ │
# │ │                      │   │   │   │   'auxiliary_train',                  │ │
# │ │                      │   │   │   │   'test',                             │ │
# │ │                      │   │   │   │   'validation',                       │ │
# │ │                      │   │   │   │   'dev'                               │ │
# │ │                      │   │   │   ),                                      │ │
# │ │                      │   │   │   trust_dataset=True,                     │ │
# │ │                      │   │   │   evaluation_splits=('test',),            │ │
# │ │                      │   │   │   few_shots_split='dev',                  │ │
# │ │                      │   │   │   few_shots_select='sequential',          │ │
# │ │                      │   │   │   generation_size=1,                      │ │
# │ │                      │   │   │   generation_grammar=None,                │ │
# │ │                      │   │   │   stop_sequence=('\n',),                  │ │
# │ │                      │   │   │   num_samples=None,                       │ │
# │ │                      │   │   │   suite=('leaderboard', 'mmlu'),          │ │
# │ │                      │   │   │   original_num_docs=235,                  │ │
# │ │                      │   │   │   effective_num_docs=235,                 │ │
# │ │                      │   │   │   must_remove_duplicate_docs=False,       │ │
# │ │                      │   │   │   version=0                               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   },                                              │ │
# │ │                      │   'summary_tasks': defaultdict(<class             │ │
# │ │                      'lighteval.logging.info_loggers.DetailsLogger.Comp… │ │
# │ │                      {                                                   │ │
# │ │                      │   │   'leaderboard|mmlu:conceptual_physics|0':    │ │
# │ │                      CompiledDetail(                                     │ │
# │ │                      │   │   │   hashes={                                │ │
# │ │                      │   │   │   │   'hash_examples':                    │ │
# │ │                      '8300977a79386993',                                 │ │
# │ │                      │   │   │   │   'hash_full_prompts':                │ │
# │ │                      '8300977a79386993',                                 │ │
# │ │                      │   │   │   │   'hash_input_tokens':                │ │
# │ │                      '760a4d1dc23d371c',                                 │ │
# │ │                      │   │   │   │   'hash_cont_tokens':                 │ │
# │ │                      'bb3ae17ffc27f96d'                                  │ │
# │ │                      │   │   │   },                                      │ │
# │ │                      │   │   │   truncated=0,                            │ │
# │ │                      │   │   │   non_truncated=235,                      │ │
# │ │                      │   │   │   padded=910,                             │ │
# │ │                      │   │   │   non_padded=30,                          │ │
# │ │                      │   │   │   effective_few_shots=0.0,                │ │
# │ │                      │   │   │   num_truncated_few_shots=0               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   }),                                             │ │
# │ │                      │   'summary_general': {                            │ │
# │ │                      │   │   'hashes': {                                 │ │
# │ │                      │   │   │   'hash_examples': 'bb7fd366ab0a193d',    │ │
# │ │                      │   │   │   'hash_full_prompts':                    │ │
# │ │                      'bb7fd366ab0a193d',                                 │ │
# │ │                      │   │   │   'hash_input_tokens':                    │ │
# │ │                      '25febb4ecee25e02',                                 │ │
# │ │                      │   │   │   'hash_cont_tokens': '819d5b6dcaeadda2'  │ │
# │ │                      │   │   },                                          │ │
# │ │                      │   │   'truncated': 0,                             │ │
# │ │                      │   │   'non_truncated': 235,                       │ │
# │ │                      │   │   'padded': 910,                              │ │
# │ │                      │   │   'non_padded': 30,                           │ │
# │ │                      │   │   'num_truncated_few_shots': 0                │ │
# │ │                      │   }                                               │ │
# │ │                      }                                                   │ │
# │ │               self = <lighteval.logging.evaluation_tracker.EvaluationTr… │ │
# │ │                      object at 0x778b5f74ffd0>                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /spec.py:1589 in mkdirs                                                      │
# │                                                                              │
# │   1586 │                                                                     │
# │   1587 │   def mkdirs(self, path, exist_ok=False):                           │
# │   1588 │   │   """Alias of `AbstractFileSystem.makedirs`."""                 │
# │ ❱ 1589 │   │   return self.makedirs(path, exist_ok=exist_ok)                 │
# │   1590 │                                                                     │
# │   1591 │   def listdir(self, path, detail=True, **kwargs):                   │
# │   1592 │   │   """Alias of `AbstractFileSystem.ls`."""                       │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = PosixPath('/content/360M_output/results/HuggingFaceTB/SmolLM… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x778b5f74e7a0>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /implementations/local.py:52 in makedirs                                     │
# │                                                                              │
# │    49 │                                                                      │
# │    50 │   def makedirs(self, path, exist_ok=False):                          │
# │    51 │   │   path = self._strip_protocol(path)                              │
# │ ❱  52 │   │   os.makedirs(path, exist_ok=exist_ok)                           │
# │    53 │                                                                      │
# │    54 │   def rmdir(self, path):                                             │
# │    55 │   │   path = self._strip_protocol(path)                              │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = '/content/360M_output/results/HuggingFaceTB/SmolLM2-360M'     │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x778b5f74e7a0>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭─────────────────────────────── locals ───────────────────────────────╮     │
# │ │ exist_ok = True                                                      │     │
# │ │     head = '/content/360M_output/results/HuggingFaceTB'              │     │
# │ │     mode = 511                                                       │     │
# │ │     name = '/content/360M_output/results/HuggingFaceTB/SmolLM2-360M' │     │
# │ │     tail = 'SmolLM2-360M'                                            │     │
# │ ╰──────────────────────────────────────────────────────────────────────╯     │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭──────────────────────── locals ─────────────────────────╮                  │
# │ │ exist_ok = True                                         │                  │
# │ │     head = '/content/360M_output/results'               │                  │
# │ │     mode = 511                                          │                  │
# │ │     name = '/content/360M_output/results/HuggingFaceTB' │                  │
# │ │     tail = 'HuggingFaceTB'                              │                  │
# │ ╰─────────────────────────────────────────────────────────╯                  │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────── locals ──────────────────╮                                │
# │ │ exist_ok = True                           │                                │
# │ │     head = '/content/360M_output'         │                                │
# │ │     mode = 511                            │                                │
# │ │     name = '/content/360M_output/results' │                                │
# │ │     tail = 'results'                      │                                │
# │ ╰───────────────────────────────────────────╯                                │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────── locals ──────────────╮                                        │
# │ │ exist_ok = True                   │                                        │
# │ │     head = '/content'             │                                        │
# │ │     mode = 511                    │                                        │
# │ │     name = '/content/360M_output' │                                        │
# │ │     tail = '360M_output'          │                                        │
# │ ╰───────────────────────────────────╯                                        │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:225 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    222 │   │   if tail == cdir:           # xxx/newdir/. exists if xxx/newdi │
# │    223 │   │   │   return                                                    │
# │    224 │   try:                                                              │
# │ ❱  225 │   │   mkdir(name, mode)                                             │
# │    226 │   except OSError:                                                   │
# │    227 │   │   # Cannot rely on checking for EEXIST, since the operating sys │
# │    228 │   │   # could give priority to other errors like EACCES or EROFS    │
# │                                                                              │
# │ ╭─────── locals ────────╮                                                    │
# │ │ exist_ok = True       │                                                    │
# │ │     head = '/'        │                                                    │
# │ │     mode = 511        │                                                    │
# │ │     name = '/content' │                                                    │
# │ │     tail = 'content'  │                                                    │
# │ ╰───────────────────────╯                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
MODEL="akhilfau/Instruction_fine_tuned_on_camel_ai_physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:conceptual_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [2025-03-05 12:11:30,981] [    INFO]: PyTorch version 2.4.1 available. (config.py:54)
# [2025-03-05 12:11:32,963] [    INFO]: Test gather tensor (parallelism.py:133)
# [2025-03-05 12:11:33,038] [    INFO]: gathered_tensor tensor([0], device='cuda:0'), should be [0] (parallelism.py:136)
# [2025-03-05 12:11:33,038] [    INFO]: --- LOADING MODEL --- (pipeline.py:168)
# [2025-03-05 12:11:33,270] [    INFO]: Tokenizer truncation and padding size set to the left side. (transformers_model.py:539)
# [2025-03-05 12:11:33,511] [    INFO]: Setting model parallel to True since the number of local processes is 1 and the number of GPUs is 4 (transformers_model.py:402)
# [2025-03-05 12:11:33,512] [    INFO]: Model parallel was set to True, setting max memory per GPU to {0: 10169221120, 1: 15557066752, 2: 15557066752, 3: 15573843968} and device map to auto (transformers_model.py:417)
# [2025-03-05 12:11:34,153] [    INFO]: --- LOADING TASKS --- (pipeline.py:195)
# [2025-03-05 12:11:34,153] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:136)
# [2025-03-05 12:11:34,155] [    INFO]: lighteval/mmlu conceptual_physics (lighteval_task.py:187)
# [2025-03-05 12:11:35,645] [    INFO]: --- INIT SEEDS --- (pipeline.py:224)
# [2025-03-05 12:11:35,646] [    INFO]: --- RUNNING MODEL --- (pipeline.py:267)
# [2025-03-05 12:11:35,646] [    INFO]: Running RequestType.LOGLIKELIHOOD requests (pipeline.py:271)
# 0it [00:00, ?it/s]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#   7%|██▉                                         | 1/15 [00:00<00:05,  2.79it/s]
#  13%|█████▊                                      | 2/15 [00:00<00:02,  4.62it/s]
#  20%|████████▊                                   | 3/15 [00:00<00:02,  5.87it/s]
#  27%|███████████▋                                | 4/15 [00:00<00:01,  6.73it/s]
#  33%|██████████████▋                             | 5/15 [00:00<00:01,  7.32it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:01,  7.70it/s]
#  47%|████████████████████▌                       | 7/15 [00:01<00:01,  7.99it/s]
#  53%|███████████████████████▍                    | 8/15 [00:01<00:00,  8.21it/s]
#  60%|██████████████████████████▍                 | 9/15 [00:01<00:00,  8.35it/s]
#  67%|████████████████████████████▋              | 10/15 [00:01<00:00,  8.43it/s]
#  73%|███████████████████████████████▌           | 11/15 [00:01<00:00,  8.48it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:01<00:00,  8.52it/s]
#  87%|█████████████████████████████████████▎     | 13/15 [00:01<00:00,  8.56it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:01<00:00,  7.72it/s]
# 1it [00:01,  1.94s/it]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#  13%|█████▊                                      | 2/15 [00:00<00:00, 13.06it/s]
#  27%|███████████▋                                | 4/15 [00:00<00:00, 13.03it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:00, 12.98it/s]
#  53%|███████████████████████▍                    | 8/15 [00:00<00:00, 13.00it/s]
#  67%|████████████████████████████▋              | 10/15 [00:00<00:00, 13.05it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:00<00:00, 13.06it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:01<00:00, 13.31it/s]
# 2it [00:03,  1.46s/it]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#  13%|█████▊                                      | 2/15 [00:00<00:00, 15.08it/s]
#  27%|███████████▋                                | 4/15 [00:00<00:00, 15.04it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:00, 15.02it/s]
#  53%|███████████████████████▍                    | 8/15 [00:00<00:00, 15.06it/s]
#  67%|████████████████████████████▋              | 10/15 [00:00<00:00, 15.09it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:00<00:00, 15.10it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 15.31it/s]
# 3it [00:04,  1.24s/it]
#   0%|                                                    | 0/15 [00:00<?, ?it/s]
#  13%|█████▊                                      | 2/15 [00:00<00:00, 16.60it/s]
#  27%|███████████▋                                | 4/15 [00:00<00:00, 16.58it/s]
#  40%|█████████████████▌                          | 6/15 [00:00<00:00, 16.57it/s]
#  53%|███████████████████████▍                    | 8/15 [00:00<00:00, 16.52it/s]
#  67%|████████████████████████████▋              | 10/15 [00:00<00:00, 16.48it/s]
#  80%|██████████████████████████████████▍        | 12/15 [00:00<00:00, 16.50it/s]
# 100%|███████████████████████████████████████████| 15/15 [00:00<00:00, 16.77it/s]
# 4it [00:04,  1.24s/it]
# [2025-03-05 12:11:40,769] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:299)
# [2025-03-05 12:11:40,776] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:342)
# [2025-03-05 12:11:40,776] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# |                Task                 |Version|Metric|Value |   |Stderr|
# |-------------------------------------|------:|------|-----:|---|-----:|
# |all                                  |       |acc   |0.2298|±  |0.0275|
# |leaderboard:mmlu:conceptual_physics:0|      0|acc   |0.2298|±  |0.0275|
#
# [2025-03-05 12:11:40,789] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:332)
# [2025-03-05 12:11:40,789] [    INFO]: Saving experiment tracker (evaluation_tracker.py:154)
# [2025-03-05 12:11:40,789] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/main_accelerate.py:207 in accelerate                                     │
# │                                                                              │
# │   204 │                                                                      │
# │   205 │   results = pipeline.get_results()                                   │
# │   206 │                                                                      │
# │ ❱ 207 │   pipeline.save_and_push_results()                                   │
# │   208 │                                                                      │
# │   209 │   return results                                                     │
# │   210                                                                        │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │               accelerator = <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x76d973bd0670>                           │ │
# │ │                 cache_dir = None                                         │ │
# │ │              custom_tasks = None                                         │ │
# │ │ dataset_loading_processes = 1                                            │ │
# │ │                env_config = EnvConfig(cache_dir=None, token=None)        │ │
# │ │        evaluation_tracker = <lighteval.logging.evaluation_tracker.Evalu… │ │
# │ │                             object at 0x76d971357fd0>                    │ │
# │ │                    job_id = 0                                            │ │
# │ │               max_samples = None                                         │ │
# │ │                model_args = 'pretrained=akhilfau/Instruction_fine_tuned… │ │
# │ │           model_args_dict = {                                            │ │
# │ │                             │   'pretrained':                            │ │
# │ │                             'akhilfau/Instruction_fine_tuned_on_camel_a… │ │
# │ │                             │   'accelerator':                           │ │
# │ │                             <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x76d973bd0670>,                          │ │
# │ │                             │   'use_chat_template': False,              │ │
# │ │                             │   'compile': False                         │ │
# │ │                             }                                            │ │
# │ │              model_config = TransformersModelConfig(                     │ │
# │ │                             │                                            │ │
# │ │                             pretrained='akhilfau/Instruction_fine_tuned… │ │
# │ │                             │                                            │ │
# │ │                             accelerator=<accelerate.accelerator.Acceler… │ │
# │ │                             object at 0x76d973bd0670>,                   │ │
# │ │                             │   tokenizer=None,                          │ │
# │ │                             │                                            │ │
# │ │                             multichoice_continuations_start_space=None,  │ │
# │ │                             │   pairwise_tokenization=False,             │ │
# │ │                             │   subfolder=None,                          │ │
# │ │                             │   revision='main',                         │ │
# │ │                             │   batch_size=-1,                           │ │
# │ │                             │   max_gen_toks=256,                        │ │
# │ │                             │   max_length=None,                         │ │
# │ │                             │   add_special_tokens=True,                 │ │
# │ │                             │   model_parallel=True,                     │ │
# │ │                             │   dtype=None,                              │ │
# │ │                             │   device='cuda',                           │ │
# │ │                             │   quantization_config=None,                │ │
# │ │                             │   trust_remote_code=False,                 │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   compile=False,                           │ │
# │ │                             │                                            │ │
# │ │                             generation_parameters=GenerationParameters(  │ │
# │ │                             │   │   early_stopping=None,                 │ │
# │ │                             │   │   repetition_penalty=None,             │ │
# │ │                             │   │   frequency_penalty=None,              │ │
# │ │                             │   │   length_penalty=None,                 │ │
# │ │                             │   │   presence_penalty=None,               │ │
# │ │                             │   │   max_new_tokens=None,                 │ │
# │ │                             │   │   min_new_tokens=None,                 │ │
# │ │                             │   │   seed=None,                           │ │
# │ │                             │   │   stop_tokens=None,                    │ │
# │ │                             │   │   temperature=None,                    │ │
# │ │                             │   │   top_k=None,                          │ │
# │ │                             │   │   min_p=None,                          │ │
# │ │                             │   │   top_p=None,                          │ │
# │ │                             │   │   truncate_prompt=None                 │ │
# │ │                             │   ),                                       │ │
# │ │                             │   generation_config=None                   │ │
# │ │                             )                                            │ │
# │ │         num_fewshot_seeds = 1                                            │ │
# │ │                output_dir = '/content/360M_output'                       │ │
# │ │       override_batch_size = 16                                           │ │
# │ │                  pipeline = <lighteval.pipeline.Pipeline object at       │ │
# │ │                             0x76d9713566b0>                              │ │
# │ │           pipeline_params = PipelineParameters(                          │ │
# │ │                             │                                            │ │
# │ │                             launcher_type=<ParallelismManager.ACCELERAT… │ │
# │ │                             1>,                                          │ │
# │ │                             │   env_config=EnvConfig(                    │ │
# │ │                             │   │   cache_dir=None,                      │ │
# │ │                             │   │   token=None                           │ │
# │ │                             │   ),                                       │ │
# │ │                             │   job_id=0,                                │ │
# │ │                             │   dataset_loading_processes=1,             │ │
# │ │                             │   nanotron_checkpoint_path=None,           │ │
# │ │                             │   custom_tasks_directory=None,             │ │
# │ │                             │   override_batch_size=16,                  │ │
# │ │                             │   num_fewshot_seeds=1,                     │ │
# │ │                             │   max_samples=None,                        │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   system_prompt=None                       │ │
# │ │                             )                                            │ │
# │ │                public_run = False                                        │ │
# │ │               push_to_hub = False                                        │ │
# │ │       push_to_tensorboard = False                                        │ │
# │ │                   results = {                                            │ │
# │ │                             │   'config_general': {                      │ │
# │ │                             │   │   'lighteval_sha': '?',                │ │
# │ │                             │   │   'num_fewshot_seeds': 1,              │ │
# │ │                             │   │   'override_batch_size': 16,           │ │
# │ │                             │   │   'max_samples': None,                 │ │
# │ │                             │   │   'job_id': 0,                         │ │
# │ │                             │   │   'start_time': 81833.114055362,       │ │
# │ │                             │   │   'end_time': 81840.928344244,         │ │
# │ │                             │   │   'total_evaluation_time_secondes':    │ │
# │ │                             '7.814288882000255',                         │ │
# │ │                             │   │   'model_name':                        │ │
# │ │                             'akhilfau/Instruction_fine_tuned_on_camel_a… │ │
# │ │                             │   │   'model_sha':                         │ │
# │ │                             '28a1c11b822b6210e111db9e153c1bae2491e76e',  │ │
# │ │                             │   │   ... +3                               │ │
# │ │                             │   },                                       │ │
# │ │                             │   'results': {                             │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics:0':     │ │
# │ │                             defaultdict(<class 'float'>, {               │ │
# │ │                             │   │   │   'acc': 0.2297872340425532,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.027501752944412428                         │ │
# │ │                             │   │   }),                                  │ │
# │ │                             │   │   'all': {                             │ │
# │ │                             │   │   │   'acc': 0.2297872340425532,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.027501752944412428                         │ │
# │ │                             │   │   }                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'versions': {                            │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics:0': 0   │ │
# │ │                             │   },                                       │ │
# │ │                             │   'config_tasks': {                        │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics':       │ │
# │ │                             LightevalTaskConfig(                         │ │
# │ │                             │   │   │   name='mmlu:conceptual_physics',  │ │
# │ │                             │   │   │   prompt_function=<function        │ │
# │ │                             mmlu_harness at 0x76d971da4550>,             │ │
# │ │                             │   │   │   hf_repo='lighteval/mmlu',        │ │
# │ │                             │   │   │   hf_subset='conceptual_physics',  │ │
# │ │                             │   │   │   metric=(                         │ │
# │ │                             │   │   │   │   SampleLevelMetric(           │ │
# │ │                             │   │   │   │   │   metric_name='acc',       │ │
# │ │                             │   │   │   │   │   higher_is_better=True,   │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             category=<MetricCategory.MULTICHOICE: '8'>,  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             use_case=<MetricUseCase.ACCURACY: '1'>,      │ │
# │ │                             │   │   │   │   │   sample_level_fn=<bound   │ │
# │ │                             method LoglikelihoodAcc.compute of           │ │
# │ │                             <lighteval.metrics.metrics_sample.Loglikeli… │ │
# │ │                             object at 0x76d973b38c70>>,                  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             corpus_level_fn=<function mean at            │ │
# │ │                             0x76db6cc93bf0>                              │ │
# │ │                             │   │   │   │   ),                           │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   hf_revision=None,                │ │
# │ │                             │   │   │   hf_filter=None,                  │ │
# │ │                             │   │   │   hf_avail_splits=(                │ │
# │ │                             │   │   │   │   'auxiliary_train',           │ │
# │ │                             │   │   │   │   'test',                      │ │
# │ │                             │   │   │   │   'validation',                │ │
# │ │                             │   │   │   │   'dev'                        │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   trust_dataset=True,              │ │
# │ │                             │   │   │   evaluation_splits=('test',),     │ │
# │ │                             │   │   │   few_shots_split='dev',           │ │
# │ │                             │   │   │   few_shots_select='sequential',   │ │
# │ │                             │   │   │   generation_size=1,               │ │
# │ │                             │   │   │   generation_grammar=None,         │ │
# │ │                             │   │   │   stop_sequence=('\n',),           │ │
# │ │                             │   │   │   num_samples=None,                │ │
# │ │                             │   │   │   suite=('leaderboard', 'mmlu'),   │ │
# │ │                             │   │   │   original_num_docs=235,           │ │
# │ │                             │   │   │   effective_num_docs=235,          │ │
# │ │                             │   │   │                                    │ │
# │ │                             must_remove_duplicate_docs=False,            │ │
# │ │                             │   │   │   version=0                        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_tasks': {                       │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:conceptual_physics:0':     │ │
# │ │                             CompiledDetail(                              │ │
# │ │                             │   │   │   hashes={                         │ │
# │ │                             │   │   │   │   'hash_examples':             │ │
# │ │                             '8300977a79386993',                          │ │
# │ │                             │   │   │   │   'hash_full_prompts':         │ │
# │ │                             '8300977a79386993',                          │ │
# │ │                             │   │   │   │   'hash_input_tokens':         │ │
# │ │                             '911e36df50b000e2',                          │ │
# │ │                             │   │   │   │   'hash_cont_tokens':          │ │
# │ │                             'bb3ae17ffc27f96d'                           │ │
# │ │                             │   │   │   },                               │ │
# │ │                             │   │   │   truncated=0,                     │ │
# │ │                             │   │   │   non_truncated=235,               │ │
# │ │                             │   │   │   padded=910,                      │ │
# │ │                             │   │   │   non_padded=30,                   │ │
# │ │                             │   │   │   effective_few_shots=0.0,         │ │
# │ │                             │   │   │   num_truncated_few_shots=0        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_general': {                     │ │
# │ │                             │   │   'hashes': {                          │ │
# │ │                             │   │   │   'hash_examples':                 │ │
# │ │                             'bb7fd366ab0a193d',                          │ │
# │ │                             │   │   │   'hash_full_prompts':             │ │
# │ │                             'bb7fd366ab0a193d',                          │ │
# │ │                             │   │   │   'hash_input_tokens':             │ │
# │ │                             '064b649804833afa',                          │ │
# │ │                             │   │   │   'hash_cont_tokens':              │ │
# │ │                             '819d5b6dcaeadda2'                           │ │
# │ │                             │   │   },                                   │ │
# │ │                             │   │   'truncated': 0,                      │ │
# │ │                             │   │   'non_truncated': 235,                │ │
# │ │                             │   │   'padded': 910,                       │ │
# │ │                             │   │   'non_padded': 30,                    │ │
# │ │                             │   │   'num_truncated_few_shots': 0         │ │
# │ │                             │   }                                        │ │
# │ │                             }                                            │ │
# │ │               results_org = None                                         │ │
# │ │              save_details = False                                        │ │
# │ │             system_prompt = None                                         │ │
# │ │                     tasks = 'leaderboard|mmlu:conceptual_physics|0|0'    │ │
# │ │                     torch = <module 'torch' from                         │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ │         use_chat_template = False                                        │ │
# │ │                      yaml = <module 'yaml' from                          │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/pipeline.py:334 in save_and_push_results                                 │
# │                                                                              │
# │   331 │   def save_and_push_results(self):                                   │
# │   332 │   │   logger.info("--- SAVING AND PUSHING RESULTS ---")              │
# │   333 │   │   if self.is_main_process():                                     │
# │ ❱ 334 │   │   │   self.evaluation_tracker.save()                             │
# │   335 │                                                                      │
# │   336 │   def _init_final_dict(self):                                        │
# │   337 │   │   if self.is_main_process():                                     │
# │                                                                              │
# │ ╭─────────────────────────── locals ────────────────────────────╮            │
# │ │ self = <lighteval.pipeline.Pipeline object at 0x76d9713566b0> │            │
# │ ╰───────────────────────────────────────────────────────────────╯            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/logging/evaluation_tracker.py:187 in save                                │
# │                                                                              │
# │   184 │   │   │   details_datasets[task_name] = dataset                      │
# │   185 │   │                                                                  │
# │   186 │   │   # We save results at every case                                │
# │ ❱ 187 │   │   self.save_results(date_id, results_dict)                       │
# │   188 │   │                                                                  │
# │   189 │   │   if self.should_save_details:                                   │
# │   190 │   │   │   self.save_details(date_id, details_datasets)               │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │     column_names = [                                                     │ │
# │ │                    │   'example',                                        │ │
# │ │                    │   'instruction',                                    │ │
# │ │                    │   'full_prompt',                                    │ │
# │ │                    │   'num_effective_few_shots',                        │ │
# │ │                    │   'num_asked_few_shots',                            │ │
# │ │                    │   'predictions',                                    │ │
# │ │                    │   'input_tokens',                                   │ │
# │ │                    │   'cont_tokens',                                    │ │
# │ │                    │   'truncated',                                      │ │
# │ │                    │   'padded',                                         │ │
# │ │                    │   ... +6                                            │ │
# │ │                    ]                                                     │ │
# │ │   config_general = {                                                     │ │
# │ │                    │   'lighteval_sha': '?',                             │ │
# │ │                    │   'num_fewshot_seeds': 1,                           │ │
# │ │                    │   'override_batch_size': 16,                        │ │
# │ │                    │   'max_samples': None,                              │ │
# │ │                    │   'job_id': 0,                                      │ │
# │ │                    │   'start_time': 81833.114055362,                    │ │
# │ │                    │   'end_time': 81840.928344244,                      │ │
# │ │                    │   'total_evaluation_time_secondes':                 │ │
# │ │                    '7.814288882000255',                                  │ │
# │ │                    │   'model_name':                                     │ │
# │ │                    'akhilfau/Instruction_fine_tuned_on_camel_ai_physics… │ │
# │ │                    │   'model_sha':                                      │ │
# │ │                    '28a1c11b822b6210e111db9e153c1bae2491e76e',           │ │
# │ │                    │   ... +2                                            │ │
# │ │                    }                                                     │ │
# │ │          dataset = Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 235                                     │ │
# │ │                    })                                                    │ │
# │ │          date_id = '2025-03-05T12-11-40.789218'                          │ │
# │ │ details_datasets = {                                                     │ │
# │ │                    │   'leaderboard|mmlu:conceptual_physics|0':          │ │
# │ │                    Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 235                                     │ │
# │ │                    })                                                    │ │
# │ │                    }                                                     │ │
# │ │     results_dict = {                                                     │ │
# │ │                    │   'config_general': {                               │ │
# │ │                    │   │   'lighteval_sha': '?',                         │ │
# │ │                    │   │   'num_fewshot_seeds': 1,                       │ │
# │ │                    │   │   'override_batch_size': 16,                    │ │
# │ │                    │   │   'max_samples': None,                          │ │
# │ │                    │   │   'job_id': 0,                                  │ │
# │ │                    │   │   'start_time': 81833.114055362,                │ │
# │ │                    │   │   'end_time': 81840.928344244,                  │ │
# │ │                    │   │   'total_evaluation_time_secondes':             │ │
# │ │                    '7.814288882000255',                                  │ │
# │ │                    │   │   'model_name':                                 │ │
# │ │                    'akhilfau/Instruction_fine_tuned_on_camel_ai_physics… │ │
# │ │                    │   │   'model_sha':                                  │ │
# │ │                    '28a1c11b822b6210e111db9e153c1bae2491e76e',           │ │
# │ │                    │   │   ... +2                                        │ │
# │ │                    │   },                                                │ │
# │ │                    │   'results': defaultdict(<function                  │ │
# │ │                    MetricsLogger.<lambda>.<locals>.<lambda> at           │ │
# │ │                    0x76d97135dcf0>, {                                    │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics|0':      │ │
# │ │                    defaultdict(<class 'float'>, {                        │ │
# │ │                    │   │   │   'acc': 0.2297872340425532,                │ │
# │ │                    │   │   │   'acc_stderr': 0.027501752944412428        │ │
# │ │                    │   │   }),                                           │ │
# │ │                    │   │   'all': {                                      │ │
# │ │                    │   │   │   'acc': 0.2297872340425532,                │ │
# │ │                    │   │   │   'acc_stderr': 0.027501752944412428        │ │
# │ │                    │   │   }                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'versions': {                                     │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics|0': 0    │ │
# │ │                    │   },                                                │ │
# │ │                    │   'config_tasks': {                                 │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics':        │ │
# │ │                    LightevalTaskConfig(                                  │ │
# │ │                    │   │   │   name='mmlu:conceptual_physics',           │ │
# │ │                    │   │   │   prompt_function=<function mmlu_harness at │ │
# │ │                    0x76d971da4550>,                                      │ │
# │ │                    │   │   │   hf_repo='lighteval/mmlu',                 │ │
# │ │                    │   │   │   hf_subset='conceptual_physics',           │ │
# │ │                    │   │   │   metric=(                                  │ │
# │ │                    │   │   │   │   SampleLevelMetric(                    │ │
# │ │                    │   │   │   │   │   metric_name='acc',                │ │
# │ │                    │   │   │   │   │   higher_is_better=True,            │ │
# │ │                    │   │   │   │   │                                     │ │
# │ │                    category=<MetricCategory.MULTICHOICE: '8'>,           │ │
# │ │                    │   │   │   │   │   use_case=<MetricUseCase.ACCURACY: │ │
# │ │                    '1'>,                                                 │ │
# │ │                    │   │   │   │   │   sample_level_fn=<bound method     │ │
# │ │                    LoglikelihoodAcc.compute of                           │ │
# │ │                    <lighteval.metrics.metrics_sample.LoglikelihoodAcc    │ │
# │ │                    object at 0x76d973b38c70>>,                           │ │
# │ │                    │   │   │   │   │   corpus_level_fn=<function mean at │ │
# │ │                    0x76db6cc93bf0>                                       │ │
# │ │                    │   │   │   │   ),                                    │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   hf_revision=None,                         │ │
# │ │                    │   │   │   hf_filter=None,                           │ │
# │ │                    │   │   │   hf_avail_splits=(                         │ │
# │ │                    │   │   │   │   'auxiliary_train',                    │ │
# │ │                    │   │   │   │   'test',                               │ │
# │ │                    │   │   │   │   'validation',                         │ │
# │ │                    │   │   │   │   'dev'                                 │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   trust_dataset=True,                       │ │
# │ │                    │   │   │   evaluation_splits=('test',),              │ │
# │ │                    │   │   │   few_shots_split='dev',                    │ │
# │ │                    │   │   │   few_shots_select='sequential',            │ │
# │ │                    │   │   │   generation_size=1,                        │ │
# │ │                    │   │   │   generation_grammar=None,                  │ │
# │ │                    │   │   │   stop_sequence=('\n',),                    │ │
# │ │                    │   │   │   num_samples=None,                         │ │
# │ │                    │   │   │   suite=('leaderboard', 'mmlu'),            │ │
# │ │                    │   │   │   original_num_docs=235,                    │ │
# │ │                    │   │   │   effective_num_docs=235,                   │ │
# │ │                    │   │   │   must_remove_duplicate_docs=False,         │ │
# │ │                    │   │   │   version=0                                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   },                                                │ │
# │ │                    │   'summary_tasks': defaultdict(<class               │ │
# │ │                    'lighteval.logging.info_loggers.DetailsLogger.Compil… │ │
# │ │                    {                                                     │ │
# │ │                    │   │   'leaderboard|mmlu:conceptual_physics|0':      │ │
# │ │                    CompiledDetail(                                       │ │
# │ │                    │   │   │   hashes={                                  │ │
# │ │                    │   │   │   │   'hash_examples': '8300977a79386993',  │ │
# │ │                    │   │   │   │   'hash_full_prompts':                  │ │
# │ │                    '8300977a79386993',                                   │ │
# │ │                    │   │   │   │   'hash_input_tokens':                  │ │
# │ │                    '911e36df50b000e2',                                   │ │
# │ │                    │   │   │   │   'hash_cont_tokens':                   │ │
# │ │                    'bb3ae17ffc27f96d'                                    │ │
# │ │                    │   │   │   },                                        │ │
# │ │                    │   │   │   truncated=0,                              │ │
# │ │                    │   │   │   non_truncated=235,                        │ │
# │ │                    │   │   │   padded=910,                               │ │
# │ │                    │   │   │   non_padded=30,                            │ │
# │ │                    │   │   │   effective_few_shots=0.0,                  │ │
# │ │                    │   │   │   num_truncated_few_shots=0                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'summary_general': {                              │ │
# │ │                    │   │   'hashes': {                                   │ │
# │ │                    │   │   │   'hash_examples': 'bb7fd366ab0a193d',      │ │
# │ │                    │   │   │   'hash_full_prompts': 'bb7fd366ab0a193d',  │ │
# │ │                    │   │   │   'hash_input_tokens': '064b649804833afa',  │ │
# │ │                    │   │   │   'hash_cont_tokens': '819d5b6dcaeadda2'    │ │
# │ │                    │   │   },                                            │ │
# │ │                    │   │   'truncated': 0,                               │ │
# │ │                    │   │   'non_truncated': 235,                         │ │
# │ │                    │   │   'padded': 910,                                │ │
# │ │                    │   │   'non_padded': 30,                             │ │
# │ │                    │   │   'num_truncated_few_shots': 0                  │ │
# │ │                    │   }                                                 │ │
# │ │                    }                                                     │ │
# │ │             self = <lighteval.logging.evaluation_tracker.EvaluationTrac… │ │
# │ │                    object at 0x76d971357fd0>                             │ │
# │ │     task_details = [                                                     │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about conceptual phys'+86,   │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+6,                                              │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# │ │                    phys'+86,                                             │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-3.2791354656219482, False),             │ │
# │ │                    │   │   │   (-0.09136451035737991, True),             │ │
# │ │                    │   │   │   (-3.3306186199188232, False),             │ │
# │ │                    │   │   │   (-4.897858142852783, False)               │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +42                               │ │
# │ │                    │   │   │   ]                                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   cont_tokens=[[330], [389], [340], [422]],     │ │
# │ │                    │   │   truncated=[0, 0, 0, 0],                       │ │
# │ │                    │   │   padded=[10, 10, 10, 10],                      │ │
# │ │                    │   │   gold=[],                                      │ │
# │ │                    │   │   pred_logits=[],                               │ │
# │ │                    │   │   choices=[' A', ' B', ' C', ' D'],             │ │
# │ │                    │   │   gold_index=[1],                               │ │
# │ │                    │   │   metrics={'acc': 1},                           │ │
# │ │                    │   │   specifics=None                                │ │
# │ │                    │   ),                                                │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about conceptual phys'+158,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about conceptual      │ │
# ...
# │ │                      │   │   │   hf_filter=None,                         │ │
# │ │                      │   │   │   hf_avail_splits=(                       │ │
# │ │                      │   │   │   │   'auxiliary_train',                  │ │
# │ │                      │   │   │   │   'test',                             │ │
# │ │                      │   │   │   │   'validation',                       │ │
# │ │                      │   │   │   │   'dev'                               │ │
# │ │                      │   │   │   ),                                      │ │
# │ │                      │   │   │   trust_dataset=True,                     │ │
# │ │                      │   │   │   evaluation_splits=('test',),            │ │
# │ │                      │   │   │   few_shots_split='dev',                  │ │
# │ │                      │   │   │   few_shots_select='sequential',          │ │
# │ │                      │   │   │   generation_size=1,                      │ │
# │ │                      │   │   │   generation_grammar=None,                │ │
# │ │                      │   │   │   stop_sequence=('\n',),                  │ │
# │ │                      │   │   │   num_samples=None,                       │ │
# │ │                      │   │   │   suite=('leaderboard', 'mmlu'),          │ │
# │ │                      │   │   │   original_num_docs=235,                  │ │
# │ │                      │   │   │   effective_num_docs=235,                 │ │
# │ │                      │   │   │   must_remove_duplicate_docs=False,       │ │
# │ │                      │   │   │   version=0                               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   },                                              │ │
# │ │                      │   'summary_tasks': defaultdict(<class             │ │
# │ │                      'lighteval.logging.info_loggers.DetailsLogger.Comp… │ │
# │ │                      {                                                   │ │
# │ │                      │   │   'leaderboard|mmlu:conceptual_physics|0':    │ │
# │ │                      CompiledDetail(                                     │ │
# │ │                      │   │   │   hashes={                                │ │
# │ │                      │   │   │   │   'hash_examples':                    │ │
# │ │                      '8300977a79386993',                                 │ │
# │ │                      │   │   │   │   'hash_full_prompts':                │ │
# │ │                      '8300977a79386993',                                 │ │
# │ │                      │   │   │   │   'hash_input_tokens':                │ │
# │ │                      '911e36df50b000e2',                                 │ │
# │ │                      │   │   │   │   'hash_cont_tokens':                 │ │
# │ │                      'bb3ae17ffc27f96d'                                  │ │
# │ │                      │   │   │   },                                      │ │
# │ │                      │   │   │   truncated=0,                            │ │
# │ │                      │   │   │   non_truncated=235,                      │ │
# │ │                      │   │   │   padded=910,                             │ │
# │ │                      │   │   │   non_padded=30,                          │ │
# │ │                      │   │   │   effective_few_shots=0.0,                │ │
# │ │                      │   │   │   num_truncated_few_shots=0               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   }),                                             │ │
# │ │                      │   'summary_general': {                            │ │
# │ │                      │   │   'hashes': {                                 │ │
# │ │                      │   │   │   'hash_examples': 'bb7fd366ab0a193d',    │ │
# │ │                      │   │   │   'hash_full_prompts':                    │ │
# │ │                      'bb7fd366ab0a193d',                                 │ │
# │ │                      │   │   │   'hash_input_tokens':                    │ │
# │ │                      '064b649804833afa',                                 │ │
# │ │                      │   │   │   'hash_cont_tokens': '819d5b6dcaeadda2'  │ │
# │ │                      │   │   },                                          │ │
# │ │                      │   │   'truncated': 0,                             │ │
# │ │                      │   │   'non_truncated': 235,                       │ │
# │ │                      │   │   'padded': 910,                              │ │
# │ │                      │   │   'non_padded': 30,                           │ │
# │ │                      │   │   'num_truncated_few_shots': 0                │ │
# │ │                      │   }                                               │ │
# │ │                      }                                                   │ │
# │ │               self = <lighteval.logging.evaluation_tracker.EvaluationTr… │ │
# │ │                      object at 0x76d971357fd0>                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /spec.py:1589 in mkdirs                                                      │
# │                                                                              │
# │   1586 │                                                                     │
# │   1587 │   def mkdirs(self, path, exist_ok=False):                           │
# │   1588 │   │   """Alias of `AbstractFileSystem.makedirs`."""                 │
# │ ❱ 1589 │   │   return self.makedirs(path, exist_ok=exist_ok)                 │
# │   1590 │                                                                     │
# │   1591 │   def listdir(self, path, detail=True, **kwargs):                   │
# │   1592 │   │   """Alias of `AbstractFileSystem.ls`."""                       │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = PosixPath('/content/360M_output/results/akhilfau/Instruction… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x76d971356740>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /implementations/local.py:52 in makedirs                                     │
# │                                                                              │
# │    49 │                                                                      │
# │    50 │   def makedirs(self, path, exist_ok=False):                          │
# │    51 │   │   path = self._strip_protocol(path)                              │
# │ ❱  52 │   │   os.makedirs(path, exist_ok=exist_ok)                           │
# │    53 │                                                                      │
# │    54 │   def rmdir(self, path):                                             │
# │    55 │   │   path = self._strip_protocol(path)                              │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = '/content/360M_output/results/akhilfau/Instruction_fine_tune… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x76d971356740>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     head = '/content/360M_output/results/akhilfau'                       │ │
# │ │     mode = 511                                                           │ │
# │ │     name = '/content/360M_output/results/akhilfau/Instruction_fine_tune… │ │
# │ │     tail = 'Instruction_fine_tuned_on_camel_ai_physics'                  │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭────────────────────── locals ──────────────────────╮                       │
# │ │ exist_ok = True                                    │                       │
# │ │     head = '/content/360M_output/results'          │                       │
# │ │     mode = 511                                     │                       │
# │ │     name = '/content/360M_output/results/akhilfau' │                       │
# │ │     tail = 'akhilfau'                              │                       │
# │ ╰────────────────────────────────────────────────────╯                       │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────── locals ──────────────────╮                                │
# │ │ exist_ok = True                           │                                │
# │ │     head = '/content/360M_output'         │                                │
# │ │     mode = 511                            │                                │
# │ │     name = '/content/360M_output/results' │                                │
# │ │     tail = 'results'                      │                                │
# │ ╰───────────────────────────────────────────╯                                │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────── locals ──────────────╮                                        │
# │ │ exist_ok = True                   │                                        │
# │ │     head = '/content'             │                                        │
# │ │     mode = 511                    │                                        │
# │ │     name = '/content/360M_output' │                                        │
# │ │     tail = '360M_output'          │                                        │
# │ ╰───────────────────────────────────╯                                        │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:225 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    222 │   │   if tail == cdir:           # xxx/newdir/. exists if xxx/newdi │
# │    223 │   │   │   return                                                    │
# │    224 │   try:                                                              │
# │ ❱  225 │   │   mkdir(name, mode)                                             │
# │    226 │   except OSError:                                                   │
# │    227 │   │   # Cannot rely on checking for EEXIST, since the operating sys │
# │    228 │   │   # could give priority to other errors like EACCES or EROFS    │
# │                                                                              │
# │ ╭─────── locals ────────╮                                                    │
# │ │ exist_ok = True       │                                                    │
# │ │     head = '/'        │                                                    │
# │ │     mode = 511        │                                                    │
# │ │     name = '/content' │                                                    │
# │ │     tail = 'content'  │                                                    │
# │ ╰───────────────────────╯                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
#High School Physics

# %%
MODEL="HuggingFaceTB/SmolLM2-360M"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:high_school_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [2025-03-05 12:15:22,666] [    INFO]: PyTorch version 2.4.1 available. (config.py:54)
# [2025-03-05 12:15:24,705] [    INFO]: Test gather tensor (parallelism.py:133)
# [2025-03-05 12:15:24,778] [    INFO]: gathered_tensor tensor([0], device='cuda:0'), should be [0] (parallelism.py:136)
# [2025-03-05 12:15:24,779] [    INFO]: --- LOADING MODEL --- (pipeline.py:168)
# [2025-03-05 12:15:24,923] [    INFO]: Tokenizer truncation and padding size set to the left side. (transformers_model.py:539)
# [2025-03-05 12:15:25,173] [    INFO]: Setting model parallel to True since the number of local processes is 1 and the number of GPUs is 4 (transformers_model.py:402)
# [2025-03-05 12:15:25,173] [    INFO]: Model parallel was set to True, setting max memory per GPU to {0: 10169221120, 1: 15557066752, 2: 15557066752, 3: 15573843968} and device map to auto (transformers_model.py:417)
# [2025-03-05 12:15:25,700] [    INFO]: --- LOADING TASKS --- (pipeline.py:195)
# [2025-03-05 12:15:25,701] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:136)
# [2025-03-05 12:15:25,703] [    INFO]: lighteval/mmlu high_school_physics (lighteval_task.py:187)
# 0000.parquet: 100%|████████████████████████| 33.0k/33.0k [00:00<00:00, 95.4MB/s]
# 0000.parquet: 100%|████████████████████████| 7.96k/7.96k [00:00<00:00, 33.4MB/s]
# 0000.parquet: 100%|████████████████████████| 4.57k/4.57k [00:00<00:00, 25.8MB/s]
# Generating auxiliary_train split: 100%|█| 99842/99842 [00:00<00:00, 189401.43 ex
# Generating test split: 100%|████████| 151/151 [00:00<00:00, 66145.16 examples/s]
# Generating validation split: 100%|█████| 17/17 [00:00<00:00, 9093.63 examples/s]
# Generating dev split: 100%|██████████████| 5/5 [00:00<00:00, 2850.17 examples/s]
# [2025-03-05 12:15:27,786] [    INFO]: --- INIT SEEDS --- (pipeline.py:224)
# [2025-03-05 12:15:27,786] [    INFO]: --- RUNNING MODEL --- (pipeline.py:267)
# [2025-03-05 12:15:27,787] [    INFO]: Running RequestType.LOGLIKELIHOOD requests (pipeline.py:271)
# 0it [00:00, ?it/s]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:00<00:03,  2.47it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:01,  5.87it/s]
#  50%|██████████████████████                      | 5/10 [00:00<00:00,  7.84it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:00<00:00,  9.04it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:01<00:00,  8.62it/s]
# 1it [00:01,  1.16s/it]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:00, 20.19it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:00<00:00, 20.23it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 20.61it/s]
# 2it [00:01,  1.31it/s]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:00, 24.30it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:00<00:00, 24.39it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 24.91it/s]
# 3it [00:02,  1.67it/s]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:00, 25.66it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:00<00:00, 26.21it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 26.50it/s]
# 4it [00:02,  1.65it/s]
# [2025-03-05 12:15:30,401] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:299)
# [2025-03-05 12:15:30,407] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:342)
# [2025-03-05 12:15:30,407] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# |                 Task                 |Version|Metric|Value |   |Stderr|
# |--------------------------------------|------:|------|-----:|---|-----:|
# |all                                   |       |acc   |0.2185|±  |0.0337|
# |leaderboard:mmlu:high_school_physics:0|      0|acc   |0.2185|±  |0.0337|
#
# [2025-03-05 12:15:30,420] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:332)
# [2025-03-05 12:15:30,420] [    INFO]: Saving experiment tracker (evaluation_tracker.py:154)
# [2025-03-05 12:15:30,420] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/main_accelerate.py:207 in accelerate                                     │
# │                                                                              │
# │   204 │                                                                      │
# │   205 │   results = pipeline.get_results()                                   │
# │   206 │                                                                      │
# │ ❱ 207 │   pipeline.save_and_push_results()                                   │
# │   208 │                                                                      │
# │   209 │   return results                                                     │
# │   210                                                                        │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │               accelerator = <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x7ed38adc4610>                           │ │
# │ │                 cache_dir = None                                         │ │
# │ │              custom_tasks = None                                         │ │
# │ │ dataset_loading_processes = 1                                            │ │
# │ │                env_config = EnvConfig(cache_dir=None, token=None)        │ │
# │ │        evaluation_tracker = <lighteval.logging.evaluation_tracker.Evalu… │ │
# │ │                             object at 0x7ed388543fd0>                    │ │
# │ │                    job_id = 0                                            │ │
# │ │               max_samples = None                                         │ │
# │ │                model_args = 'pretrained=HuggingFaceTB/SmolLM2-360M'      │ │
# │ │           model_args_dict = {                                            │ │
# │ │                             │   'pretrained':                            │ │
# │ │                             'HuggingFaceTB/SmolLM2-360M',                │ │
# │ │                             │   'accelerator':                           │ │
# │ │                             <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x7ed38adc4610>,                          │ │
# │ │                             │   'use_chat_template': False,              │ │
# │ │                             │   'compile': False                         │ │
# │ │                             }                                            │ │
# │ │              model_config = TransformersModelConfig(                     │ │
# │ │                             │   pretrained='HuggingFaceTB/SmolLM2-360M', │ │
# │ │                             │                                            │ │
# │ │                             accelerator=<accelerate.accelerator.Acceler… │ │
# │ │                             object at 0x7ed38adc4610>,                   │ │
# │ │                             │   tokenizer=None,                          │ │
# │ │                             │                                            │ │
# │ │                             multichoice_continuations_start_space=None,  │ │
# │ │                             │   pairwise_tokenization=False,             │ │
# │ │                             │   subfolder=None,                          │ │
# │ │                             │   revision='main',                         │ │
# │ │                             │   batch_size=-1,                           │ │
# │ │                             │   max_gen_toks=256,                        │ │
# │ │                             │   max_length=None,                         │ │
# │ │                             │   add_special_tokens=True,                 │ │
# │ │                             │   model_parallel=True,                     │ │
# │ │                             │   dtype=None,                              │ │
# │ │                             │   device='cuda',                           │ │
# │ │                             │   quantization_config=None,                │ │
# │ │                             │   trust_remote_code=False,                 │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   compile=False,                           │ │
# │ │                             │                                            │ │
# │ │                             generation_parameters=GenerationParameters(  │ │
# │ │                             │   │   early_stopping=None,                 │ │
# │ │                             │   │   repetition_penalty=None,             │ │
# │ │                             │   │   frequency_penalty=None,              │ │
# │ │                             │   │   length_penalty=None,                 │ │
# │ │                             │   │   presence_penalty=None,               │ │
# │ │                             │   │   max_new_tokens=None,                 │ │
# │ │                             │   │   min_new_tokens=None,                 │ │
# │ │                             │   │   seed=None,                           │ │
# │ │                             │   │   stop_tokens=None,                    │ │
# │ │                             │   │   temperature=None,                    │ │
# │ │                             │   │   top_k=None,                          │ │
# │ │                             │   │   min_p=None,                          │ │
# │ │                             │   │   top_p=None,                          │ │
# │ │                             │   │   truncate_prompt=None                 │ │
# │ │                             │   ),                                       │ │
# │ │                             │   generation_config=None                   │ │
# │ │                             )                                            │ │
# │ │         num_fewshot_seeds = 1                                            │ │
# │ │                output_dir = '/content/360M_output'                       │ │
# │ │       override_batch_size = 16                                           │ │
# │ │                  pipeline = <lighteval.pipeline.Pipeline object at       │ │
# │ │                             0x7ed388542650>                              │ │
# │ │           pipeline_params = PipelineParameters(                          │ │
# │ │                             │                                            │ │
# │ │                             launcher_type=<ParallelismManager.ACCELERAT… │ │
# │ │                             1>,                                          │ │
# │ │                             │   env_config=EnvConfig(                    │ │
# │ │                             │   │   cache_dir=None,                      │ │
# │ │                             │   │   token=None                           │ │
# │ │                             │   ),                                       │ │
# │ │                             │   job_id=0,                                │ │
# │ │                             │   dataset_loading_processes=1,             │ │
# │ │                             │   nanotron_checkpoint_path=None,           │ │
# │ │                             │   custom_tasks_directory=None,             │ │
# │ │                             │   override_batch_size=16,                  │ │
# │ │                             │   num_fewshot_seeds=1,                     │ │
# │ │                             │   max_samples=None,                        │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   system_prompt=None                       │ │
# │ │                             )                                            │ │
# │ │                public_run = False                                        │ │
# │ │               push_to_hub = False                                        │ │
# │ │       push_to_tensorboard = False                                        │ │
# │ │                   results = {                                            │ │
# │ │                             │   'config_general': {                      │ │
# │ │                             │   │   'lighteval_sha': '?',                │ │
# │ │                             │   │   'num_fewshot_seeds': 1,              │ │
# │ │                             │   │   'override_batch_size': 16,           │ │
# │ │                             │   │   'max_samples': None,                 │ │
# │ │                             │   │   'job_id': 0,                         │ │
# │ │                             │   │   'start_time': 82064.856460626,       │ │
# │ │                             │   │   'end_time': 82070.559342544,         │ │
# │ │                             │   │   'total_evaluation_time_secondes':    │ │
# │ │                             '5.702881917997729',                         │ │
# │ │                             │   │   'model_name':                        │ │
# │ │                             'HuggingFaceTB/SmolLM2-360M',                │ │
# │ │                             │   │   'model_sha':                         │ │
# │ │                             'f8027fd0eaeea54caa13c31d31b9fdc459c38b49',  │ │
# │ │                             │   │   ... +3                               │ │
# │ │                             │   },                                       │ │
# │ │                             │   'results': {                             │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics:0':    │ │
# │ │                             defaultdict(<class 'float'>, {               │ │
# │ │                             │   │   │   'acc': 0.2185430463576159,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.033742355504256936                         │ │
# │ │                             │   │   }),                                  │ │
# │ │                             │   │   'all': {                             │ │
# │ │                             │   │   │   'acc': 0.2185430463576159,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.033742355504256936                         │ │
# │ │                             │   │   }                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'versions': {                            │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics:0': 0  │ │
# │ │                             │   },                                       │ │
# │ │                             │   'config_tasks': {                        │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics':      │ │
# │ │                             LightevalTaskConfig(                         │ │
# │ │                             │   │   │   name='mmlu:high_school_physics', │ │
# │ │                             │   │   │   prompt_function=<function        │ │
# │ │                             mmlu_harness at 0x7ed388f904c0>,             │ │
# │ │                             │   │   │   hf_repo='lighteval/mmlu',        │ │
# │ │                             │   │   │   hf_subset='high_school_physics', │ │
# │ │                             │   │   │   metric=(                         │ │
# │ │                             │   │   │   │   SampleLevelMetric(           │ │
# │ │                             │   │   │   │   │   metric_name='acc',       │ │
# │ │                             │   │   │   │   │   higher_is_better=True,   │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             category=<MetricCategory.MULTICHOICE: '8'>,  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             use_case=<MetricUseCase.ACCURACY: '1'>,      │ │
# │ │                             │   │   │   │   │   sample_level_fn=<bound   │ │
# │ │                             method LoglikelihoodAcc.compute of           │ │
# │ │                             <lighteval.metrics.metrics_sample.Loglikeli… │ │
# │ │                             object at 0x7ed38ad2c880>>,                  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             corpus_level_fn=<function mean at            │ │
# │ │                             0x7ed58360fa30>                              │ │
# │ │                             │   │   │   │   ),                           │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   hf_revision=None,                │ │
# │ │                             │   │   │   hf_filter=None,                  │ │
# │ │                             │   │   │   hf_avail_splits=(                │ │
# │ │                             │   │   │   │   'auxiliary_train',           │ │
# │ │                             │   │   │   │   'test',                      │ │
# │ │                             │   │   │   │   'validation',                │ │
# │ │                             │   │   │   │   'dev'                        │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   trust_dataset=True,              │ │
# │ │                             │   │   │   evaluation_splits=('test',),     │ │
# │ │                             │   │   │   few_shots_split='dev',           │ │
# │ │                             │   │   │   few_shots_select='sequential',   │ │
# │ │                             │   │   │   generation_size=1,               │ │
# │ │                             │   │   │   generation_grammar=None,         │ │
# │ │                             │   │   │   stop_sequence=('\n',),           │ │
# │ │                             │   │   │   num_samples=None,                │ │
# │ │                             │   │   │   suite=('leaderboard', 'mmlu'),   │ │
# │ │                             │   │   │   original_num_docs=151,           │ │
# │ │                             │   │   │   effective_num_docs=151,          │ │
# │ │                             │   │   │                                    │ │
# │ │                             must_remove_duplicate_docs=False,            │ │
# │ │                             │   │   │   version=0                        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_tasks': {                       │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics:0':    │ │
# │ │                             CompiledDetail(                              │ │
# │ │                             │   │   │   hashes={                         │ │
# │ │                             │   │   │   │   'hash_examples':             │ │
# │ │                             'dc3ce06378548565',                          │ │
# │ │                             │   │   │   │   'hash_full_prompts':         │ │
# │ │                             'dc3ce06378548565',                          │ │
# │ │                             │   │   │   │   'hash_input_tokens':         │ │
# │ │                             '03a5f24e9184538e',                          │ │
# │ │                             │   │   │   │   'hash_cont_tokens':          │ │
# │ │                             'c0574161c8cbdae1'                           │ │
# │ │                             │   │   │   },                               │ │
# │ │                             │   │   │   truncated=0,                     │ │
# │ │                             │   │   │   non_truncated=151,               │ │
# │ │                             │   │   │   padded=590,                      │ │
# │ │                             │   │   │   non_padded=14,                   │ │
# │ │                             │   │   │   effective_few_shots=0.0,         │ │
# │ │                             │   │   │   num_truncated_few_shots=0        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_general': {                     │ │
# │ │                             │   │   'hashes': {                          │ │
# │ │                             │   │   │   'hash_examples':                 │ │
# │ │                             'e8ff700bb0c49d9e',                          │ │
# │ │                             │   │   │   'hash_full_prompts':             │ │
# │ │                             'e8ff700bb0c49d9e',                          │ │
# │ │                             │   │   │   'hash_input_tokens':             │ │
# │ │                             'fa7ae3b841fd7c2b',                          │ │
# │ │                             │   │   │   'hash_cont_tokens':              │ │
# │ │                             'b70594ab0120390d'                           │ │
# │ │                             │   │   },                                   │ │
# │ │                             │   │   'truncated': 0,                      │ │
# │ │                             │   │   'non_truncated': 151,                │ │
# │ │                             │   │   'padded': 590,                       │ │
# │ │                             │   │   'non_padded': 14,                    │ │
# │ │                             │   │   'num_truncated_few_shots': 0         │ │
# │ │                             │   }                                        │ │
# │ │                             }                                            │ │
# │ │               results_org = None                                         │ │
# │ │              save_details = False                                        │ │
# │ │             system_prompt = None                                         │ │
# │ │                     tasks = 'leaderboard|mmlu:high_school_physics|0|0'   │ │
# │ │                     torch = <module 'torch' from                         │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ │         use_chat_template = False                                        │ │
# │ │                      yaml = <module 'yaml' from                          │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/pipeline.py:334 in save_and_push_results                                 │
# │                                                                              │
# │   331 │   def save_and_push_results(self):                                   │
# │   332 │   │   logger.info("--- SAVING AND PUSHING RESULTS ---")              │
# │   333 │   │   if self.is_main_process():                                     │
# │ ❱ 334 │   │   │   self.evaluation_tracker.save()                             │
# │   335 │                                                                      │
# │   336 │   def _init_final_dict(self):                                        │
# │   337 │   │   if self.is_main_process():                                     │
# │                                                                              │
# │ ╭─────────────────────────── locals ────────────────────────────╮            │
# │ │ self = <lighteval.pipeline.Pipeline object at 0x7ed388542650> │            │
# │ ╰───────────────────────────────────────────────────────────────╯            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/logging/evaluation_tracker.py:187 in save                                │
# │                                                                              │
# │   184 │   │   │   details_datasets[task_name] = dataset                      │
# │   185 │   │                                                                  │
# │   186 │   │   # We save results at every case                                │
# │ ❱ 187 │   │   self.save_results(date_id, results_dict)                       │
# │   188 │   │                                                                  │
# │   189 │   │   if self.should_save_details:                                   │
# │   190 │   │   │   self.save_details(date_id, details_datasets)               │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │     column_names = [                                                     │ │
# │ │                    │   'example',                                        │ │
# │ │                    │   'instruction',                                    │ │
# │ │                    │   'full_prompt',                                    │ │
# │ │                    │   'num_effective_few_shots',                        │ │
# │ │                    │   'num_asked_few_shots',                            │ │
# │ │                    │   'predictions',                                    │ │
# │ │                    │   'input_tokens',                                   │ │
# │ │                    │   'cont_tokens',                                    │ │
# │ │                    │   'truncated',                                      │ │
# │ │                    │   'padded',                                         │ │
# │ │                    │   ... +6                                            │ │
# │ │                    ]                                                     │ │
# │ │   config_general = {                                                     │ │
# │ │                    │   'lighteval_sha': '?',                             │ │
# │ │                    │   'num_fewshot_seeds': 1,                           │ │
# │ │                    │   'override_batch_size': 16,                        │ │
# │ │                    │   'max_samples': None,                              │ │
# │ │                    │   'job_id': 0,                                      │ │
# │ │                    │   'start_time': 82064.856460626,                    │ │
# │ │                    │   'end_time': 82070.559342544,                      │ │
# │ │                    │   'total_evaluation_time_secondes':                 │ │
# │ │                    '5.702881917997729',                                  │ │
# │ │                    │   'model_name': 'HuggingFaceTB/SmolLM2-360M',       │ │
# │ │                    │   'model_sha':                                      │ │
# │ │                    'f8027fd0eaeea54caa13c31d31b9fdc459c38b49',           │ │
# │ │                    │   ... +2                                            │ │
# │ │                    }                                                     │ │
# │ │          dataset = Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 151                                     │ │
# │ │                    })                                                    │ │
# │ │          date_id = '2025-03-05T12-15-30.420674'                          │ │
# │ │ details_datasets = {                                                     │ │
# │ │                    │   'leaderboard|mmlu:high_school_physics|0':         │ │
# │ │                    Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 151                                     │ │
# │ │                    })                                                    │ │
# │ │                    }                                                     │ │
# │ │     results_dict = {                                                     │ │
# │ │                    │   'config_general': {                               │ │
# │ │                    │   │   'lighteval_sha': '?',                         │ │
# │ │                    │   │   'num_fewshot_seeds': 1,                       │ │
# │ │                    │   │   'override_batch_size': 16,                    │ │
# │ │                    │   │   'max_samples': None,                          │ │
# │ │                    │   │   'job_id': 0,                                  │ │
# │ │                    │   │   'start_time': 82064.856460626,                │ │
# │ │                    │   │   'end_time': 82070.559342544,                  │ │
# │ │                    │   │   'total_evaluation_time_secondes':             │ │
# │ │                    '5.702881917997729',                                  │ │
# │ │                    │   │   'model_name': 'HuggingFaceTB/SmolLM2-360M',   │ │
# │ │                    │   │   'model_sha':                                  │ │
# │ │                    'f8027fd0eaeea54caa13c31d31b9fdc459c38b49',           │ │
# │ │                    │   │   ... +2                                        │ │
# │ │                    │   },                                                │ │
# │ │                    │   'results': defaultdict(<function                  │ │
# │ │                    MetricsLogger.<lambda>.<locals>.<lambda> at           │ │
# │ │                    0x7ed388545c60>, {                                    │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics|0':     │ │
# │ │                    defaultdict(<class 'float'>, {                        │ │
# │ │                    │   │   │   'acc': 0.2185430463576159,                │ │
# │ │                    │   │   │   'acc_stderr': 0.033742355504256936        │ │
# │ │                    │   │   }),                                           │ │
# │ │                    │   │   'all': {                                      │ │
# │ │                    │   │   │   'acc': 0.2185430463576159,                │ │
# │ │                    │   │   │   'acc_stderr': 0.033742355504256936        │ │
# │ │                    │   │   }                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'versions': {                                     │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics|0': 0   │ │
# │ │                    │   },                                                │ │
# │ │                    │   'config_tasks': {                                 │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics':       │ │
# │ │                    LightevalTaskConfig(                                  │ │
# │ │                    │   │   │   name='mmlu:high_school_physics',          │ │
# │ │                    │   │   │   prompt_function=<function mmlu_harness at │ │
# │ │                    0x7ed388f904c0>,                                      │ │
# │ │                    │   │   │   hf_repo='lighteval/mmlu',                 │ │
# │ │                    │   │   │   hf_subset='high_school_physics',          │ │
# │ │                    │   │   │   metric=(                                  │ │
# │ │                    │   │   │   │   SampleLevelMetric(                    │ │
# │ │                    │   │   │   │   │   metric_name='acc',                │ │
# │ │                    │   │   │   │   │   higher_is_better=True,            │ │
# │ │                    │   │   │   │   │                                     │ │
# │ │                    category=<MetricCategory.MULTICHOICE: '8'>,           │ │
# │ │                    │   │   │   │   │   use_case=<MetricUseCase.ACCURACY: │ │
# │ │                    '1'>,                                                 │ │
# │ │                    │   │   │   │   │   sample_level_fn=<bound method     │ │
# │ │                    LoglikelihoodAcc.compute of                           │ │
# │ │                    <lighteval.metrics.metrics_sample.LoglikelihoodAcc    │ │
# │ │                    object at 0x7ed38ad2c880>>,                           │ │
# │ │                    │   │   │   │   │   corpus_level_fn=<function mean at │ │
# │ │                    0x7ed58360fa30>                                       │ │
# │ │                    │   │   │   │   ),                                    │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   hf_revision=None,                         │ │
# │ │                    │   │   │   hf_filter=None,                           │ │
# │ │                    │   │   │   hf_avail_splits=(                         │ │
# │ │                    │   │   │   │   'auxiliary_train',                    │ │
# │ │                    │   │   │   │   'test',                               │ │
# │ │                    │   │   │   │   'validation',                         │ │
# │ │                    │   │   │   │   'dev'                                 │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   trust_dataset=True,                       │ │
# │ │                    │   │   │   evaluation_splits=('test',),              │ │
# │ │                    │   │   │   few_shots_split='dev',                    │ │
# │ │                    │   │   │   few_shots_select='sequential',            │ │
# │ │                    │   │   │   generation_size=1,                        │ │
# │ │                    │   │   │   generation_grammar=None,                  │ │
# │ │                    │   │   │   stop_sequence=('\n',),                    │ │
# │ │                    │   │   │   num_samples=None,                         │ │
# │ │                    │   │   │   suite=('leaderboard', 'mmlu'),            │ │
# │ │                    │   │   │   original_num_docs=151,                    │ │
# │ │                    │   │   │   effective_num_docs=151,                   │ │
# │ │                    │   │   │   must_remove_duplicate_docs=False,         │ │
# │ │                    │   │   │   version=0                                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   },                                                │ │
# │ │                    │   'summary_tasks': defaultdict(<class               │ │
# │ │                    'lighteval.logging.info_loggers.DetailsLogger.Compil… │ │
# │ │                    {                                                     │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics|0':     │ │
# │ │                    CompiledDetail(                                       │ │
# │ │                    │   │   │   hashes={                                  │ │
# │ │                    │   │   │   │   'hash_examples': 'dc3ce06378548565',  │ │
# │ │                    │   │   │   │   'hash_full_prompts':                  │ │
# │ │                    'dc3ce06378548565',                                   │ │
# │ │                    │   │   │   │   'hash_input_tokens':                  │ │
# │ │                    '03a5f24e9184538e',                                   │ │
# │ │                    │   │   │   │   'hash_cont_tokens':                   │ │
# │ │                    'c0574161c8cbdae1'                                    │ │
# │ │                    │   │   │   },                                        │ │
# │ │                    │   │   │   truncated=0,                              │ │
# │ │                    │   │   │   non_truncated=151,                        │ │
# │ │                    │   │   │   padded=590,                               │ │
# │ │                    │   │   │   non_padded=14,                            │ │
# │ │                    │   │   │   effective_few_shots=0.0,                  │ │
# │ │                    │   │   │   num_truncated_few_shots=0                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'summary_general': {                              │ │
# │ │                    │   │   'hashes': {                                   │ │
# │ │                    │   │   │   'hash_examples': 'e8ff700bb0c49d9e',      │ │
# │ │                    │   │   │   'hash_full_prompts': 'e8ff700bb0c49d9e',  │ │
# │ │                    │   │   │   'hash_input_tokens': 'fa7ae3b841fd7c2b',  │ │
# │ │                    │   │   │   'hash_cont_tokens': 'b70594ab0120390d'    │ │
# │ │                    │   │   },                                            │ │
# │ │                    │   │   'truncated': 0,                               │ │
# │ │                    │   │   'non_truncated': 151,                         │ │
# │ │                    │   │   'padded': 590,                                │ │
# │ │                    │   │   'non_padded': 14,                             │ │
# │ │                    │   │   'num_truncated_few_shots': 0                  │ │
# │ │                    │   }                                                 │ │
# │ │                    }                                                     │ │
# │ │             self = <lighteval.logging.evaluation_tracker.EvaluationTrac… │ │
# │ │                    object at 0x7ed388543fd0>                             │ │
# │ │     task_details = [                                                     │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about high school phy'+232,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+7,                                               │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+232,                                             │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-1.34375, True),                         │ │
# │ │                    │   │   │   (-1.71875, False),                        │ │
# │ │                    │   │   │   (-1.71875, False),                        │ │
# │ │                    │   │   │   (-1.71875, False)                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ]                                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   cont_tokens=[[330], [389], [340], [422]],     │ │
# │ │                    │   │   truncated=[0, 0, 0, 0],                       │ │
# │ │                    │   │   padded=[27, 27, 27, 27],                      │ │
# │ │                    │   │   gold=[],                                      │ │
# │ │                    │   │   pred_logits=[],                               │ │
# │ │                    │   │   choices=[' A', ' B', ' C', ' D'],             │ │
# │ │                    │   │   gold_index=[3],                               │ │
# │ │                    │   │   metrics={'acc': 0},                           │ │
# │ │                    │   │   specifics=None                                │ │
# │ │                    │   ),                                                │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about high school phy'+292,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+7,                                               │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+292,                                             │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-1.65625, False),                        │ │
# │ │                    │   │   │   (-1.65625, False),                        │ │
# │ │                    │   │   │   (-1.40625, True),                         │ │
# │ │                    │   │   │   (-1.53125, False)                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# ...
# │ │                      │   │   │   hf_filter=None,                         │ │
# │ │                      │   │   │   hf_avail_splits=(                       │ │
# │ │                      │   │   │   │   'auxiliary_train',                  │ │
# │ │                      │   │   │   │   'test',                             │ │
# │ │                      │   │   │   │   'validation',                       │ │
# │ │                      │   │   │   │   'dev'                               │ │
# │ │                      │   │   │   ),                                      │ │
# │ │                      │   │   │   trust_dataset=True,                     │ │
# │ │                      │   │   │   evaluation_splits=('test',),            │ │
# │ │                      │   │   │   few_shots_split='dev',                  │ │
# │ │                      │   │   │   few_shots_select='sequential',          │ │
# │ │                      │   │   │   generation_size=1,                      │ │
# │ │                      │   │   │   generation_grammar=None,                │ │
# │ │                      │   │   │   stop_sequence=('\n',),                  │ │
# │ │                      │   │   │   num_samples=None,                       │ │
# │ │                      │   │   │   suite=('leaderboard', 'mmlu'),          │ │
# │ │                      │   │   │   original_num_docs=151,                  │ │
# │ │                      │   │   │   effective_num_docs=151,                 │ │
# │ │                      │   │   │   must_remove_duplicate_docs=False,       │ │
# │ │                      │   │   │   version=0                               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   },                                              │ │
# │ │                      │   'summary_tasks': defaultdict(<class             │ │
# │ │                      'lighteval.logging.info_loggers.DetailsLogger.Comp… │ │
# │ │                      {                                                   │ │
# │ │                      │   │   'leaderboard|mmlu:high_school_physics|0':   │ │
# │ │                      CompiledDetail(                                     │ │
# │ │                      │   │   │   hashes={                                │ │
# │ │                      │   │   │   │   'hash_examples':                    │ │
# │ │                      'dc3ce06378548565',                                 │ │
# │ │                      │   │   │   │   'hash_full_prompts':                │ │
# │ │                      'dc3ce06378548565',                                 │ │
# │ │                      │   │   │   │   'hash_input_tokens':                │ │
# │ │                      '03a5f24e9184538e',                                 │ │
# │ │                      │   │   │   │   'hash_cont_tokens':                 │ │
# │ │                      'c0574161c8cbdae1'                                  │ │
# │ │                      │   │   │   },                                      │ │
# │ │                      │   │   │   truncated=0,                            │ │
# │ │                      │   │   │   non_truncated=151,                      │ │
# │ │                      │   │   │   padded=590,                             │ │
# │ │                      │   │   │   non_padded=14,                          │ │
# │ │                      │   │   │   effective_few_shots=0.0,                │ │
# │ │                      │   │   │   num_truncated_few_shots=0               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   }),                                             │ │
# │ │                      │   'summary_general': {                            │ │
# │ │                      │   │   'hashes': {                                 │ │
# │ │                      │   │   │   'hash_examples': 'e8ff700bb0c49d9e',    │ │
# │ │                      │   │   │   'hash_full_prompts':                    │ │
# │ │                      'e8ff700bb0c49d9e',                                 │ │
# │ │                      │   │   │   'hash_input_tokens':                    │ │
# │ │                      'fa7ae3b841fd7c2b',                                 │ │
# │ │                      │   │   │   'hash_cont_tokens': 'b70594ab0120390d'  │ │
# │ │                      │   │   },                                          │ │
# │ │                      │   │   'truncated': 0,                             │ │
# │ │                      │   │   'non_truncated': 151,                       │ │
# │ │                      │   │   'padded': 590,                              │ │
# │ │                      │   │   'non_padded': 14,                           │ │
# │ │                      │   │   'num_truncated_few_shots': 0                │ │
# │ │                      │   }                                               │ │
# │ │                      }                                                   │ │
# │ │               self = <lighteval.logging.evaluation_tracker.EvaluationTr… │ │
# │ │                      object at 0x7ed388543fd0>                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /spec.py:1589 in mkdirs                                                      │
# │                                                                              │
# │   1586 │                                                                     │
# │   1587 │   def mkdirs(self, path, exist_ok=False):                           │
# │   1588 │   │   """Alias of `AbstractFileSystem.makedirs`."""                 │
# │ ❱ 1589 │   │   return self.makedirs(path, exist_ok=exist_ok)                 │
# │   1590 │                                                                     │
# │   1591 │   def listdir(self, path, detail=True, **kwargs):                   │
# │   1592 │   │   """Alias of `AbstractFileSystem.ls`."""                       │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = PosixPath('/content/360M_output/results/HuggingFaceTB/SmolLM… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x7ed3885426e0>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /implementations/local.py:52 in makedirs                                     │
# │                                                                              │
# │    49 │                                                                      │
# │    50 │   def makedirs(self, path, exist_ok=False):                          │
# │    51 │   │   path = self._strip_protocol(path)                              │
# │ ❱  52 │   │   os.makedirs(path, exist_ok=exist_ok)                           │
# │    53 │                                                                      │
# │    54 │   def rmdir(self, path):                                             │
# │    55 │   │   path = self._strip_protocol(path)                              │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = '/content/360M_output/results/HuggingFaceTB/SmolLM2-360M'     │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x7ed3885426e0>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭─────────────────────────────── locals ───────────────────────────────╮     │
# │ │ exist_ok = True                                                      │     │
# │ │     head = '/content/360M_output/results/HuggingFaceTB'              │     │
# │ │     mode = 511                                                       │     │
# │ │     name = '/content/360M_output/results/HuggingFaceTB/SmolLM2-360M' │     │
# │ │     tail = 'SmolLM2-360M'                                            │     │
# │ ╰──────────────────────────────────────────────────────────────────────╯     │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭──────────────────────── locals ─────────────────────────╮                  │
# │ │ exist_ok = True                                         │                  │
# │ │     head = '/content/360M_output/results'               │                  │
# │ │     mode = 511                                          │                  │
# │ │     name = '/content/360M_output/results/HuggingFaceTB' │                  │
# │ │     tail = 'HuggingFaceTB'                              │                  │
# │ ╰─────────────────────────────────────────────────────────╯                  │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────── locals ──────────────────╮                                │
# │ │ exist_ok = True                           │                                │
# │ │     head = '/content/360M_output'         │                                │
# │ │     mode = 511                            │                                │
# │ │     name = '/content/360M_output/results' │                                │
# │ │     tail = 'results'                      │                                │
# │ ╰───────────────────────────────────────────╯                                │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────── locals ──────────────╮                                        │
# │ │ exist_ok = True                   │                                        │
# │ │     head = '/content'             │                                        │
# │ │     mode = 511                    │                                        │
# │ │     name = '/content/360M_output' │                                        │
# │ │     tail = '360M_output'          │                                        │
# │ ╰───────────────────────────────────╯                                        │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:225 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    222 │   │   if tail == cdir:           # xxx/newdir/. exists if xxx/newdi │
# │    223 │   │   │   return                                                    │
# │    224 │   try:                                                              │
# │ ❱  225 │   │   mkdir(name, mode)                                             │
# │    226 │   except OSError:                                                   │
# │    227 │   │   # Cannot rely on checking for EEXIST, since the operating sys │
# │    228 │   │   # could give priority to other errors like EACCES or EROFS    │
# │                                                                              │
# │ ╭─────── locals ────────╮                                                    │
# │ │ exist_ok = True       │                                                    │
# │ │     head = '/'        │                                                    │
# │ │     mode = 511        │                                                    │
# │ │     name = '/content' │                                                    │
# │ │     tail = 'content'  │                                                    │
# │ ╰───────────────────────╯                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
MODEL="akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel-ai-physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:high_school_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [2025-03-05 12:17:18,134] [    INFO]: PyTorch version 2.4.1 available. (config.py:54)
# [2025-03-05 12:17:20,121] [    INFO]: Test gather tensor (parallelism.py:133)
# [2025-03-05 12:17:20,195] [    INFO]: gathered_tensor tensor([0], device='cuda:0'), should be [0] (parallelism.py:136)
# [2025-03-05 12:17:20,195] [    INFO]: --- LOADING MODEL --- (pipeline.py:168)
# [2025-03-05 12:17:20,422] [    INFO]: Tokenizer truncation and padding size set to the left side. (transformers_model.py:539)
# [2025-03-05 12:17:20,668] [    INFO]: Setting model parallel to True since the number of local processes is 1 and the number of GPUs is 4 (transformers_model.py:402)
# [2025-03-05 12:17:20,668] [    INFO]: Model parallel was set to True, setting max memory per GPU to {0: 10169221120, 1: 15557066752, 2: 15557066752, 3: 15573843968} and device map to auto (transformers_model.py:417)
# [2025-03-05 12:17:21,804] [    INFO]: --- LOADING TASKS --- (pipeline.py:195)
# [2025-03-05 12:17:21,804] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:136)
# [2025-03-05 12:17:21,806] [    INFO]: lighteval/mmlu high_school_physics (lighteval_task.py:187)
# [2025-03-05 12:17:25,265] [    INFO]: --- INIT SEEDS --- (pipeline.py:224)
# [2025-03-05 12:17:25,265] [    INFO]: --- RUNNING MODEL --- (pipeline.py:267)
# [2025-03-05 12:17:25,265] [    INFO]: Running RequestType.LOGLIKELIHOOD requests (pipeline.py:271)
# 0it [00:00, ?it/s]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:00<00:03,  2.58it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:01,  5.93it/s]
#  50%|██████████████████████                      | 5/10 [00:00<00:00,  7.76it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:00<00:00,  8.83it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:01<00:00,  8.46it/s]
# 1it [00:01,  1.18s/it]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:00, 19.17it/s]
#  40%|█████████████████▌                          | 4/10 [00:00<00:00, 19.17it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:00<00:00, 19.23it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:00<00:00, 19.20it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 19.00it/s]
# 2it [00:01,  1.25it/s]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:00, 22.88it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:00<00:00, 23.10it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 23.37it/s]
# 3it [00:02,  1.59it/s]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:00, 22.83it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:00<00:00, 23.37it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 23.32it/s]
# 4it [00:02,  1.56it/s]
# [2025-03-05 12:17:28,024] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:299)
# [2025-03-05 12:17:28,030] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:342)
# [2025-03-05 12:17:28,030] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# |                 Task                 |Version|Metric|Value |   |Stderr|
# |--------------------------------------|------:|------|-----:|---|-----:|
# |all                                   |       |acc   |0.1854|±  |0.0317|
# |leaderboard:mmlu:high_school_physics:0|      0|acc   |0.1854|±  |0.0317|
#
# [2025-03-05 12:17:28,043] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:332)
# [2025-03-05 12:17:28,043] [    INFO]: Saving experiment tracker (evaluation_tracker.py:154)
# [2025-03-05 12:17:28,043] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/main_accelerate.py:207 in accelerate                                     │
# │                                                                              │
# │   204 │                                                                      │
# │   205 │   results = pipeline.get_results()                                   │
# │   206 │                                                                      │
# │ ❱ 207 │   pipeline.save_and_push_results()                                   │
# │   208 │                                                                      │
# │   209 │   return results                                                     │
# │   210                                                                        │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │               accelerator = <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x7b9a17dd4d90>                           │ │
# │ │                 cache_dir = None                                         │ │
# │ │              custom_tasks = None                                         │ │
# │ │ dataset_loading_processes = 1                                            │ │
# │ │                env_config = EnvConfig(cache_dir=None, token=None)        │ │
# │ │        evaluation_tracker = <lighteval.logging.evaluation_tracker.Evalu… │ │
# │ │                             object at 0x7b9a1555ffd0>                    │ │
# │ │                    job_id = 0                                            │ │
# │ │               max_samples = None                                         │ │
# │ │                model_args = 'pretrained=akhilfau/fine-tuned-smolLM2-360… │ │
# │ │           model_args_dict = {                                            │ │
# │ │                             │   'pretrained':                            │ │
# │ │                             'akhilfau/fine-tuned-smolLM2-360M-with-LoRA… │ │
# │ │                             │   'accelerator':                           │ │
# │ │                             <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x7b9a17dd4d90>,                          │ │
# │ │                             │   'use_chat_template': False,              │ │
# │ │                             │   'compile': False                         │ │
# │ │                             }                                            │ │
# │ │              model_config = TransformersModelConfig(                     │ │
# │ │                             │                                            │ │
# │ │                             pretrained='akhilfau/fine-tuned-smolLM2-360… │ │
# │ │                             │                                            │ │
# │ │                             accelerator=<accelerate.accelerator.Acceler… │ │
# │ │                             object at 0x7b9a17dd4d90>,                   │ │
# │ │                             │   tokenizer=None,                          │ │
# │ │                             │                                            │ │
# │ │                             multichoice_continuations_start_space=None,  │ │
# │ │                             │   pairwise_tokenization=False,             │ │
# │ │                             │   subfolder=None,                          │ │
# │ │                             │   revision='main',                         │ │
# │ │                             │   batch_size=-1,                           │ │
# │ │                             │   max_gen_toks=256,                        │ │
# │ │                             │   max_length=None,                         │ │
# │ │                             │   add_special_tokens=True,                 │ │
# │ │                             │   model_parallel=True,                     │ │
# │ │                             │   dtype=None,                              │ │
# │ │                             │   device='cuda',                           │ │
# │ │                             │   quantization_config=None,                │ │
# │ │                             │   trust_remote_code=False,                 │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   compile=False,                           │ │
# │ │                             │                                            │ │
# │ │                             generation_parameters=GenerationParameters(  │ │
# │ │                             │   │   early_stopping=None,                 │ │
# │ │                             │   │   repetition_penalty=None,             │ │
# │ │                             │   │   frequency_penalty=None,              │ │
# │ │                             │   │   length_penalty=None,                 │ │
# │ │                             │   │   presence_penalty=None,               │ │
# │ │                             │   │   max_new_tokens=None,                 │ │
# │ │                             │   │   min_new_tokens=None,                 │ │
# │ │                             │   │   seed=None,                           │ │
# │ │                             │   │   stop_tokens=None,                    │ │
# │ │                             │   │   temperature=None,                    │ │
# │ │                             │   │   top_k=None,                          │ │
# │ │                             │   │   min_p=None,                          │ │
# │ │                             │   │   top_p=None,                          │ │
# │ │                             │   │   truncate_prompt=None                 │ │
# │ │                             │   ),                                       │ │
# │ │                             │   generation_config=None                   │ │
# │ │                             )                                            │ │
# │ │         num_fewshot_seeds = 1                                            │ │
# │ │                output_dir = '/content/360M_output'                       │ │
# │ │       override_batch_size = 16                                           │ │
# │ │                  pipeline = <lighteval.pipeline.Pipeline object at       │ │
# │ │                             0x7b9a1555e740>                              │ │
# │ │           pipeline_params = PipelineParameters(                          │ │
# │ │                             │                                            │ │
# │ │                             launcher_type=<ParallelismManager.ACCELERAT… │ │
# │ │                             1>,                                          │ │
# │ │                             │   env_config=EnvConfig(                    │ │
# │ │                             │   │   cache_dir=None,                      │ │
# │ │                             │   │   token=None                           │ │
# │ │                             │   ),                                       │ │
# │ │                             │   job_id=0,                                │ │
# │ │                             │   dataset_loading_processes=1,             │ │
# │ │                             │   nanotron_checkpoint_path=None,           │ │
# │ │                             │   custom_tasks_directory=None,             │ │
# │ │                             │   override_batch_size=16,                  │ │
# │ │                             │   num_fewshot_seeds=1,                     │ │
# │ │                             │   max_samples=None,                        │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   system_prompt=None                       │ │
# │ │                             )                                            │ │
# │ │                public_run = False                                        │ │
# │ │               push_to_hub = False                                        │ │
# │ │       push_to_tensorboard = False                                        │ │
# │ │                   results = {                                            │ │
# │ │                             │   'config_general': {                      │ │
# │ │                             │   │   'lighteval_sha': '?',                │ │
# │ │                             │   │   'num_fewshot_seeds': 1,              │ │
# │ │                             │   │   'override_batch_size': 16,           │ │
# │ │                             │   │   'max_samples': None,                 │ │
# │ │                             │   │   'job_id': 0,                         │ │
# │ │                             │   │   'start_time': 82180.272322654,       │ │
# │ │                             │   │   'end_time': 82188.182252275,         │ │
# │ │                             │   │   'total_evaluation_time_secondes':    │ │
# │ │                             '7.909929621004267',                         │ │
# │ │                             │   │   'model_name':                        │ │
# │ │                             'akhilfau/fine-tuned-smolLM2-360M-with-LoRA… │ │
# │ │                             │   │   'model_sha':                         │ │
# │ │                             'dac3187866a397c41b9c0a8c26c74f374ab68174',  │ │
# │ │                             │   │   ... +3                               │ │
# │ │                             │   },                                       │ │
# │ │                             │   'results': {                             │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics:0':    │ │
# │ │                             defaultdict(<class 'float'>, {               │ │
# │ │                             │   │   │   'acc': 0.18543046357615894,      │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.03173284384294285                          │ │
# │ │                             │   │   }),                                  │ │
# │ │                             │   │   'all': {                             │ │
# │ │                             │   │   │   'acc': 0.18543046357615894,      │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.03173284384294285                          │ │
# │ │                             │   │   }                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'versions': {                            │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics:0': 0  │ │
# │ │                             │   },                                       │ │
# │ │                             │   'config_tasks': {                        │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics':      │ │
# │ │                             LightevalTaskConfig(                         │ │
# │ │                             │   │   │   name='mmlu:high_school_physics', │ │
# │ │                             │   │   │   prompt_function=<function        │ │
# │ │                             mmlu_harness at 0x7b9a15fa8550>,             │ │
# │ │                             │   │   │   hf_repo='lighteval/mmlu',        │ │
# │ │                             │   │   │   hf_subset='high_school_physics', │ │
# │ │                             │   │   │   metric=(                         │ │
# │ │                             │   │   │   │   SampleLevelMetric(           │ │
# │ │                             │   │   │   │   │   metric_name='acc',       │ │
# │ │                             │   │   │   │   │   higher_is_better=True,   │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             category=<MetricCategory.MULTICHOICE: '8'>,  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             use_case=<MetricUseCase.ACCURACY: '1'>,      │ │
# │ │                             │   │   │   │   │   sample_level_fn=<bound   │ │
# │ │                             method LoglikelihoodAcc.compute of           │ │
# │ │                             <lighteval.metrics.metrics_sample.Loglikeli… │ │
# │ │                             object at 0x7b9a17d40d00>>,                  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             corpus_level_fn=<function mean at            │ │
# │ │                             0x7b9c10c00370>                              │ │
# │ │                             │   │   │   │   ),                           │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   hf_revision=None,                │ │
# │ │                             │   │   │   hf_filter=None,                  │ │
# │ │                             │   │   │   hf_avail_splits=(                │ │
# │ │                             │   │   │   │   'auxiliary_train',           │ │
# │ │                             │   │   │   │   'test',                      │ │
# │ │                             │   │   │   │   'validation',                │ │
# │ │                             │   │   │   │   'dev'                        │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   trust_dataset=True,              │ │
# │ │                             │   │   │   evaluation_splits=('test',),     │ │
# │ │                             │   │   │   few_shots_split='dev',           │ │
# │ │                             │   │   │   few_shots_select='sequential',   │ │
# │ │                             │   │   │   generation_size=1,               │ │
# │ │                             │   │   │   generation_grammar=None,         │ │
# │ │                             │   │   │   stop_sequence=('\n',),           │ │
# │ │                             │   │   │   num_samples=None,                │ │
# │ │                             │   │   │   suite=('leaderboard', 'mmlu'),   │ │
# │ │                             │   │   │   original_num_docs=151,           │ │
# │ │                             │   │   │   effective_num_docs=151,          │ │
# │ │                             │   │   │                                    │ │
# │ │                             must_remove_duplicate_docs=False,            │ │
# │ │                             │   │   │   version=0                        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_tasks': {                       │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics:0':    │ │
# │ │                             CompiledDetail(                              │ │
# │ │                             │   │   │   hashes={                         │ │
# │ │                             │   │   │   │   'hash_examples':             │ │
# │ │                             'dc3ce06378548565',                          │ │
# │ │                             │   │   │   │   'hash_full_prompts':         │ │
# │ │                             'dc3ce06378548565',                          │ │
# │ │                             │   │   │   │   'hash_input_tokens':         │ │
# │ │                             '03a5f24e9184538e',                          │ │
# │ │                             │   │   │   │   'hash_cont_tokens':          │ │
# │ │                             'c0574161c8cbdae1'                           │ │
# │ │                             │   │   │   },                               │ │
# │ │                             │   │   │   truncated=0,                     │ │
# │ │                             │   │   │   non_truncated=151,               │ │
# │ │                             │   │   │   padded=590,                      │ │
# │ │                             │   │   │   non_padded=14,                   │ │
# │ │                             │   │   │   effective_few_shots=0.0,         │ │
# │ │                             │   │   │   num_truncated_few_shots=0        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_general': {                     │ │
# │ │                             │   │   'hashes': {                          │ │
# │ │                             │   │   │   'hash_examples':                 │ │
# │ │                             'e8ff700bb0c49d9e',                          │ │
# │ │                             │   │   │   'hash_full_prompts':             │ │
# │ │                             'e8ff700bb0c49d9e',                          │ │
# │ │                             │   │   │   'hash_input_tokens':             │ │
# │ │                             'fa7ae3b841fd7c2b',                          │ │
# │ │                             │   │   │   'hash_cont_tokens':              │ │
# │ │                             'b70594ab0120390d'                           │ │
# │ │                             │   │   },                                   │ │
# │ │                             │   │   'truncated': 0,                      │ │
# │ │                             │   │   'non_truncated': 151,                │ │
# │ │                             │   │   'padded': 590,                       │ │
# │ │                             │   │   'non_padded': 14,                    │ │
# │ │                             │   │   'num_truncated_few_shots': 0         │ │
# │ │                             │   }                                        │ │
# │ │                             }                                            │ │
# │ │               results_org = None                                         │ │
# │ │              save_details = False                                        │ │
# │ │             system_prompt = None                                         │ │
# │ │                     tasks = 'leaderboard|mmlu:high_school_physics|0|0'   │ │
# │ │                     torch = <module 'torch' from                         │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ │         use_chat_template = False                                        │ │
# │ │                      yaml = <module 'yaml' from                          │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/pipeline.py:334 in save_and_push_results                                 │
# │                                                                              │
# │   331 │   def save_and_push_results(self):                                   │
# │   332 │   │   logger.info("--- SAVING AND PUSHING RESULTS ---")              │
# │   333 │   │   if self.is_main_process():                                     │
# │ ❱ 334 │   │   │   self.evaluation_tracker.save()                             │
# │   335 │                                                                      │
# │   336 │   def _init_final_dict(self):                                        │
# │   337 │   │   if self.is_main_process():                                     │
# │                                                                              │
# │ ╭─────────────────────────── locals ────────────────────────────╮            │
# │ │ self = <lighteval.pipeline.Pipeline object at 0x7b9a1555e740> │            │
# │ ╰───────────────────────────────────────────────────────────────╯            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/logging/evaluation_tracker.py:187 in save                                │
# │                                                                              │
# │   184 │   │   │   details_datasets[task_name] = dataset                      │
# │   185 │   │                                                                  │
# │   186 │   │   # We save results at every case                                │
# │ ❱ 187 │   │   self.save_results(date_id, results_dict)                       │
# │   188 │   │                                                                  │
# │   189 │   │   if self.should_save_details:                                   │
# │   190 │   │   │   self.save_details(date_id, details_datasets)               │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │     column_names = [                                                     │ │
# │ │                    │   'example',                                        │ │
# │ │                    │   'instruction',                                    │ │
# │ │                    │   'full_prompt',                                    │ │
# │ │                    │   'num_effective_few_shots',                        │ │
# │ │                    │   'num_asked_few_shots',                            │ │
# │ │                    │   'predictions',                                    │ │
# │ │                    │   'input_tokens',                                   │ │
# │ │                    │   'cont_tokens',                                    │ │
# │ │                    │   'truncated',                                      │ │
# │ │                    │   'padded',                                         │ │
# │ │                    │   ... +6                                            │ │
# │ │                    ]                                                     │ │
# │ │   config_general = {                                                     │ │
# │ │                    │   'lighteval_sha': '?',                             │ │
# │ │                    │   'num_fewshot_seeds': 1,                           │ │
# │ │                    │   'override_batch_size': 16,                        │ │
# │ │                    │   'max_samples': None,                              │ │
# │ │                    │   'job_id': 0,                                      │ │
# │ │                    │   'start_time': 82180.272322654,                    │ │
# │ │                    │   'end_time': 82188.182252275,                      │ │
# │ │                    │   'total_evaluation_time_secondes':                 │ │
# │ │                    '7.909929621004267',                                  │ │
# │ │                    │   'model_name':                                     │ │
# │ │                    'akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel… │ │
# │ │                    │   'model_sha':                                      │ │
# │ │                    'dac3187866a397c41b9c0a8c26c74f374ab68174',           │ │
# │ │                    │   ... +2                                            │ │
# │ │                    }                                                     │ │
# │ │          dataset = Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 151                                     │ │
# │ │                    })                                                    │ │
# │ │          date_id = '2025-03-05T12-17-28.043607'                          │ │
# │ │ details_datasets = {                                                     │ │
# │ │                    │   'leaderboard|mmlu:high_school_physics|0':         │ │
# │ │                    Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 151                                     │ │
# │ │                    })                                                    │ │
# │ │                    }                                                     │ │
# │ │     results_dict = {                                                     │ │
# │ │                    │   'config_general': {                               │ │
# │ │                    │   │   'lighteval_sha': '?',                         │ │
# │ │                    │   │   'num_fewshot_seeds': 1,                       │ │
# │ │                    │   │   'override_batch_size': 16,                    │ │
# │ │                    │   │   'max_samples': None,                          │ │
# │ │                    │   │   'job_id': 0,                                  │ │
# │ │                    │   │   'start_time': 82180.272322654,                │ │
# │ │                    │   │   'end_time': 82188.182252275,                  │ │
# │ │                    │   │   'total_evaluation_time_secondes':             │ │
# │ │                    '7.909929621004267',                                  │ │
# │ │                    │   │   'model_name':                                 │ │
# │ │                    'akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel… │ │
# │ │                    │   │   'model_sha':                                  │ │
# │ │                    'dac3187866a397c41b9c0a8c26c74f374ab68174',           │ │
# │ │                    │   │   ... +2                                        │ │
# │ │                    │   },                                                │ │
# │ │                    │   'results': defaultdict(<function                  │ │
# │ │                    MetricsLogger.<lambda>.<locals>.<lambda> at           │ │
# │ │                    0x7b9a15561cf0>, {                                    │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics|0':     │ │
# │ │                    defaultdict(<class 'float'>, {                        │ │
# │ │                    │   │   │   'acc': 0.18543046357615894,               │ │
# │ │                    │   │   │   'acc_stderr': 0.03173284384294285         │ │
# │ │                    │   │   }),                                           │ │
# │ │                    │   │   'all': {                                      │ │
# │ │                    │   │   │   'acc': 0.18543046357615894,               │ │
# │ │                    │   │   │   'acc_stderr': 0.03173284384294285         │ │
# │ │                    │   │   }                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'versions': {                                     │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics|0': 0   │ │
# │ │                    │   },                                                │ │
# │ │                    │   'config_tasks': {                                 │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics':       │ │
# │ │                    LightevalTaskConfig(                                  │ │
# │ │                    │   │   │   name='mmlu:high_school_physics',          │ │
# │ │                    │   │   │   prompt_function=<function mmlu_harness at │ │
# │ │                    0x7b9a15fa8550>,                                      │ │
# │ │                    │   │   │   hf_repo='lighteval/mmlu',                 │ │
# │ │                    │   │   │   hf_subset='high_school_physics',          │ │
# │ │                    │   │   │   metric=(                                  │ │
# │ │                    │   │   │   │   SampleLevelMetric(                    │ │
# │ │                    │   │   │   │   │   metric_name='acc',                │ │
# │ │                    │   │   │   │   │   higher_is_better=True,            │ │
# │ │                    │   │   │   │   │                                     │ │
# │ │                    category=<MetricCategory.MULTICHOICE: '8'>,           │ │
# │ │                    │   │   │   │   │   use_case=<MetricUseCase.ACCURACY: │ │
# │ │                    '1'>,                                                 │ │
# │ │                    │   │   │   │   │   sample_level_fn=<bound method     │ │
# │ │                    LoglikelihoodAcc.compute of                           │ │
# │ │                    <lighteval.metrics.metrics_sample.LoglikelihoodAcc    │ │
# │ │                    object at 0x7b9a17d40d00>>,                           │ │
# │ │                    │   │   │   │   │   corpus_level_fn=<function mean at │ │
# │ │                    0x7b9c10c00370>                                       │ │
# │ │                    │   │   │   │   ),                                    │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   hf_revision=None,                         │ │
# │ │                    │   │   │   hf_filter=None,                           │ │
# │ │                    │   │   │   hf_avail_splits=(                         │ │
# │ │                    │   │   │   │   'auxiliary_train',                    │ │
# │ │                    │   │   │   │   'test',                               │ │
# │ │                    │   │   │   │   'validation',                         │ │
# │ │                    │   │   │   │   'dev'                                 │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   trust_dataset=True,                       │ │
# │ │                    │   │   │   evaluation_splits=('test',),              │ │
# │ │                    │   │   │   few_shots_split='dev',                    │ │
# │ │                    │   │   │   few_shots_select='sequential',            │ │
# │ │                    │   │   │   generation_size=1,                        │ │
# │ │                    │   │   │   generation_grammar=None,                  │ │
# │ │                    │   │   │   stop_sequence=('\n',),                    │ │
# │ │                    │   │   │   num_samples=None,                         │ │
# │ │                    │   │   │   suite=('leaderboard', 'mmlu'),            │ │
# │ │                    │   │   │   original_num_docs=151,                    │ │
# │ │                    │   │   │   effective_num_docs=151,                   │ │
# │ │                    │   │   │   must_remove_duplicate_docs=False,         │ │
# │ │                    │   │   │   version=0                                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   },                                                │ │
# │ │                    │   'summary_tasks': defaultdict(<class               │ │
# │ │                    'lighteval.logging.info_loggers.DetailsLogger.Compil… │ │
# │ │                    {                                                     │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics|0':     │ │
# │ │                    CompiledDetail(                                       │ │
# │ │                    │   │   │   hashes={                                  │ │
# │ │                    │   │   │   │   'hash_examples': 'dc3ce06378548565',  │ │
# │ │                    │   │   │   │   'hash_full_prompts':                  │ │
# │ │                    'dc3ce06378548565',                                   │ │
# │ │                    │   │   │   │   'hash_input_tokens':                  │ │
# │ │                    '03a5f24e9184538e',                                   │ │
# │ │                    │   │   │   │   'hash_cont_tokens':                   │ │
# │ │                    'c0574161c8cbdae1'                                    │ │
# │ │                    │   │   │   },                                        │ │
# │ │                    │   │   │   truncated=0,                              │ │
# │ │                    │   │   │   non_truncated=151,                        │ │
# │ │                    │   │   │   padded=590,                               │ │
# │ │                    │   │   │   non_padded=14,                            │ │
# │ │                    │   │   │   effective_few_shots=0.0,                  │ │
# │ │                    │   │   │   num_truncated_few_shots=0                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'summary_general': {                              │ │
# │ │                    │   │   'hashes': {                                   │ │
# │ │                    │   │   │   'hash_examples': 'e8ff700bb0c49d9e',      │ │
# │ │                    │   │   │   'hash_full_prompts': 'e8ff700bb0c49d9e',  │ │
# │ │                    │   │   │   'hash_input_tokens': 'fa7ae3b841fd7c2b',  │ │
# │ │                    │   │   │   'hash_cont_tokens': 'b70594ab0120390d'    │ │
# │ │                    │   │   },                                            │ │
# │ │                    │   │   'truncated': 0,                               │ │
# │ │                    │   │   'non_truncated': 151,                         │ │
# │ │                    │   │   'padded': 590,                                │ │
# │ │                    │   │   'non_padded': 14,                             │ │
# │ │                    │   │   'num_truncated_few_shots': 0                  │ │
# │ │                    │   }                                                 │ │
# │ │                    }                                                     │ │
# │ │             self = <lighteval.logging.evaluation_tracker.EvaluationTrac… │ │
# │ │                    object at 0x7b9a1555ffd0>                             │ │
# │ │     task_details = [                                                     │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about high school phy'+232,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+7,                                               │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+232,                                             │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-0.95703125, True),                      │ │
# │ │                    │   │   │   (-1.828125, False),                       │ │
# │ │                    │   │   │   (-1.703125, False),                       │ │
# │ │                    │   │   │   (-1.703125, False)                        │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ]                                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   cont_tokens=[[330], [389], [340], [422]],     │ │
# │ │                    │   │   truncated=[0, 0, 0, 0],                       │ │
# │ │                    │   │   padded=[27, 27, 27, 27],                      │ │
# │ │                    │   │   gold=[],                                      │ │
# │ │                    │   │   pred_logits=[],                               │ │
# │ │                    │   │   choices=[' A', ' B', ' C', ' D'],             │ │
# │ │                    │   │   gold_index=[3],                               │ │
# │ │                    │   │   metrics={'acc': 0},                           │ │
# │ │                    │   │   specifics=None                                │ │
# │ │                    │   ),                                                │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about high school phy'+292,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+7,                                               │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+292,                                             │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-1.1640625, True),                       │ │
# │ │                    │   │   │   (-1.7890625, False),                      │ │
# │ │                    │   │   │   (-1.4140625, False),                      │ │
# │ │                    │   │   │   (-1.7890625, False)                       │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# ...
# │ │                      │   │   │   hf_filter=None,                         │ │
# │ │                      │   │   │   hf_avail_splits=(                       │ │
# │ │                      │   │   │   │   'auxiliary_train',                  │ │
# │ │                      │   │   │   │   'test',                             │ │
# │ │                      │   │   │   │   'validation',                       │ │
# │ │                      │   │   │   │   'dev'                               │ │
# │ │                      │   │   │   ),                                      │ │
# │ │                      │   │   │   trust_dataset=True,                     │ │
# │ │                      │   │   │   evaluation_splits=('test',),            │ │
# │ │                      │   │   │   few_shots_split='dev',                  │ │
# │ │                      │   │   │   few_shots_select='sequential',          │ │
# │ │                      │   │   │   generation_size=1,                      │ │
# │ │                      │   │   │   generation_grammar=None,                │ │
# │ │                      │   │   │   stop_sequence=('\n',),                  │ │
# │ │                      │   │   │   num_samples=None,                       │ │
# │ │                      │   │   │   suite=('leaderboard', 'mmlu'),          │ │
# │ │                      │   │   │   original_num_docs=151,                  │ │
# │ │                      │   │   │   effective_num_docs=151,                 │ │
# │ │                      │   │   │   must_remove_duplicate_docs=False,       │ │
# │ │                      │   │   │   version=0                               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   },                                              │ │
# │ │                      │   'summary_tasks': defaultdict(<class             │ │
# │ │                      'lighteval.logging.info_loggers.DetailsLogger.Comp… │ │
# │ │                      {                                                   │ │
# │ │                      │   │   'leaderboard|mmlu:high_school_physics|0':   │ │
# │ │                      CompiledDetail(                                     │ │
# │ │                      │   │   │   hashes={                                │ │
# │ │                      │   │   │   │   'hash_examples':                    │ │
# │ │                      'dc3ce06378548565',                                 │ │
# │ │                      │   │   │   │   'hash_full_prompts':                │ │
# │ │                      'dc3ce06378548565',                                 │ │
# │ │                      │   │   │   │   'hash_input_tokens':                │ │
# │ │                      '03a5f24e9184538e',                                 │ │
# │ │                      │   │   │   │   'hash_cont_tokens':                 │ │
# │ │                      'c0574161c8cbdae1'                                  │ │
# │ │                      │   │   │   },                                      │ │
# │ │                      │   │   │   truncated=0,                            │ │
# │ │                      │   │   │   non_truncated=151,                      │ │
# │ │                      │   │   │   padded=590,                             │ │
# │ │                      │   │   │   non_padded=14,                          │ │
# │ │                      │   │   │   effective_few_shots=0.0,                │ │
# │ │                      │   │   │   num_truncated_few_shots=0               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   }),                                             │ │
# │ │                      │   'summary_general': {                            │ │
# │ │                      │   │   'hashes': {                                 │ │
# │ │                      │   │   │   'hash_examples': 'e8ff700bb0c49d9e',    │ │
# │ │                      │   │   │   'hash_full_prompts':                    │ │
# │ │                      'e8ff700bb0c49d9e',                                 │ │
# │ │                      │   │   │   'hash_input_tokens':                    │ │
# │ │                      'fa7ae3b841fd7c2b',                                 │ │
# │ │                      │   │   │   'hash_cont_tokens': 'b70594ab0120390d'  │ │
# │ │                      │   │   },                                          │ │
# │ │                      │   │   'truncated': 0,                             │ │
# │ │                      │   │   'non_truncated': 151,                       │ │
# │ │                      │   │   'padded': 590,                              │ │
# │ │                      │   │   'non_padded': 14,                           │ │
# │ │                      │   │   'num_truncated_few_shots': 0                │ │
# │ │                      │   }                                               │ │
# │ │                      }                                                   │ │
# │ │               self = <lighteval.logging.evaluation_tracker.EvaluationTr… │ │
# │ │                      object at 0x7b9a1555ffd0>                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /spec.py:1589 in mkdirs                                                      │
# │                                                                              │
# │   1586 │                                                                     │
# │   1587 │   def mkdirs(self, path, exist_ok=False):                           │
# │   1588 │   │   """Alias of `AbstractFileSystem.makedirs`."""                 │
# │ ❱ 1589 │   │   return self.makedirs(path, exist_ok=exist_ok)                 │
# │   1590 │                                                                     │
# │   1591 │   def listdir(self, path, detail=True, **kwargs):                   │
# │   1592 │   │   """Alias of `AbstractFileSystem.ls`."""                       │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = PosixPath('/content/360M_output/results/akhilfau/fine-tuned-… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x7b9a1555e7d0>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /implementations/local.py:52 in makedirs                                     │
# │                                                                              │
# │    49 │                                                                      │
# │    50 │   def makedirs(self, path, exist_ok=False):                          │
# │    51 │   │   path = self._strip_protocol(path)                              │
# │ ❱  52 │   │   os.makedirs(path, exist_ok=exist_ok)                           │
# │    53 │                                                                      │
# │    54 │   def rmdir(self, path):                                             │
# │    55 │   │   path = self._strip_protocol(path)                              │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = '/content/360M_output/results/akhilfau/fine-tuned-smolLM2-36… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x7b9a1555e7d0>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     head = '/content/360M_output/results/akhilfau'                       │ │
# │ │     mode = 511                                                           │ │
# │ │     name = '/content/360M_output/results/akhilfau/fine-tuned-smolLM2-36… │ │
# │ │     tail = 'fine-tuned-smolLM2-360M-with-LoRA-on-camel-ai-physics'       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭────────────────────── locals ──────────────────────╮                       │
# │ │ exist_ok = True                                    │                       │
# │ │     head = '/content/360M_output/results'          │                       │
# │ │     mode = 511                                     │                       │
# │ │     name = '/content/360M_output/results/akhilfau' │                       │
# │ │     tail = 'akhilfau'                              │                       │
# │ ╰────────────────────────────────────────────────────╯                       │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────── locals ──────────────────╮                                │
# │ │ exist_ok = True                           │                                │
# │ │     head = '/content/360M_output'         │                                │
# │ │     mode = 511                            │                                │
# │ │     name = '/content/360M_output/results' │                                │
# │ │     tail = 'results'                      │                                │
# │ ╰───────────────────────────────────────────╯                                │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────── locals ──────────────╮                                        │
# │ │ exist_ok = True                   │                                        │
# │ │     head = '/content'             │                                        │
# │ │     mode = 511                    │                                        │
# │ │     name = '/content/360M_output' │                                        │
# │ │     tail = '360M_output'          │                                        │
# │ ╰───────────────────────────────────╯                                        │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:225 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    222 │   │   if tail == cdir:           # xxx/newdir/. exists if xxx/newdi │
# │    223 │   │   │   return                                                    │
# │    224 │   try:                                                              │
# │ ❱  225 │   │   mkdir(name, mode)                                             │
# │    226 │   except OSError:                                                   │
# │    227 │   │   # Cannot rely on checking for EEXIST, since the operating sys │
# │    228 │   │   # could give priority to other errors like EACCES or EROFS    │
# │                                                                              │
# │ ╭─────── locals ────────╮                                                    │
# │ │ exist_ok = True       │                                                    │
# │ │     head = '/'        │                                                    │
# │ │     mode = 511        │                                                    │
# │ │     name = '/content' │                                                    │
# │ │     tail = 'content'  │                                                    │
# │ ╰───────────────────────╯                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
MODEL="akhilfau/Instruction_fine_tuned_on_camel_ai_physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:high_school_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [2025-03-05 12:18:58,686] [    INFO]: PyTorch version 2.4.1 available. (config.py:54)
# [2025-03-05 12:19:01,387] [    INFO]: Test gather tensor (parallelism.py:133)
# [2025-03-05 12:19:01,461] [    INFO]: gathered_tensor tensor([0], device='cuda:0'), should be [0] (parallelism.py:136)
# [2025-03-05 12:19:01,461] [    INFO]: --- LOADING MODEL --- (pipeline.py:168)
# [2025-03-05 12:19:01,764] [    INFO]: Tokenizer truncation and padding size set to the left side. (transformers_model.py:539)
# [2025-03-05 12:19:02,015] [    INFO]: Setting model parallel to True since the number of local processes is 1 and the number of GPUs is 4 (transformers_model.py:402)
# [2025-03-05 12:19:02,016] [    INFO]: Model parallel was set to True, setting max memory per GPU to {0: 10169221120, 1: 15557066752, 2: 15557066752, 3: 15573843968} and device map to auto (transformers_model.py:417)
# [2025-03-05 12:19:02,657] [    INFO]: --- LOADING TASKS --- (pipeline.py:195)
# [2025-03-05 12:19:02,657] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:136)
# [2025-03-05 12:19:02,659] [    INFO]: lighteval/mmlu high_school_physics (lighteval_task.py:187)
# [2025-03-05 12:19:03,560] [    INFO]: --- INIT SEEDS --- (pipeline.py:224)
# [2025-03-05 12:19:03,560] [    INFO]: --- RUNNING MODEL --- (pipeline.py:267)
# [2025-03-05 12:19:03,560] [    INFO]: Running RequestType.LOGLIKELIHOOD requests (pipeline.py:271)
# 0it [00:00, ?it/s]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:00<00:04,  1.89it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:03,  2.56it/s]
#  30%|█████████████▏                              | 3/10 [00:01<00:02,  2.87it/s]
#  40%|█████████████████▌                          | 4/10 [00:01<00:01,  3.04it/s]
#  50%|██████████████████████                      | 5/10 [00:01<00:01,  3.16it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:02<00:01,  3.23it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:02<00:00,  3.28it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:02<00:00,  3.30it/s]
#  90%|███████████████████████████████████████▌    | 9/10 [00:02<00:00,  3.31it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  3.29it/s]
# 1it [00:03,  3.04s/it]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:00<00:01,  6.91it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:01,  6.92it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:01,  6.91it/s]
#  40%|█████████████████▌                          | 4/10 [00:00<00:00,  6.91it/s]
#  50%|██████████████████████                      | 5/10 [00:00<00:00,  6.90it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:00<00:00,  6.90it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:01<00:00,  6.90it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:01<00:00,  6.90it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:01<00:00,  7.29it/s]
# 2it [00:04,  2.06s/it]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:00<00:01,  8.58it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:00,  8.60it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:00,  8.61it/s]
#  40%|█████████████████▌                          | 4/10 [00:00<00:00,  8.62it/s]
#  50%|██████████████████████                      | 5/10 [00:00<00:00,  8.63it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:00<00:00,  8.62it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:00<00:00,  8.62it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:00<00:00,  8.63it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:01<00:00,  9.09it/s]
# 3it [00:05,  1.62s/it]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:00<00:00,  9.88it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:00,  9.90it/s]
#  30%|█████████████▏                              | 3/10 [00:00<00:00,  9.87it/s]
#  40%|█████████████████▌                          | 4/10 [00:00<00:00,  9.87it/s]
#  50%|██████████████████████                      | 5/10 [00:00<00:00,  9.89it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:00<00:00,  9.91it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:00<00:00,  9.90it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:00<00:00,  9.88it/s]
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 10.40it/s]
# 4it [00:06,  1.62s/it]
# [2025-03-05 12:19:10,227] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:299)
# [2025-03-05 12:19:10,234] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:342)
# [2025-03-05 12:19:10,234] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# |                 Task                 |Version|Metric|Value |   |Stderr|
# |--------------------------------------|------:|------|-----:|---|-----:|
# |all                                   |       |acc   |0.2583|±  |0.0357|
# |leaderboard:mmlu:high_school_physics:0|      0|acc   |0.2583|±  |0.0357|
#
# [2025-03-05 12:19:10,246] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:332)
# [2025-03-05 12:19:10,246] [    INFO]: Saving experiment tracker (evaluation_tracker.py:154)
# [2025-03-05 12:19:10,246] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/main_accelerate.py:207 in accelerate                                     │
# │                                                                              │
# │   204 │                                                                      │
# │   205 │   results = pipeline.get_results()                                   │
# │   206 │                                                                      │
# │ ❱ 207 │   pipeline.save_and_push_results()                                   │
# │   208 │                                                                      │
# │   209 │   return results                                                     │
# │   210                                                                        │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │               accelerator = <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x72c314dcf1c0>                           │ │
# │ │                 cache_dir = None                                         │ │
# │ │              custom_tasks = None                                         │ │
# │ │ dataset_loading_processes = 1                                            │ │
# │ │                env_config = EnvConfig(cache_dir=None, token=None)        │ │
# │ │        evaluation_tracker = <lighteval.logging.evaluation_tracker.Evalu… │ │
# │ │                             object at 0x72c31254beb0>                    │ │
# │ │                    job_id = 0                                            │ │
# │ │               max_samples = None                                         │ │
# │ │                model_args = 'pretrained=akhilfau/Instruction_fine_tuned… │ │
# │ │           model_args_dict = {                                            │ │
# │ │                             │   'pretrained':                            │ │
# │ │                             'akhilfau/Instruction_fine_tuned_on_camel_a… │ │
# │ │                             │   'accelerator':                           │ │
# │ │                             <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x72c314dcf1c0>,                          │ │
# │ │                             │   'use_chat_template': False,              │ │
# │ │                             │   'compile': False                         │ │
# │ │                             }                                            │ │
# │ │              model_config = TransformersModelConfig(                     │ │
# │ │                             │                                            │ │
# │ │                             pretrained='akhilfau/Instruction_fine_tuned… │ │
# │ │                             │                                            │ │
# │ │                             accelerator=<accelerate.accelerator.Acceler… │ │
# │ │                             object at 0x72c314dcf1c0>,                   │ │
# │ │                             │   tokenizer=None,                          │ │
# │ │                             │                                            │ │
# │ │                             multichoice_continuations_start_space=None,  │ │
# │ │                             │   pairwise_tokenization=False,             │ │
# │ │                             │   subfolder=None,                          │ │
# │ │                             │   revision='main',                         │ │
# │ │                             │   batch_size=-1,                           │ │
# │ │                             │   max_gen_toks=256,                        │ │
# │ │                             │   max_length=None,                         │ │
# │ │                             │   add_special_tokens=True,                 │ │
# │ │                             │   model_parallel=True,                     │ │
# │ │                             │   dtype=None,                              │ │
# │ │                             │   device='cuda',                           │ │
# │ │                             │   quantization_config=None,                │ │
# │ │                             │   trust_remote_code=False,                 │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   compile=False,                           │ │
# │ │                             │                                            │ │
# │ │                             generation_parameters=GenerationParameters(  │ │
# │ │                             │   │   early_stopping=None,                 │ │
# │ │                             │   │   repetition_penalty=None,             │ │
# │ │                             │   │   frequency_penalty=None,              │ │
# │ │                             │   │   length_penalty=None,                 │ │
# │ │                             │   │   presence_penalty=None,               │ │
# │ │                             │   │   max_new_tokens=None,                 │ │
# │ │                             │   │   min_new_tokens=None,                 │ │
# │ │                             │   │   seed=None,                           │ │
# │ │                             │   │   stop_tokens=None,                    │ │
# │ │                             │   │   temperature=None,                    │ │
# │ │                             │   │   top_k=None,                          │ │
# │ │                             │   │   min_p=None,                          │ │
# │ │                             │   │   top_p=None,                          │ │
# │ │                             │   │   truncate_prompt=None                 │ │
# │ │                             │   ),                                       │ │
# │ │                             │   generation_config=None                   │ │
# │ │                             )                                            │ │
# │ │         num_fewshot_seeds = 1                                            │ │
# │ │                output_dir = '/content/360M_output'                       │ │
# │ │       override_batch_size = 16                                           │ │
# │ │                  pipeline = <lighteval.pipeline.Pipeline object at       │ │
# │ │                             0x72c31254a6e0>                              │ │
# │ │           pipeline_params = PipelineParameters(                          │ │
# │ │                             │                                            │ │
# │ │                             launcher_type=<ParallelismManager.ACCELERAT… │ │
# │ │                             1>,                                          │ │
# │ │                             │   env_config=EnvConfig(                    │ │
# │ │                             │   │   cache_dir=None,                      │ │
# │ │                             │   │   token=None                           │ │
# │ │                             │   ),                                       │ │
# │ │                             │   job_id=0,                                │ │
# │ │                             │   dataset_loading_processes=1,             │ │
# │ │                             │   nanotron_checkpoint_path=None,           │ │
# │ │                             │   custom_tasks_directory=None,             │ │
# │ │                             │   override_batch_size=16,                  │ │
# │ │                             │   num_fewshot_seeds=1,                     │ │
# │ │                             │   max_samples=None,                        │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   system_prompt=None                       │ │
# │ │                             )                                            │ │
# │ │                public_run = False                                        │ │
# │ │               push_to_hub = False                                        │ │
# │ │       push_to_tensorboard = False                                        │ │
# │ │                   results = {                                            │ │
# │ │                             │   'config_general': {                      │ │
# │ │                             │   │   'lighteval_sha': '?',                │ │
# │ │                             │   │   'num_fewshot_seeds': 1,              │ │
# │ │                             │   │   'override_batch_size': 16,           │ │
# │ │                             │   │   'max_samples': None,                 │ │
# │ │                             │   │   'job_id': 0,                         │ │
# │ │                             │   │   'start_time': 82281.538199843,       │ │
# │ │                             │   │   'end_time': 82290.385860809,         │ │
# │ │                             │   │   'total_evaluation_time_secondes':    │ │
# │ │                             '8.84766096599924',                          │ │
# │ │                             │   │   'model_name':                        │ │
# │ │                             'akhilfau/Instruction_fine_tuned_on_camel_a… │ │
# │ │                             │   │   'model_sha':                         │ │
# │ │                             '28a1c11b822b6210e111db9e153c1bae2491e76e',  │ │
# │ │                             │   │   ... +3                               │ │
# │ │                             │   },                                       │ │
# │ │                             │   'results': {                             │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics:0':    │ │
# │ │                             defaultdict(<class 'float'>, {               │ │
# │ │                             │   │   │   'acc': 0.2582781456953642,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.035737053147634576                         │ │
# │ │                             │   │   }),                                  │ │
# │ │                             │   │   'all': {                             │ │
# │ │                             │   │   │   'acc': 0.2582781456953642,       │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.035737053147634576                         │ │
# │ │                             │   │   }                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'versions': {                            │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics:0': 0  │ │
# │ │                             │   },                                       │ │
# │ │                             │   'config_tasks': {                        │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics':      │ │
# │ │                             LightevalTaskConfig(                         │ │
# │ │                             │   │   │   name='mmlu:high_school_physics', │ │
# │ │                             │   │   │   prompt_function=<function        │ │
# │ │                             mmlu_harness at 0x72c312f984c0>,             │ │
# │ │                             │   │   │   hf_repo='lighteval/mmlu',        │ │
# │ │                             │   │   │   hf_subset='high_school_physics', │ │
# │ │                             │   │   │   metric=(                         │ │
# │ │                             │   │   │   │   SampleLevelMetric(           │ │
# │ │                             │   │   │   │   │   metric_name='acc',       │ │
# │ │                             │   │   │   │   │   higher_is_better=True,   │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             category=<MetricCategory.MULTICHOICE: '8'>,  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             use_case=<MetricUseCase.ACCURACY: '1'>,      │ │
# │ │                             │   │   │   │   │   sample_level_fn=<bound   │ │
# │ │                             method LoglikelihoodAcc.compute of           │ │
# │ │                             <lighteval.metrics.metrics_sample.Loglikeli… │ │
# │ │                             object at 0x72c314d387f0>>,                  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             corpus_level_fn=<function mean at            │ │
# │ │                             0x72c50d1f38b0>                              │ │
# │ │                             │   │   │   │   ),                           │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   hf_revision=None,                │ │
# │ │                             │   │   │   hf_filter=None,                  │ │
# │ │                             │   │   │   hf_avail_splits=(                │ │
# │ │                             │   │   │   │   'auxiliary_train',           │ │
# │ │                             │   │   │   │   'test',                      │ │
# │ │                             │   │   │   │   'validation',                │ │
# │ │                             │   │   │   │   'dev'                        │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   trust_dataset=True,              │ │
# │ │                             │   │   │   evaluation_splits=('test',),     │ │
# │ │                             │   │   │   few_shots_split='dev',           │ │
# │ │                             │   │   │   few_shots_select='sequential',   │ │
# │ │                             │   │   │   generation_size=1,               │ │
# │ │                             │   │   │   generation_grammar=None,         │ │
# │ │                             │   │   │   stop_sequence=('\n',),           │ │
# │ │                             │   │   │   num_samples=None,                │ │
# │ │                             │   │   │   suite=('leaderboard', 'mmlu'),   │ │
# │ │                             │   │   │   original_num_docs=151,           │ │
# │ │                             │   │   │   effective_num_docs=151,          │ │
# │ │                             │   │   │                                    │ │
# │ │                             must_remove_duplicate_docs=False,            │ │
# │ │                             │   │   │   version=0                        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_tasks': {                       │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:high_school_physics:0':    │ │
# │ │                             CompiledDetail(                              │ │
# │ │                             │   │   │   hashes={                         │ │
# │ │                             │   │   │   │   'hash_examples':             │ │
# │ │                             'dc3ce06378548565',                          │ │
# │ │                             │   │   │   │   'hash_full_prompts':         │ │
# │ │                             'dc3ce06378548565',                          │ │
# │ │                             │   │   │   │   'hash_input_tokens':         │ │
# │ │                             'b6ac406504a36770',                          │ │
# │ │                             │   │   │   │   'hash_cont_tokens':          │ │
# │ │                             'c0574161c8cbdae1'                           │ │
# │ │                             │   │   │   },                               │ │
# │ │                             │   │   │   truncated=0,                     │ │
# │ │                             │   │   │   non_truncated=151,               │ │
# │ │                             │   │   │   padded=590,                      │ │
# │ │                             │   │   │   non_padded=14,                   │ │
# │ │                             │   │   │   effective_few_shots=0.0,         │ │
# │ │                             │   │   │   num_truncated_few_shots=0        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_general': {                     │ │
# │ │                             │   │   'hashes': {                          │ │
# │ │                             │   │   │   'hash_examples':                 │ │
# │ │                             'e8ff700bb0c49d9e',                          │ │
# │ │                             │   │   │   'hash_full_prompts':             │ │
# │ │                             'e8ff700bb0c49d9e',                          │ │
# │ │                             │   │   │   'hash_input_tokens':             │ │
# │ │                             'fe17304c84c62dfc',                          │ │
# │ │                             │   │   │   'hash_cont_tokens':              │ │
# │ │                             'b70594ab0120390d'                           │ │
# │ │                             │   │   },                                   │ │
# │ │                             │   │   'truncated': 0,                      │ │
# │ │                             │   │   'non_truncated': 151,                │ │
# │ │                             │   │   'padded': 590,                       │ │
# │ │                             │   │   'non_padded': 14,                    │ │
# │ │                             │   │   'num_truncated_few_shots': 0         │ │
# │ │                             │   }                                        │ │
# │ │                             }                                            │ │
# │ │               results_org = None                                         │ │
# │ │              save_details = False                                        │ │
# │ │             system_prompt = None                                         │ │
# │ │                     tasks = 'leaderboard|mmlu:high_school_physics|0|0'   │ │
# │ │                     torch = <module 'torch' from                         │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ │         use_chat_template = False                                        │ │
# │ │                      yaml = <module 'yaml' from                          │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/pipeline.py:334 in save_and_push_results                                 │
# │                                                                              │
# │   331 │   def save_and_push_results(self):                                   │
# │   332 │   │   logger.info("--- SAVING AND PUSHING RESULTS ---")              │
# │   333 │   │   if self.is_main_process():                                     │
# │ ❱ 334 │   │   │   self.evaluation_tracker.save()                             │
# │   335 │                                                                      │
# │   336 │   def _init_final_dict(self):                                        │
# │   337 │   │   if self.is_main_process():                                     │
# │                                                                              │
# │ ╭─────────────────────────── locals ────────────────────────────╮            │
# │ │ self = <lighteval.pipeline.Pipeline object at 0x72c31254a6e0> │            │
# │ ╰───────────────────────────────────────────────────────────────╯            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/logging/evaluation_tracker.py:187 in save                                │
# │                                                                              │
# │   184 │   │   │   details_datasets[task_name] = dataset                      │
# │   185 │   │                                                                  │
# │   186 │   │   # We save results at every case                                │
# │ ❱ 187 │   │   self.save_results(date_id, results_dict)                       │
# │   188 │   │                                                                  │
# │   189 │   │   if self.should_save_details:                                   │
# │   190 │   │   │   self.save_details(date_id, details_datasets)               │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │     column_names = [                                                     │ │
# │ │                    │   'example',                                        │ │
# │ │                    │   'instruction',                                    │ │
# │ │                    │   'full_prompt',                                    │ │
# │ │                    │   'num_effective_few_shots',                        │ │
# │ │                    │   'num_asked_few_shots',                            │ │
# │ │                    │   'predictions',                                    │ │
# │ │                    │   'input_tokens',                                   │ │
# │ │                    │   'cont_tokens',                                    │ │
# │ │                    │   'truncated',                                      │ │
# │ │                    │   'padded',                                         │ │
# │ │                    │   ... +6                                            │ │
# │ │                    ]                                                     │ │
# │ │   config_general = {                                                     │ │
# │ │                    │   'lighteval_sha': '?',                             │ │
# │ │                    │   'num_fewshot_seeds': 1,                           │ │
# │ │                    │   'override_batch_size': 16,                        │ │
# │ │                    │   'max_samples': None,                              │ │
# │ │                    │   'job_id': 0,                                      │ │
# │ │                    │   'start_time': 82281.538199843,                    │ │
# │ │                    │   'end_time': 82290.385860809,                      │ │
# │ │                    │   'total_evaluation_time_secondes':                 │ │
# │ │                    '8.84766096599924',                                   │ │
# │ │                    │   'model_name':                                     │ │
# │ │                    'akhilfau/Instruction_fine_tuned_on_camel_ai_physics… │ │
# │ │                    │   'model_sha':                                      │ │
# │ │                    '28a1c11b822b6210e111db9e153c1bae2491e76e',           │ │
# │ │                    │   ... +2                                            │ │
# │ │                    }                                                     │ │
# │ │          dataset = Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 151                                     │ │
# │ │                    })                                                    │ │
# │ │          date_id = '2025-03-05T12-19-10.246760'                          │ │
# │ │ details_datasets = {                                                     │ │
# │ │                    │   'leaderboard|mmlu:high_school_physics|0':         │ │
# │ │                    Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 151                                     │ │
# │ │                    })                                                    │ │
# │ │                    }                                                     │ │
# │ │     results_dict = {                                                     │ │
# │ │                    │   'config_general': {                               │ │
# │ │                    │   │   'lighteval_sha': '?',                         │ │
# │ │                    │   │   'num_fewshot_seeds': 1,                       │ │
# │ │                    │   │   'override_batch_size': 16,                    │ │
# │ │                    │   │   'max_samples': None,                          │ │
# │ │                    │   │   'job_id': 0,                                  │ │
# │ │                    │   │   'start_time': 82281.538199843,                │ │
# │ │                    │   │   'end_time': 82290.385860809,                  │ │
# │ │                    │   │   'total_evaluation_time_secondes':             │ │
# │ │                    '8.84766096599924',                                   │ │
# │ │                    │   │   'model_name':                                 │ │
# │ │                    'akhilfau/Instruction_fine_tuned_on_camel_ai_physics… │ │
# │ │                    │   │   'model_sha':                                  │ │
# │ │                    '28a1c11b822b6210e111db9e153c1bae2491e76e',           │ │
# │ │                    │   │   ... +2                                        │ │
# │ │                    │   },                                                │ │
# │ │                    │   'results': defaultdict(<function                  │ │
# │ │                    MetricsLogger.<lambda>.<locals>.<lambda> at           │ │
# │ │                    0x72c312559cf0>, {                                    │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics|0':     │ │
# │ │                    defaultdict(<class 'float'>, {                        │ │
# │ │                    │   │   │   'acc': 0.2582781456953642,                │ │
# │ │                    │   │   │   'acc_stderr': 0.035737053147634576        │ │
# │ │                    │   │   }),                                           │ │
# │ │                    │   │   'all': {                                      │ │
# │ │                    │   │   │   'acc': 0.2582781456953642,                │ │
# │ │                    │   │   │   'acc_stderr': 0.035737053147634576        │ │
# │ │                    │   │   }                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'versions': {                                     │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics|0': 0   │ │
# │ │                    │   },                                                │ │
# │ │                    │   'config_tasks': {                                 │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics':       │ │
# │ │                    LightevalTaskConfig(                                  │ │
# │ │                    │   │   │   name='mmlu:high_school_physics',          │ │
# │ │                    │   │   │   prompt_function=<function mmlu_harness at │ │
# │ │                    0x72c312f984c0>,                                      │ │
# │ │                    │   │   │   hf_repo='lighteval/mmlu',                 │ │
# │ │                    │   │   │   hf_subset='high_school_physics',          │ │
# │ │                    │   │   │   metric=(                                  │ │
# │ │                    │   │   │   │   SampleLevelMetric(                    │ │
# │ │                    │   │   │   │   │   metric_name='acc',                │ │
# │ │                    │   │   │   │   │   higher_is_better=True,            │ │
# │ │                    │   │   │   │   │                                     │ │
# │ │                    category=<MetricCategory.MULTICHOICE: '8'>,           │ │
# │ │                    │   │   │   │   │   use_case=<MetricUseCase.ACCURACY: │ │
# │ │                    '1'>,                                                 │ │
# │ │                    │   │   │   │   │   sample_level_fn=<bound method     │ │
# │ │                    LoglikelihoodAcc.compute of                           │ │
# │ │                    <lighteval.metrics.metrics_sample.LoglikelihoodAcc    │ │
# │ │                    object at 0x72c314d387f0>>,                           │ │
# │ │                    │   │   │   │   │   corpus_level_fn=<function mean at │ │
# │ │                    0x72c50d1f38b0>                                       │ │
# │ │                    │   │   │   │   ),                                    │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   hf_revision=None,                         │ │
# │ │                    │   │   │   hf_filter=None,                           │ │
# │ │                    │   │   │   hf_avail_splits=(                         │ │
# │ │                    │   │   │   │   'auxiliary_train',                    │ │
# │ │                    │   │   │   │   'test',                               │ │
# │ │                    │   │   │   │   'validation',                         │ │
# │ │                    │   │   │   │   'dev'                                 │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   trust_dataset=True,                       │ │
# │ │                    │   │   │   evaluation_splits=('test',),              │ │
# │ │                    │   │   │   few_shots_split='dev',                    │ │
# │ │                    │   │   │   few_shots_select='sequential',            │ │
# │ │                    │   │   │   generation_size=1,                        │ │
# │ │                    │   │   │   generation_grammar=None,                  │ │
# │ │                    │   │   │   stop_sequence=('\n',),                    │ │
# │ │                    │   │   │   num_samples=None,                         │ │
# │ │                    │   │   │   suite=('leaderboard', 'mmlu'),            │ │
# │ │                    │   │   │   original_num_docs=151,                    │ │
# │ │                    │   │   │   effective_num_docs=151,                   │ │
# │ │                    │   │   │   must_remove_duplicate_docs=False,         │ │
# │ │                    │   │   │   version=0                                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   },                                                │ │
# │ │                    │   'summary_tasks': defaultdict(<class               │ │
# │ │                    'lighteval.logging.info_loggers.DetailsLogger.Compil… │ │
# │ │                    {                                                     │ │
# │ │                    │   │   'leaderboard|mmlu:high_school_physics|0':     │ │
# │ │                    CompiledDetail(                                       │ │
# │ │                    │   │   │   hashes={                                  │ │
# │ │                    │   │   │   │   'hash_examples': 'dc3ce06378548565',  │ │
# │ │                    │   │   │   │   'hash_full_prompts':                  │ │
# │ │                    'dc3ce06378548565',                                   │ │
# │ │                    │   │   │   │   'hash_input_tokens':                  │ │
# │ │                    'b6ac406504a36770',                                   │ │
# │ │                    │   │   │   │   'hash_cont_tokens':                   │ │
# │ │                    'c0574161c8cbdae1'                                    │ │
# │ │                    │   │   │   },                                        │ │
# │ │                    │   │   │   truncated=0,                              │ │
# │ │                    │   │   │   non_truncated=151,                        │ │
# │ │                    │   │   │   padded=590,                               │ │
# │ │                    │   │   │   non_padded=14,                            │ │
# │ │                    │   │   │   effective_few_shots=0.0,                  │ │
# │ │                    │   │   │   num_truncated_few_shots=0                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'summary_general': {                              │ │
# │ │                    │   │   'hashes': {                                   │ │
# │ │                    │   │   │   'hash_examples': 'e8ff700bb0c49d9e',      │ │
# │ │                    │   │   │   'hash_full_prompts': 'e8ff700bb0c49d9e',  │ │
# │ │                    │   │   │   'hash_input_tokens': 'fe17304c84c62dfc',  │ │
# │ │                    │   │   │   'hash_cont_tokens': 'b70594ab0120390d'    │ │
# │ │                    │   │   },                                            │ │
# │ │                    │   │   'truncated': 0,                               │ │
# │ │                    │   │   'non_truncated': 151,                         │ │
# │ │                    │   │   'padded': 590,                                │ │
# │ │                    │   │   'non_padded': 14,                             │ │
# │ │                    │   │   'num_truncated_few_shots': 0                  │ │
# │ │                    │   }                                                 │ │
# │ │                    }                                                     │ │
# │ │             self = <lighteval.logging.evaluation_tracker.EvaluationTrac… │ │
# │ │                    object at 0x72c31254beb0>                             │ │
# │ │     task_details = [                                                     │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about high school phy'+232,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+7,                                               │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about high school     │ │
# │ │                    phy'+232,                                             │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-6.5516743659973145, False),             │ │
# │ │                    │   │   │   (-2.4058480262756348, False),             │ │
# │ │                    │   │   │   (-1.0593153238296509, False),             │ │
# │ │                    │   │   │   (-0.5774790048599243, True)               │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +128                              │ │
# │ │                    │   │   │   ]                                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   cont_tokens=[[330], [389], [340], [422]],     │ │
# │ │                    │   │   truncated=[0, 0, 0, 0],                       │ │
# │ │                    │   │   padded=[27, 27, 27, 27],                      │ │
# │ │                    │   │   gold=[],                                      │ │
# │ │                    │   │   pred_logits=[],                               │ │
# │ │                    │   │   choices=[' A', ' B', ' C', ' D'],             │ │
# │ │                    │   │   gold_index=[3],                               │ │
# │ │                    │   │   metrics={'acc': 1},                           │ │
# │ │                    │   │   specifics=None                                │ │
# │ │                    │   ),                                                │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about high school phy'+292,  │ │
# ...
# │ │                      │   │   │   hf_filter=None,                         │ │
# │ │                      │   │   │   hf_avail_splits=(                       │ │
# │ │                      │   │   │   │   'auxiliary_train',                  │ │
# │ │                      │   │   │   │   'test',                             │ │
# │ │                      │   │   │   │   'validation',                       │ │
# │ │                      │   │   │   │   'dev'                               │ │
# │ │                      │   │   │   ),                                      │ │
# │ │                      │   │   │   trust_dataset=True,                     │ │
# │ │                      │   │   │   evaluation_splits=('test',),            │ │
# │ │                      │   │   │   few_shots_split='dev',                  │ │
# │ │                      │   │   │   few_shots_select='sequential',          │ │
# │ │                      │   │   │   generation_size=1,                      │ │
# │ │                      │   │   │   generation_grammar=None,                │ │
# │ │                      │   │   │   stop_sequence=('\n',),                  │ │
# │ │                      │   │   │   num_samples=None,                       │ │
# │ │                      │   │   │   suite=('leaderboard', 'mmlu'),          │ │
# │ │                      │   │   │   original_num_docs=151,                  │ │
# │ │                      │   │   │   effective_num_docs=151,                 │ │
# │ │                      │   │   │   must_remove_duplicate_docs=False,       │ │
# │ │                      │   │   │   version=0                               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   },                                              │ │
# │ │                      │   'summary_tasks': defaultdict(<class             │ │
# │ │                      'lighteval.logging.info_loggers.DetailsLogger.Comp… │ │
# │ │                      {                                                   │ │
# │ │                      │   │   'leaderboard|mmlu:high_school_physics|0':   │ │
# │ │                      CompiledDetail(                                     │ │
# │ │                      │   │   │   hashes={                                │ │
# │ │                      │   │   │   │   'hash_examples':                    │ │
# │ │                      'dc3ce06378548565',                                 │ │
# │ │                      │   │   │   │   'hash_full_prompts':                │ │
# │ │                      'dc3ce06378548565',                                 │ │
# │ │                      │   │   │   │   'hash_input_tokens':                │ │
# │ │                      'b6ac406504a36770',                                 │ │
# │ │                      │   │   │   │   'hash_cont_tokens':                 │ │
# │ │                      'c0574161c8cbdae1'                                  │ │
# │ │                      │   │   │   },                                      │ │
# │ │                      │   │   │   truncated=0,                            │ │
# │ │                      │   │   │   non_truncated=151,                      │ │
# │ │                      │   │   │   padded=590,                             │ │
# │ │                      │   │   │   non_padded=14,                          │ │
# │ │                      │   │   │   effective_few_shots=0.0,                │ │
# │ │                      │   │   │   num_truncated_few_shots=0               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   }),                                             │ │
# │ │                      │   'summary_general': {                            │ │
# │ │                      │   │   'hashes': {                                 │ │
# │ │                      │   │   │   'hash_examples': 'e8ff700bb0c49d9e',    │ │
# │ │                      │   │   │   'hash_full_prompts':                    │ │
# │ │                      'e8ff700bb0c49d9e',                                 │ │
# │ │                      │   │   │   'hash_input_tokens':                    │ │
# │ │                      'fe17304c84c62dfc',                                 │ │
# │ │                      │   │   │   'hash_cont_tokens': 'b70594ab0120390d'  │ │
# │ │                      │   │   },                                          │ │
# │ │                      │   │   'truncated': 0,                             │ │
# │ │                      │   │   'non_truncated': 151,                       │ │
# │ │                      │   │   'padded': 590,                              │ │
# │ │                      │   │   'non_padded': 14,                           │ │
# │ │                      │   │   'num_truncated_few_shots': 0                │ │
# │ │                      │   }                                               │ │
# │ │                      }                                                   │ │
# │ │               self = <lighteval.logging.evaluation_tracker.EvaluationTr… │ │
# │ │                      object at 0x72c31254beb0>                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /spec.py:1589 in mkdirs                                                      │
# │                                                                              │
# │   1586 │                                                                     │
# │   1587 │   def mkdirs(self, path, exist_ok=False):                           │
# │   1588 │   │   """Alias of `AbstractFileSystem.makedirs`."""                 │
# │ ❱ 1589 │   │   return self.makedirs(path, exist_ok=exist_ok)                 │
# │   1590 │                                                                     │
# │   1591 │   def listdir(self, path, detail=True, **kwargs):                   │
# │   1592 │   │   """Alias of `AbstractFileSystem.ls`."""                       │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = PosixPath('/content/360M_output/results/akhilfau/Instruction… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x72c31254a770>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /implementations/local.py:52 in makedirs                                     │
# │                                                                              │
# │    49 │                                                                      │
# │    50 │   def makedirs(self, path, exist_ok=False):                          │
# │    51 │   │   path = self._strip_protocol(path)                              │
# │ ❱  52 │   │   os.makedirs(path, exist_ok=exist_ok)                           │
# │    53 │                                                                      │
# │    54 │   def rmdir(self, path):                                             │
# │    55 │   │   path = self._strip_protocol(path)                              │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = '/content/360M_output/results/akhilfau/Instruction_fine_tune… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x72c31254a770>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     head = '/content/360M_output/results/akhilfau'                       │ │
# │ │     mode = 511                                                           │ │
# │ │     name = '/content/360M_output/results/akhilfau/Instruction_fine_tune… │ │
# │ │     tail = 'Instruction_fine_tuned_on_camel_ai_physics'                  │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭────────────────────── locals ──────────────────────╮                       │
# │ │ exist_ok = True                                    │                       │
# │ │     head = '/content/360M_output/results'          │                       │
# │ │     mode = 511                                     │                       │
# │ │     name = '/content/360M_output/results/akhilfau' │                       │
# │ │     tail = 'akhilfau'                              │                       │
# │ ╰────────────────────────────────────────────────────╯                       │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────── locals ──────────────────╮                                │
# │ │ exist_ok = True                           │                                │
# │ │     head = '/content/360M_output'         │                                │
# │ │     mode = 511                            │                                │
# │ │     name = '/content/360M_output/results' │                                │
# │ │     tail = 'results'                      │                                │
# │ ╰───────────────────────────────────────────╯                                │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────── locals ──────────────╮                                        │
# │ │ exist_ok = True                   │                                        │
# │ │     head = '/content'             │                                        │
# │ │     mode = 511                    │                                        │
# │ │     name = '/content/360M_output' │                                        │
# │ │     tail = '360M_output'          │                                        │
# │ ╰───────────────────────────────────╯                                        │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:225 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    222 │   │   if tail == cdir:           # xxx/newdir/. exists if xxx/newdi │
# │    223 │   │   │   return                                                    │
# │    224 │   try:                                                              │
# │ ❱  225 │   │   mkdir(name, mode)                                             │
# │    226 │   except OSError:                                                   │
# │    227 │   │   # Cannot rely on checking for EEXIST, since the operating sys │
# │    228 │   │   # could give priority to other errors like EACCES or EROFS    │
# │                                                                              │
# │ ╭─────── locals ────────╮                                                    │
# │ │ exist_ok = True       │                                                    │
# │ │     head = '/'        │                                                    │
# │ │     mode = 511        │                                                    │
# │ │     name = '/content' │                                                    │
# │ │     tail = 'content'  │                                                    │
# │ ╰───────────────────────╯                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
#College_physics

# %%
MODEL="HuggingFaceTB/SmolLM2-360M"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:college_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [2025-03-05 12:23:24,852] [    INFO]: PyTorch version 2.4.1 available. (config.py:54)
# [2025-03-05 12:23:26,794] [    INFO]: Test gather tensor (parallelism.py:133)
# [2025-03-05 12:23:26,873] [    INFO]: gathered_tensor tensor([0], device='cuda:0'), should be [0] (parallelism.py:136)
# [2025-03-05 12:23:26,873] [    INFO]: --- LOADING MODEL --- (pipeline.py:168)
# [2025-03-05 12:23:27,043] [    INFO]: Tokenizer truncation and padding size set to the left side. (transformers_model.py:539)
# [2025-03-05 12:23:27,287] [    INFO]: Setting model parallel to True since the number of local processes is 1 and the number of GPUs is 4 (transformers_model.py:402)
# [2025-03-05 12:23:27,288] [    INFO]: Model parallel was set to True, setting max memory per GPU to {0: 10169221120, 1: 15557066752, 2: 15557066752, 3: 15573843968} and device map to auto (transformers_model.py:417)
# [2025-03-05 12:23:27,820] [    INFO]: --- LOADING TASKS --- (pipeline.py:195)
# [2025-03-05 12:23:27,820] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:136)
# [2025-03-05 12:23:27,823] [    INFO]: lighteval/mmlu college_physics (lighteval_task.py:187)
# [2025-03-05 12:23:28,778] [    INFO]: --- INIT SEEDS --- (pipeline.py:224)
# [2025-03-05 12:23:28,778] [    INFO]: --- RUNNING MODEL --- (pipeline.py:267)
# [2025-03-05 12:23:28,778] [    INFO]: Running RequestType.LOGLIKELIHOOD requests (pipeline.py:271)
# 0it [00:00, ?it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▍                                      | 1/7 [00:00<00:02,  2.66it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00,  7.33it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 10.29it/s]
# 1it [00:00,  1.47it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00, 22.97it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 23.96it/s]
# 2it [00:00,  2.21it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00, 25.38it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 26.17it/s]
# 3it [00:01,  2.72it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00, 24.71it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 26.16it/s]
# 4it [00:01,  2.65it/s]
# [2025-03-05 12:23:30,399] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:299)
# [2025-03-05 12:23:30,403] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:342)
# [2025-03-05 12:23:30,403] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# |               Task               |Version|Metric|Value |   |Stderr|
# |----------------------------------|------:|------|-----:|---|-----:|
# |all                               |       |acc   |0.1863|±  |0.0387|
# |leaderboard:mmlu:college_physics:0|      0|acc   |0.1863|±  |0.0387|
#
# [2025-03-05 12:23:30,416] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:332)
# [2025-03-05 12:23:30,416] [    INFO]: Saving experiment tracker (evaluation_tracker.py:154)
# [2025-03-05 12:23:30,416] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/main_accelerate.py:207 in accelerate                                     │
# │                                                                              │
# │   204 │                                                                      │
# │   205 │   results = pipeline.get_results()                                   │
# │   206 │                                                                      │
# │ ❱ 207 │   pipeline.save_and_push_results()                                   │
# │   208 │                                                                      │
# │   209 │   return results                                                     │
# │   210                                                                        │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │               accelerator = <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x7418363c0730>                           │ │
# │ │                 cache_dir = None                                         │ │
# │ │              custom_tasks = None                                         │ │
# │ │ dataset_loading_processes = 1                                            │ │
# │ │                env_config = EnvConfig(cache_dir=None, token=None)        │ │
# │ │        evaluation_tracker = <lighteval.logging.evaluation_tracker.Evalu… │ │
# │ │                             object at 0x741833b37340>                    │ │
# │ │                    job_id = 0                                            │ │
# │ │               max_samples = None                                         │ │
# │ │                model_args = 'pretrained=HuggingFaceTB/SmolLM2-360M'      │ │
# │ │           model_args_dict = {                                            │ │
# │ │                             │   'pretrained':                            │ │
# │ │                             'HuggingFaceTB/SmolLM2-360M',                │ │
# │ │                             │   'accelerator':                           │ │
# │ │                             <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x7418363c0730>,                          │ │
# │ │                             │   'use_chat_template': False,              │ │
# │ │                             │   'compile': False                         │ │
# │ │                             }                                            │ │
# │ │              model_config = TransformersModelConfig(                     │ │
# │ │                             │   pretrained='HuggingFaceTB/SmolLM2-360M', │ │
# │ │                             │                                            │ │
# │ │                             accelerator=<accelerate.accelerator.Acceler… │ │
# │ │                             object at 0x7418363c0730>,                   │ │
# │ │                             │   tokenizer=None,                          │ │
# │ │                             │                                            │ │
# │ │                             multichoice_continuations_start_space=None,  │ │
# │ │                             │   pairwise_tokenization=False,             │ │
# │ │                             │   subfolder=None,                          │ │
# │ │                             │   revision='main',                         │ │
# │ │                             │   batch_size=-1,                           │ │
# │ │                             │   max_gen_toks=256,                        │ │
# │ │                             │   max_length=None,                         │ │
# │ │                             │   add_special_tokens=True,                 │ │
# │ │                             │   model_parallel=True,                     │ │
# │ │                             │   dtype=None,                              │ │
# │ │                             │   device='cuda',                           │ │
# │ │                             │   quantization_config=None,                │ │
# │ │                             │   trust_remote_code=False,                 │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   compile=False,                           │ │
# │ │                             │                                            │ │
# │ │                             generation_parameters=GenerationParameters(  │ │
# │ │                             │   │   early_stopping=None,                 │ │
# │ │                             │   │   repetition_penalty=None,             │ │
# │ │                             │   │   frequency_penalty=None,              │ │
# │ │                             │   │   length_penalty=None,                 │ │
# │ │                             │   │   presence_penalty=None,               │ │
# │ │                             │   │   max_new_tokens=None,                 │ │
# │ │                             │   │   min_new_tokens=None,                 │ │
# │ │                             │   │   seed=None,                           │ │
# │ │                             │   │   stop_tokens=None,                    │ │
# │ │                             │   │   temperature=None,                    │ │
# │ │                             │   │   top_k=None,                          │ │
# │ │                             │   │   min_p=None,                          │ │
# │ │                             │   │   top_p=None,                          │ │
# │ │                             │   │   truncate_prompt=None                 │ │
# │ │                             │   ),                                       │ │
# │ │                             │   generation_config=None                   │ │
# │ │                             )                                            │ │
# │ │         num_fewshot_seeds = 1                                            │ │
# │ │                output_dir = '/content/360M_output'                       │ │
# │ │       override_batch_size = 16                                           │ │
# │ │                  pipeline = <lighteval.pipeline.Pipeline object at       │ │
# │ │                             0x741833b36770>                              │ │
# │ │           pipeline_params = PipelineParameters(                          │ │
# │ │                             │                                            │ │
# │ │                             launcher_type=<ParallelismManager.ACCELERAT… │ │
# │ │                             1>,                                          │ │
# │ │                             │   env_config=EnvConfig(                    │ │
# │ │                             │   │   cache_dir=None,                      │ │
# │ │                             │   │   token=None                           │ │
# │ │                             │   ),                                       │ │
# │ │                             │   job_id=0,                                │ │
# │ │                             │   dataset_loading_processes=1,             │ │
# │ │                             │   nanotron_checkpoint_path=None,           │ │
# │ │                             │   custom_tasks_directory=None,             │ │
# │ │                             │   override_batch_size=16,                  │ │
# │ │                             │   num_fewshot_seeds=1,                     │ │
# │ │                             │   max_samples=None,                        │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   system_prompt=None                       │ │
# │ │                             )                                            │ │
# │ │                public_run = False                                        │ │
# │ │               push_to_hub = False                                        │ │
# │ │       push_to_tensorboard = False                                        │ │
# │ │                   results = {                                            │ │
# │ │                             │   'config_general': {                      │ │
# │ │                             │   │   'lighteval_sha': '?',                │ │
# │ │                             │   │   'num_fewshot_seeds': 1,              │ │
# │ │                             │   │   'override_batch_size': 16,           │ │
# │ │                             │   │   'max_samples': None,                 │ │
# │ │                             │   │   'job_id': 0,                         │ │
# │ │                             │   │   'start_time': 82546.944780402,       │ │
# │ │                             │   │   'end_time': 82550.555197988,         │ │
# │ │                             │   │   'total_evaluation_time_secondes':    │ │
# │ │                             '3.6104175859945826',                        │ │
# │ │                             │   │   'model_name':                        │ │
# │ │                             'HuggingFaceTB/SmolLM2-360M',                │ │
# │ │                             │   │   'model_sha':                         │ │
# │ │                             'f8027fd0eaeea54caa13c31d31b9fdc459c38b49',  │ │
# │ │                             │   │   ... +3                               │ │
# │ │                             │   },                                       │ │
# │ │                             │   'results': {                             │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:college_physics:0':        │ │
# │ │                             defaultdict(<class 'float'>, {               │ │
# │ │                             │   │   │   'acc': 0.18627450980392157,      │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.038739587141493524                         │ │
# │ │                             │   │   }),                                  │ │
# │ │                             │   │   'all': {                             │ │
# │ │                             │   │   │   'acc': 0.18627450980392157,      │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.038739587141493524                         │ │
# │ │                             │   │   }                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'versions': {                            │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:college_physics:0': 0      │ │
# │ │                             │   },                                       │ │
# │ │                             │   'config_tasks': {                        │ │
# │ │                             │   │   'leaderboard:mmlu:college_physics':  │ │
# │ │                             LightevalTaskConfig(                         │ │
# │ │                             │   │   │   name='mmlu:college_physics',     │ │
# │ │                             │   │   │   prompt_function=<function        │ │
# │ │                             mmlu_harness at 0x7418345844c0>,             │ │
# │ │                             │   │   │   hf_repo='lighteval/mmlu',        │ │
# │ │                             │   │   │   hf_subset='college_physics',     │ │
# │ │                             │   │   │   metric=(                         │ │
# │ │                             │   │   │   │   SampleLevelMetric(           │ │
# │ │                             │   │   │   │   │   metric_name='acc',       │ │
# │ │                             │   │   │   │   │   higher_is_better=True,   │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             category=<MetricCategory.MULTICHOICE: '8'>,  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             use_case=<MetricUseCase.ACCURACY: '1'>,      │ │
# │ │                             │   │   │   │   │   sample_level_fn=<bound   │ │
# │ │                             method LoglikelihoodAcc.compute of           │ │
# │ │                             <lighteval.metrics.metrics_sample.Loglikeli… │ │
# │ │                             object at 0x741836324940>>,                  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             corpus_level_fn=<function mean at            │ │
# │ │                             0x741a2f9e7db0>                              │ │
# │ │                             │   │   │   │   ),                           │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   hf_revision=None,                │ │
# │ │                             │   │   │   hf_filter=None,                  │ │
# │ │                             │   │   │   hf_avail_splits=(                │ │
# │ │                             │   │   │   │   'auxiliary_train',           │ │
# │ │                             │   │   │   │   'test',                      │ │
# │ │                             │   │   │   │   'validation',                │ │
# │ │                             │   │   │   │   'dev'                        │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   trust_dataset=True,              │ │
# │ │                             │   │   │   evaluation_splits=('test',),     │ │
# │ │                             │   │   │   few_shots_split='dev',           │ │
# │ │                             │   │   │   few_shots_select='sequential',   │ │
# │ │                             │   │   │   generation_size=1,               │ │
# │ │                             │   │   │   generation_grammar=None,         │ │
# │ │                             │   │   │   stop_sequence=('\n',),           │ │
# │ │                             │   │   │   num_samples=None,                │ │
# │ │                             │   │   │   suite=('leaderboard', 'mmlu'),   │ │
# │ │                             │   │   │   original_num_docs=102,           │ │
# │ │                             │   │   │   effective_num_docs=102,          │ │
# │ │                             │   │   │                                    │ │
# │ │                             must_remove_duplicate_docs=False,            │ │
# │ │                             │   │   │   version=0                        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_tasks': {                       │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:college_physics:0':        │ │
# │ │                             CompiledDetail(                              │ │
# │ │                             │   │   │   hashes={                         │ │
# │ │                             │   │   │   │   'hash_examples':             │ │
# │ │                             'ebdab1cdb7e555df',                          │ │
# │ │                             │   │   │   │   'hash_full_prompts':         │ │
# │ │                             'ebdab1cdb7e555df',                          │ │
# │ │                             │   │   │   │   'hash_input_tokens':         │ │
# │ │                             'f0c8814fdfd4ed8c',                          │ │
# │ │                             │   │   │   │   'hash_cont_tokens':          │ │
# │ │                             '928b22b6932f99ca'                           │ │
# │ │                             │   │   │   },                               │ │
# │ │                             │   │   │   truncated=0,                     │ │
# │ │                             │   │   │   non_truncated=102,               │ │
# │ │                             │   │   │   padded=392,                      │ │
# │ │                             │   │   │   non_padded=16,                   │ │
# │ │                             │   │   │   effective_few_shots=0.0,         │ │
# │ │                             │   │   │   num_truncated_few_shots=0        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_general': {                     │ │
# │ │                             │   │   'hashes': {                          │ │
# │ │                             │   │   │   'hash_examples':                 │ │
# │ │                             '51e0fc9d449f6a6d',                          │ │
# │ │                             │   │   │   'hash_full_prompts':             │ │
# │ │                             '51e0fc9d449f6a6d',                          │ │
# │ │                             │   │   │   'hash_input_tokens':             │ │
# │ │                             'a4a57da07a18ea04',                          │ │
# │ │                             │   │   │   'hash_cont_tokens':              │ │
# │ │                             '0f55f6e6c4edd430'                           │ │
# │ │                             │   │   },                                   │ │
# │ │                             │   │   'truncated': 0,                      │ │
# │ │                             │   │   'non_truncated': 102,                │ │
# │ │                             │   │   'padded': 392,                       │ │
# │ │                             │   │   'non_padded': 16,                    │ │
# │ │                             │   │   'num_truncated_few_shots': 0         │ │
# │ │                             │   }                                        │ │
# │ │                             }                                            │ │
# │ │               results_org = None                                         │ │
# │ │              save_details = False                                        │ │
# │ │             system_prompt = None                                         │ │
# │ │                     tasks = 'leaderboard|mmlu:college_physics|0|0'       │ │
# │ │                     torch = <module 'torch' from                         │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ │         use_chat_template = False                                        │ │
# │ │                      yaml = <module 'yaml' from                          │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/pipeline.py:334 in save_and_push_results                                 │
# │                                                                              │
# │   331 │   def save_and_push_results(self):                                   │
# │   332 │   │   logger.info("--- SAVING AND PUSHING RESULTS ---")              │
# │   333 │   │   if self.is_main_process():                                     │
# │ ❱ 334 │   │   │   self.evaluation_tracker.save()                             │
# │   335 │                                                                      │
# │   336 │   def _init_final_dict(self):                                        │
# │   337 │   │   if self.is_main_process():                                     │
# │                                                                              │
# │ ╭─────────────────────────── locals ────────────────────────────╮            │
# │ │ self = <lighteval.pipeline.Pipeline object at 0x741833b36770> │            │
# │ ╰───────────────────────────────────────────────────────────────╯            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/logging/evaluation_tracker.py:187 in save                                │
# │                                                                              │
# │   184 │   │   │   details_datasets[task_name] = dataset                      │
# │   185 │   │                                                                  │
# │   186 │   │   # We save results at every case                                │
# │ ❱ 187 │   │   self.save_results(date_id, results_dict)                       │
# │   188 │   │                                                                  │
# │   189 │   │   if self.should_save_details:                                   │
# │   190 │   │   │   self.save_details(date_id, details_datasets)               │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │     column_names = [                                                     │ │
# │ │                    │   'example',                                        │ │
# │ │                    │   'instruction',                                    │ │
# │ │                    │   'full_prompt',                                    │ │
# │ │                    │   'num_effective_few_shots',                        │ │
# │ │                    │   'num_asked_few_shots',                            │ │
# │ │                    │   'predictions',                                    │ │
# │ │                    │   'input_tokens',                                   │ │
# │ │                    │   'cont_tokens',                                    │ │
# │ │                    │   'truncated',                                      │ │
# │ │                    │   'padded',                                         │ │
# │ │                    │   ... +6                                            │ │
# │ │                    ]                                                     │ │
# │ │   config_general = {                                                     │ │
# │ │                    │   'lighteval_sha': '?',                             │ │
# │ │                    │   'num_fewshot_seeds': 1,                           │ │
# │ │                    │   'override_batch_size': 16,                        │ │
# │ │                    │   'max_samples': None,                              │ │
# │ │                    │   'job_id': 0,                                      │ │
# │ │                    │   'start_time': 82546.944780402,                    │ │
# │ │                    │   'end_time': 82550.555197988,                      │ │
# │ │                    │   'total_evaluation_time_secondes':                 │ │
# │ │                    '3.6104175859945826',                                 │ │
# │ │                    │   'model_name': 'HuggingFaceTB/SmolLM2-360M',       │ │
# │ │                    │   'model_sha':                                      │ │
# │ │                    'f8027fd0eaeea54caa13c31d31b9fdc459c38b49',           │ │
# │ │                    │   ... +2                                            │ │
# │ │                    }                                                     │ │
# │ │          dataset = Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 102                                     │ │
# │ │                    })                                                    │ │
# │ │          date_id = '2025-03-05T12-23-30.416137'                          │ │
# │ │ details_datasets = {                                                     │ │
# │ │                    │   'leaderboard|mmlu:college_physics|0': Dataset({   │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 102                                     │ │
# │ │                    })                                                    │ │
# │ │                    }                                                     │ │
# │ │     results_dict = {                                                     │ │
# │ │                    │   'config_general': {                               │ │
# │ │                    │   │   'lighteval_sha': '?',                         │ │
# │ │                    │   │   'num_fewshot_seeds': 1,                       │ │
# │ │                    │   │   'override_batch_size': 16,                    │ │
# │ │                    │   │   'max_samples': None,                          │ │
# │ │                    │   │   'job_id': 0,                                  │ │
# │ │                    │   │   'start_time': 82546.944780402,                │ │
# │ │                    │   │   'end_time': 82550.555197988,                  │ │
# │ │                    │   │   'total_evaluation_time_secondes':             │ │
# │ │                    '3.6104175859945826',                                 │ │
# │ │                    │   │   'model_name': 'HuggingFaceTB/SmolLM2-360M',   │ │
# │ │                    │   │   'model_sha':                                  │ │
# │ │                    'f8027fd0eaeea54caa13c31d31b9fdc459c38b49',           │ │
# │ │                    │   │   ... +2                                        │ │
# │ │                    │   },                                                │ │
# │ │                    │   'results': defaultdict(<function                  │ │
# │ │                    MetricsLogger.<lambda>.<locals>.<lambda> at           │ │
# │ │                    0x741833b3dcf0>, {                                    │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics|0':         │ │
# │ │                    defaultdict(<class 'float'>, {                        │ │
# │ │                    │   │   │   'acc': 0.18627450980392157,               │ │
# │ │                    │   │   │   'acc_stderr': 0.038739587141493524        │ │
# │ │                    │   │   }),                                           │ │
# │ │                    │   │   'all': {                                      │ │
# │ │                    │   │   │   'acc': 0.18627450980392157,               │ │
# │ │                    │   │   │   'acc_stderr': 0.038739587141493524        │ │
# │ │                    │   │   }                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'versions': {                                     │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics|0': 0       │ │
# │ │                    │   },                                                │ │
# │ │                    │   'config_tasks': {                                 │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics':           │ │
# │ │                    LightevalTaskConfig(                                  │ │
# │ │                    │   │   │   name='mmlu:college_physics',              │ │
# │ │                    │   │   │   prompt_function=<function mmlu_harness at │ │
# │ │                    0x7418345844c0>,                                      │ │
# │ │                    │   │   │   hf_repo='lighteval/mmlu',                 │ │
# │ │                    │   │   │   hf_subset='college_physics',              │ │
# │ │                    │   │   │   metric=(                                  │ │
# │ │                    │   │   │   │   SampleLevelMetric(                    │ │
# │ │                    │   │   │   │   │   metric_name='acc',                │ │
# │ │                    │   │   │   │   │   higher_is_better=True,            │ │
# │ │                    │   │   │   │   │                                     │ │
# │ │                    category=<MetricCategory.MULTICHOICE: '8'>,           │ │
# │ │                    │   │   │   │   │   use_case=<MetricUseCase.ACCURACY: │ │
# │ │                    '1'>,                                                 │ │
# │ │                    │   │   │   │   │   sample_level_fn=<bound method     │ │
# │ │                    LoglikelihoodAcc.compute of                           │ │
# │ │                    <lighteval.metrics.metrics_sample.LoglikelihoodAcc    │ │
# │ │                    object at 0x741836324940>>,                           │ │
# │ │                    │   │   │   │   │   corpus_level_fn=<function mean at │ │
# │ │                    0x741a2f9e7db0>                                       │ │
# │ │                    │   │   │   │   ),                                    │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   hf_revision=None,                         │ │
# │ │                    │   │   │   hf_filter=None,                           │ │
# │ │                    │   │   │   hf_avail_splits=(                         │ │
# │ │                    │   │   │   │   'auxiliary_train',                    │ │
# │ │                    │   │   │   │   'test',                               │ │
# │ │                    │   │   │   │   'validation',                         │ │
# │ │                    │   │   │   │   'dev'                                 │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   trust_dataset=True,                       │ │
# │ │                    │   │   │   evaluation_splits=('test',),              │ │
# │ │                    │   │   │   few_shots_split='dev',                    │ │
# │ │                    │   │   │   few_shots_select='sequential',            │ │
# │ │                    │   │   │   generation_size=1,                        │ │
# │ │                    │   │   │   generation_grammar=None,                  │ │
# │ │                    │   │   │   stop_sequence=('\n',),                    │ │
# │ │                    │   │   │   num_samples=None,                         │ │
# │ │                    │   │   │   suite=('leaderboard', 'mmlu'),            │ │
# │ │                    │   │   │   original_num_docs=102,                    │ │
# │ │                    │   │   │   effective_num_docs=102,                   │ │
# │ │                    │   │   │   must_remove_duplicate_docs=False,         │ │
# │ │                    │   │   │   version=0                                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   },                                                │ │
# │ │                    │   'summary_tasks': defaultdict(<class               │ │
# │ │                    'lighteval.logging.info_loggers.DetailsLogger.Compil… │ │
# │ │                    {                                                     │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics|0':         │ │
# │ │                    CompiledDetail(                                       │ │
# │ │                    │   │   │   hashes={                                  │ │
# │ │                    │   │   │   │   'hash_examples': 'ebdab1cdb7e555df',  │ │
# │ │                    │   │   │   │   'hash_full_prompts':                  │ │
# │ │                    'ebdab1cdb7e555df',                                   │ │
# │ │                    │   │   │   │   'hash_input_tokens':                  │ │
# │ │                    'f0c8814fdfd4ed8c',                                   │ │
# │ │                    │   │   │   │   'hash_cont_tokens':                   │ │
# │ │                    '928b22b6932f99ca'                                    │ │
# │ │                    │   │   │   },                                        │ │
# │ │                    │   │   │   truncated=0,                              │ │
# │ │                    │   │   │   non_truncated=102,                        │ │
# │ │                    │   │   │   padded=392,                               │ │
# │ │                    │   │   │   non_padded=16,                            │ │
# │ │                    │   │   │   effective_few_shots=0.0,                  │ │
# │ │                    │   │   │   num_truncated_few_shots=0                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'summary_general': {                              │ │
# │ │                    │   │   'hashes': {                                   │ │
# │ │                    │   │   │   'hash_examples': '51e0fc9d449f6a6d',      │ │
# │ │                    │   │   │   'hash_full_prompts': '51e0fc9d449f6a6d',  │ │
# │ │                    │   │   │   'hash_input_tokens': 'a4a57da07a18ea04',  │ │
# │ │                    │   │   │   'hash_cont_tokens': '0f55f6e6c4edd430'    │ │
# │ │                    │   │   },                                            │ │
# │ │                    │   │   'truncated': 0,                               │ │
# │ │                    │   │   'non_truncated': 102,                         │ │
# │ │                    │   │   'padded': 392,                                │ │
# │ │                    │   │   'non_padded': 16,                             │ │
# │ │                    │   │   'num_truncated_few_shots': 0                  │ │
# │ │                    │   }                                                 │ │
# │ │                    }                                                     │ │
# │ │             self = <lighteval.logging.evaluation_tracker.EvaluationTrac… │ │
# │ │                    object at 0x741833b37340>                             │ │
# │ │     task_details = [                                                     │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about college physics'+346,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+3,                                           │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+346,                                         │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-1.4140625, True),                       │ │
# │ │                    │   │   │   (-1.6640625, False),                      │ │
# │ │                    │   │   │   (-1.6640625, False),                      │ │
# │ │                    │   │   │   (-1.5390625, False)                       │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ]                                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   cont_tokens=[[330], [389], [340], [422]],     │ │
# │ │                    │   │   truncated=[0, 0, 0, 0],                       │ │
# │ │                    │   │   padded=[18, 18, 18, 18],                      │ │
# │ │                    │   │   gold=[],                                      │ │
# │ │                    │   │   pred_logits=[],                               │ │
# │ │                    │   │   choices=[' A', ' B', ' C', ' D'],             │ │
# │ │                    │   │   gold_index=[1],                               │ │
# │ │                    │   │   metrics={'acc': 0},                           │ │
# │ │                    │   │   specifics=None                                │ │
# │ │                    │   ),                                                │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about college physics'+216,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+3,                                           │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+216,                                         │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-1.390625, True),                        │ │
# │ │                    │   │   │   (-1.515625, False),                       │ │
# │ │                    │   │   │   (-1.765625, False),                       │ │
# │ │                    │   │   │   (-1.890625, False)                        │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +75                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# ...
# │ │                      │   │   │   hf_filter=None,                         │ │
# │ │                      │   │   │   hf_avail_splits=(                       │ │
# │ │                      │   │   │   │   'auxiliary_train',                  │ │
# │ │                      │   │   │   │   'test',                             │ │
# │ │                      │   │   │   │   'validation',                       │ │
# │ │                      │   │   │   │   'dev'                               │ │
# │ │                      │   │   │   ),                                      │ │
# │ │                      │   │   │   trust_dataset=True,                     │ │
# │ │                      │   │   │   evaluation_splits=('test',),            │ │
# │ │                      │   │   │   few_shots_split='dev',                  │ │
# │ │                      │   │   │   few_shots_select='sequential',          │ │
# │ │                      │   │   │   generation_size=1,                      │ │
# │ │                      │   │   │   generation_grammar=None,                │ │
# │ │                      │   │   │   stop_sequence=('\n',),                  │ │
# │ │                      │   │   │   num_samples=None,                       │ │
# │ │                      │   │   │   suite=('leaderboard', 'mmlu'),          │ │
# │ │                      │   │   │   original_num_docs=102,                  │ │
# │ │                      │   │   │   effective_num_docs=102,                 │ │
# │ │                      │   │   │   must_remove_duplicate_docs=False,       │ │
# │ │                      │   │   │   version=0                               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   },                                              │ │
# │ │                      │   'summary_tasks': defaultdict(<class             │ │
# │ │                      'lighteval.logging.info_loggers.DetailsLogger.Comp… │ │
# │ │                      {                                                   │ │
# │ │                      │   │   'leaderboard|mmlu:college_physics|0':       │ │
# │ │                      CompiledDetail(                                     │ │
# │ │                      │   │   │   hashes={                                │ │
# │ │                      │   │   │   │   'hash_examples':                    │ │
# │ │                      'ebdab1cdb7e555df',                                 │ │
# │ │                      │   │   │   │   'hash_full_prompts':                │ │
# │ │                      'ebdab1cdb7e555df',                                 │ │
# │ │                      │   │   │   │   'hash_input_tokens':                │ │
# │ │                      'f0c8814fdfd4ed8c',                                 │ │
# │ │                      │   │   │   │   'hash_cont_tokens':                 │ │
# │ │                      '928b22b6932f99ca'                                  │ │
# │ │                      │   │   │   },                                      │ │
# │ │                      │   │   │   truncated=0,                            │ │
# │ │                      │   │   │   non_truncated=102,                      │ │
# │ │                      │   │   │   padded=392,                             │ │
# │ │                      │   │   │   non_padded=16,                          │ │
# │ │                      │   │   │   effective_few_shots=0.0,                │ │
# │ │                      │   │   │   num_truncated_few_shots=0               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   }),                                             │ │
# │ │                      │   'summary_general': {                            │ │
# │ │                      │   │   'hashes': {                                 │ │
# │ │                      │   │   │   'hash_examples': '51e0fc9d449f6a6d',    │ │
# │ │                      │   │   │   'hash_full_prompts':                    │ │
# │ │                      '51e0fc9d449f6a6d',                                 │ │
# │ │                      │   │   │   'hash_input_tokens':                    │ │
# │ │                      'a4a57da07a18ea04',                                 │ │
# │ │                      │   │   │   'hash_cont_tokens': '0f55f6e6c4edd430'  │ │
# │ │                      │   │   },                                          │ │
# │ │                      │   │   'truncated': 0,                             │ │
# │ │                      │   │   'non_truncated': 102,                       │ │
# │ │                      │   │   'padded': 392,                              │ │
# │ │                      │   │   'non_padded': 16,                           │ │
# │ │                      │   │   'num_truncated_few_shots': 0                │ │
# │ │                      │   }                                               │ │
# │ │                      }                                                   │ │
# │ │               self = <lighteval.logging.evaluation_tracker.EvaluationTr… │ │
# │ │                      object at 0x741833b37340>                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /spec.py:1589 in mkdirs                                                      │
# │                                                                              │
# │   1586 │                                                                     │
# │   1587 │   def mkdirs(self, path, exist_ok=False):                           │
# │   1588 │   │   """Alias of `AbstractFileSystem.makedirs`."""                 │
# │ ❱ 1589 │   │   return self.makedirs(path, exist_ok=exist_ok)                 │
# │   1590 │                                                                     │
# │   1591 │   def listdir(self, path, detail=True, **kwargs):                   │
# │   1592 │   │   """Alias of `AbstractFileSystem.ls`."""                       │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = PosixPath('/content/360M_output/results/HuggingFaceTB/SmolLM… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x741833b36800>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /implementations/local.py:52 in makedirs                                     │
# │                                                                              │
# │    49 │                                                                      │
# │    50 │   def makedirs(self, path, exist_ok=False):                          │
# │    51 │   │   path = self._strip_protocol(path)                              │
# │ ❱  52 │   │   os.makedirs(path, exist_ok=exist_ok)                           │
# │    53 │                                                                      │
# │    54 │   def rmdir(self, path):                                             │
# │    55 │   │   path = self._strip_protocol(path)                              │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = '/content/360M_output/results/HuggingFaceTB/SmolLM2-360M'     │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x741833b36800>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭─────────────────────────────── locals ───────────────────────────────╮     │
# │ │ exist_ok = True                                                      │     │
# │ │     head = '/content/360M_output/results/HuggingFaceTB'              │     │
# │ │     mode = 511                                                       │     │
# │ │     name = '/content/360M_output/results/HuggingFaceTB/SmolLM2-360M' │     │
# │ │     tail = 'SmolLM2-360M'                                            │     │
# │ ╰──────────────────────────────────────────────────────────────────────╯     │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭──────────────────────── locals ─────────────────────────╮                  │
# │ │ exist_ok = True                                         │                  │
# │ │     head = '/content/360M_output/results'               │                  │
# │ │     mode = 511                                          │                  │
# │ │     name = '/content/360M_output/results/HuggingFaceTB' │                  │
# │ │     tail = 'HuggingFaceTB'                              │                  │
# │ ╰─────────────────────────────────────────────────────────╯                  │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────── locals ──────────────────╮                                │
# │ │ exist_ok = True                           │                                │
# │ │     head = '/content/360M_output'         │                                │
# │ │     mode = 511                            │                                │
# │ │     name = '/content/360M_output/results' │                                │
# │ │     tail = 'results'                      │                                │
# │ ╰───────────────────────────────────────────╯                                │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────── locals ──────────────╮                                        │
# │ │ exist_ok = True                   │                                        │
# │ │     head = '/content'             │                                        │
# │ │     mode = 511                    │                                        │
# │ │     name = '/content/360M_output' │                                        │
# │ │     tail = '360M_output'          │                                        │
# │ ╰───────────────────────────────────╯                                        │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:225 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    222 │   │   if tail == cdir:           # xxx/newdir/. exists if xxx/newdi │
# │    223 │   │   │   return                                                    │
# │    224 │   try:                                                              │
# │ ❱  225 │   │   mkdir(name, mode)                                             │
# │    226 │   except OSError:                                                   │
# │    227 │   │   # Cannot rely on checking for EEXIST, since the operating sys │
# │    228 │   │   # could give priority to other errors like EACCES or EROFS    │
# │                                                                              │
# │ ╭─────── locals ────────╮                                                    │
# │ │ exist_ok = True       │                                                    │
# │ │     head = '/'        │                                                    │
# │ │     mode = 511        │                                                    │
# │ │     name = '/content' │                                                    │
# │ │     tail = 'content'  │                                                    │
# │ ╰───────────────────────╯                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
MODEL="akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel-ai-physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:college_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [2025-03-05 12:25:19,887] [    INFO]: PyTorch version 2.4.1 available. (config.py:54)
# [2025-03-05 12:25:21,960] [    INFO]: Test gather tensor (parallelism.py:133)
# [2025-03-05 12:25:22,038] [    INFO]: gathered_tensor tensor([0], device='cuda:0'), should be [0] (parallelism.py:136)
# [2025-03-05 12:25:22,038] [    INFO]: --- LOADING MODEL --- (pipeline.py:168)
# [2025-03-05 12:25:22,310] [    INFO]: Tokenizer truncation and padding size set to the left side. (transformers_model.py:539)
# [2025-03-05 12:25:22,557] [    INFO]: Setting model parallel to True since the number of local processes is 1 and the number of GPUs is 4 (transformers_model.py:402)
# [2025-03-05 12:25:22,558] [    INFO]: Model parallel was set to True, setting max memory per GPU to {0: 10169221120, 1: 15557066752, 2: 15557066752, 3: 15573843968} and device map to auto (transformers_model.py:417)
# [2025-03-05 12:25:23,807] [    INFO]: --- LOADING TASKS --- (pipeline.py:195)
# [2025-03-05 12:25:23,807] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:136)
# [2025-03-05 12:25:23,809] [    INFO]: lighteval/mmlu college_physics (lighteval_task.py:187)
# [2025-03-05 12:25:24,711] [    INFO]: --- INIT SEEDS --- (pipeline.py:224)
# [2025-03-05 12:25:24,711] [    INFO]: --- RUNNING MODEL --- (pipeline.py:267)
# [2025-03-05 12:25:24,711] [    INFO]: Running RequestType.LOGLIKELIHOOD requests (pipeline.py:271)
# 0it [00:00, ?it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▍                                      | 1/7 [00:00<00:02,  2.59it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00,  7.12it/s]
#  71%|████████████████████████████████▏            | 5/7 [00:00<00:00, 10.37it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00,  9.90it/s]
# 1it [00:00,  1.41it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00, 22.17it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 22.72it/s]
# 2it [00:01,  2.11it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00, 23.28it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 23.63it/s]
# 3it [00:01,  2.55it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00, 21.12it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 23.09it/s]
# 4it [00:01,  2.47it/s]
# [2025-03-05 12:25:26,444] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:299)
# [2025-03-05 12:25:26,448] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:342)
# [2025-03-05 12:25:26,448] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# |               Task               |Version|Metric|Value |   |Stderr|
# |----------------------------------|------:|------|-----:|---|-----:|
# |all                               |       |acc   |0.1961|±  |0.0395|
# |leaderboard:mmlu:college_physics:0|      0|acc   |0.1961|±  |0.0395|
#
# [2025-03-05 12:25:26,461] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:332)
# [2025-03-05 12:25:26,461] [    INFO]: Saving experiment tracker (evaluation_tracker.py:154)
# [2025-03-05 12:25:26,461] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/main_accelerate.py:207 in accelerate                                     │
# │                                                                              │
# │   204 │                                                                      │
# │   205 │   results = pipeline.get_results()                                   │
# │   206 │                                                                      │
# │ ❱ 207 │   pipeline.save_and_push_results()                                   │
# │   208 │                                                                      │
# │   209 │   return results                                                     │
# │   210                                                                        │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │               accelerator = <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x7751839d86d0>                           │ │
# │ │                 cache_dir = None                                         │ │
# │ │              custom_tasks = None                                         │ │
# │ │ dataset_loading_processes = 1                                            │ │
# │ │                env_config = EnvConfig(cache_dir=None, token=None)        │ │
# │ │        evaluation_tracker = <lighteval.logging.evaluation_tracker.Evalu… │ │
# │ │                             object at 0x775181167fd0>                    │ │
# │ │                    job_id = 0                                            │ │
# │ │               max_samples = None                                         │ │
# │ │                model_args = 'pretrained=akhilfau/fine-tuned-smolLM2-360… │ │
# │ │           model_args_dict = {                                            │ │
# │ │                             │   'pretrained':                            │ │
# │ │                             'akhilfau/fine-tuned-smolLM2-360M-with-LoRA… │ │
# │ │                             │   'accelerator':                           │ │
# │ │                             <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x7751839d86d0>,                          │ │
# │ │                             │   'use_chat_template': False,              │ │
# │ │                             │   'compile': False                         │ │
# │ │                             }                                            │ │
# │ │              model_config = TransformersModelConfig(                     │ │
# │ │                             │                                            │ │
# │ │                             pretrained='akhilfau/fine-tuned-smolLM2-360… │ │
# │ │                             │                                            │ │
# │ │                             accelerator=<accelerate.accelerator.Acceler… │ │
# │ │                             object at 0x7751839d86d0>,                   │ │
# │ │                             │   tokenizer=None,                          │ │
# │ │                             │                                            │ │
# │ │                             multichoice_continuations_start_space=None,  │ │
# │ │                             │   pairwise_tokenization=False,             │ │
# │ │                             │   subfolder=None,                          │ │
# │ │                             │   revision='main',                         │ │
# │ │                             │   batch_size=-1,                           │ │
# │ │                             │   max_gen_toks=256,                        │ │
# │ │                             │   max_length=None,                         │ │
# │ │                             │   add_special_tokens=True,                 │ │
# │ │                             │   model_parallel=True,                     │ │
# │ │                             │   dtype=None,                              │ │
# │ │                             │   device='cuda',                           │ │
# │ │                             │   quantization_config=None,                │ │
# │ │                             │   trust_remote_code=False,                 │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   compile=False,                           │ │
# │ │                             │                                            │ │
# │ │                             generation_parameters=GenerationParameters(  │ │
# │ │                             │   │   early_stopping=None,                 │ │
# │ │                             │   │   repetition_penalty=None,             │ │
# │ │                             │   │   frequency_penalty=None,              │ │
# │ │                             │   │   length_penalty=None,                 │ │
# │ │                             │   │   presence_penalty=None,               │ │
# │ │                             │   │   max_new_tokens=None,                 │ │
# │ │                             │   │   min_new_tokens=None,                 │ │
# │ │                             │   │   seed=None,                           │ │
# │ │                             │   │   stop_tokens=None,                    │ │
# │ │                             │   │   temperature=None,                    │ │
# │ │                             │   │   top_k=None,                          │ │
# │ │                             │   │   min_p=None,                          │ │
# │ │                             │   │   top_p=None,                          │ │
# │ │                             │   │   truncate_prompt=None                 │ │
# │ │                             │   ),                                       │ │
# │ │                             │   generation_config=None                   │ │
# │ │                             )                                            │ │
# │ │         num_fewshot_seeds = 1                                            │ │
# │ │                output_dir = '/content/360M_output'                       │ │
# │ │       override_batch_size = 16                                           │ │
# │ │                  pipeline = <lighteval.pipeline.Pipeline object at       │ │
# │ │                             0x775181166680>                              │ │
# │ │           pipeline_params = PipelineParameters(                          │ │
# │ │                             │                                            │ │
# │ │                             launcher_type=<ParallelismManager.ACCELERAT… │ │
# │ │                             1>,                                          │ │
# │ │                             │   env_config=EnvConfig(                    │ │
# │ │                             │   │   cache_dir=None,                      │ │
# │ │                             │   │   token=None                           │ │
# │ │                             │   ),                                       │ │
# │ │                             │   job_id=0,                                │ │
# │ │                             │   dataset_loading_processes=1,             │ │
# │ │                             │   nanotron_checkpoint_path=None,           │ │
# │ │                             │   custom_tasks_directory=None,             │ │
# │ │                             │   override_batch_size=16,                  │ │
# │ │                             │   num_fewshot_seeds=1,                     │ │
# │ │                             │   max_samples=None,                        │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   system_prompt=None                       │ │
# │ │                             )                                            │ │
# │ │                public_run = False                                        │ │
# │ │               push_to_hub = False                                        │ │
# │ │       push_to_tensorboard = False                                        │ │
# │ │                   results = {                                            │ │
# │ │                             │   'config_general': {                      │ │
# │ │                             │   │   'lighteval_sha': '?',                │ │
# │ │                             │   │   'num_fewshot_seeds': 1,              │ │
# │ │                             │   │   'override_batch_size': 16,           │ │
# │ │                             │   │   'max_samples': None,                 │ │
# │ │                             │   │   'job_id': 0,                         │ │
# │ │                             │   │   'start_time': 82662.11117918,        │ │
# │ │                             │   │   'end_time': 82666.600546877,         │ │
# │ │                             │   │   'total_evaluation_time_secondes':    │ │
# │ │                             '4.489367696995032',                         │ │
# │ │                             │   │   'model_name':                        │ │
# │ │                             'akhilfau/fine-tuned-smolLM2-360M-with-LoRA… │ │
# │ │                             │   │   'model_sha':                         │ │
# │ │                             'dac3187866a397c41b9c0a8c26c74f374ab68174',  │ │
# │ │                             │   │   ... +3                               │ │
# │ │                             │   },                                       │ │
# │ │                             │   'results': {                             │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:college_physics:0':        │ │
# │ │                             defaultdict(<class 'float'>, {               │ │
# │ │                             │   │   │   'acc': 0.19607843137254902,      │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.03950581861179963                          │ │
# │ │                             │   │   }),                                  │ │
# │ │                             │   │   'all': {                             │ │
# │ │                             │   │   │   'acc': 0.19607843137254902,      │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.03950581861179963                          │ │
# │ │                             │   │   }                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'versions': {                            │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:college_physics:0': 0      │ │
# │ │                             │   },                                       │ │
# │ │                             │   'config_tasks': {                        │ │
# │ │                             │   │   'leaderboard:mmlu:college_physics':  │ │
# │ │                             LightevalTaskConfig(                         │ │
# │ │                             │   │   │   name='mmlu:college_physics',     │ │
# │ │                             │   │   │   prompt_function=<function        │ │
# │ │                             mmlu_harness at 0x775181bb45e0>,             │ │
# │ │                             │   │   │   hf_repo='lighteval/mmlu',        │ │
# │ │                             │   │   │   hf_subset='college_physics',     │ │
# │ │                             │   │   │   metric=(                         │ │
# │ │                             │   │   │   │   SampleLevelMetric(           │ │
# │ │                             │   │   │   │   │   metric_name='acc',       │ │
# │ │                             │   │   │   │   │   higher_is_better=True,   │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             category=<MetricCategory.MULTICHOICE: '8'>,  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             use_case=<MetricUseCase.ACCURACY: '1'>,      │ │
# │ │                             │   │   │   │   │   sample_level_fn=<bound   │ │
# │ │                             method LoglikelihoodAcc.compute of           │ │
# │ │                             <lighteval.metrics.metrics_sample.Loglikeli… │ │
# │ │                             object at 0x775183948790>>,                  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             corpus_level_fn=<function mean at            │ │
# │ │                             0x77537cf03830>                              │ │
# │ │                             │   │   │   │   ),                           │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   hf_revision=None,                │ │
# │ │                             │   │   │   hf_filter=None,                  │ │
# │ │                             │   │   │   hf_avail_splits=(                │ │
# │ │                             │   │   │   │   'auxiliary_train',           │ │
# │ │                             │   │   │   │   'test',                      │ │
# │ │                             │   │   │   │   'validation',                │ │
# │ │                             │   │   │   │   'dev'                        │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   trust_dataset=True,              │ │
# │ │                             │   │   │   evaluation_splits=('test',),     │ │
# │ │                             │   │   │   few_shots_split='dev',           │ │
# │ │                             │   │   │   few_shots_select='sequential',   │ │
# │ │                             │   │   │   generation_size=1,               │ │
# │ │                             │   │   │   generation_grammar=None,         │ │
# │ │                             │   │   │   stop_sequence=('\n',),           │ │
# │ │                             │   │   │   num_samples=None,                │ │
# │ │                             │   │   │   suite=('leaderboard', 'mmlu'),   │ │
# │ │                             │   │   │   original_num_docs=102,           │ │
# │ │                             │   │   │   effective_num_docs=102,          │ │
# │ │                             │   │   │                                    │ │
# │ │                             must_remove_duplicate_docs=False,            │ │
# │ │                             │   │   │   version=0                        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_tasks': {                       │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:college_physics:0':        │ │
# │ │                             CompiledDetail(                              │ │
# │ │                             │   │   │   hashes={                         │ │
# │ │                             │   │   │   │   'hash_examples':             │ │
# │ │                             'ebdab1cdb7e555df',                          │ │
# │ │                             │   │   │   │   'hash_full_prompts':         │ │
# │ │                             'ebdab1cdb7e555df',                          │ │
# │ │                             │   │   │   │   'hash_input_tokens':         │ │
# │ │                             'f0c8814fdfd4ed8c',                          │ │
# │ │                             │   │   │   │   'hash_cont_tokens':          │ │
# │ │                             '928b22b6932f99ca'                           │ │
# │ │                             │   │   │   },                               │ │
# │ │                             │   │   │   truncated=0,                     │ │
# │ │                             │   │   │   non_truncated=102,               │ │
# │ │                             │   │   │   padded=392,                      │ │
# │ │                             │   │   │   non_padded=16,                   │ │
# │ │                             │   │   │   effective_few_shots=0.0,         │ │
# │ │                             │   │   │   num_truncated_few_shots=0        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_general': {                     │ │
# │ │                             │   │   'hashes': {                          │ │
# │ │                             │   │   │   'hash_examples':                 │ │
# │ │                             '51e0fc9d449f6a6d',                          │ │
# │ │                             │   │   │   'hash_full_prompts':             │ │
# │ │                             '51e0fc9d449f6a6d',                          │ │
# │ │                             │   │   │   'hash_input_tokens':             │ │
# │ │                             'a4a57da07a18ea04',                          │ │
# │ │                             │   │   │   'hash_cont_tokens':              │ │
# │ │                             '0f55f6e6c4edd430'                           │ │
# │ │                             │   │   },                                   │ │
# │ │                             │   │   'truncated': 0,                      │ │
# │ │                             │   │   'non_truncated': 102,                │ │
# │ │                             │   │   'padded': 392,                       │ │
# │ │                             │   │   'non_padded': 16,                    │ │
# │ │                             │   │   'num_truncated_few_shots': 0         │ │
# │ │                             │   }                                        │ │
# │ │                             }                                            │ │
# │ │               results_org = None                                         │ │
# │ │              save_details = False                                        │ │
# │ │             system_prompt = None                                         │ │
# │ │                     tasks = 'leaderboard|mmlu:college_physics|0|0'       │ │
# │ │                     torch = <module 'torch' from                         │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ │         use_chat_template = False                                        │ │
# │ │                      yaml = <module 'yaml' from                          │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/pipeline.py:334 in save_and_push_results                                 │
# │                                                                              │
# │   331 │   def save_and_push_results(self):                                   │
# │   332 │   │   logger.info("--- SAVING AND PUSHING RESULTS ---")              │
# │   333 │   │   if self.is_main_process():                                     │
# │ ❱ 334 │   │   │   self.evaluation_tracker.save()                             │
# │   335 │                                                                      │
# │   336 │   def _init_final_dict(self):                                        │
# │   337 │   │   if self.is_main_process():                                     │
# │                                                                              │
# │ ╭─────────────────────────── locals ────────────────────────────╮            │
# │ │ self = <lighteval.pipeline.Pipeline object at 0x775181166680> │            │
# │ ╰───────────────────────────────────────────────────────────────╯            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/logging/evaluation_tracker.py:187 in save                                │
# │                                                                              │
# │   184 │   │   │   details_datasets[task_name] = dataset                      │
# │   185 │   │                                                                  │
# │   186 │   │   # We save results at every case                                │
# │ ❱ 187 │   │   self.save_results(date_id, results_dict)                       │
# │   188 │   │                                                                  │
# │   189 │   │   if self.should_save_details:                                   │
# │   190 │   │   │   self.save_details(date_id, details_datasets)               │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │     column_names = [                                                     │ │
# │ │                    │   'example',                                        │ │
# │ │                    │   'instruction',                                    │ │
# │ │                    │   'full_prompt',                                    │ │
# │ │                    │   'num_effective_few_shots',                        │ │
# │ │                    │   'num_asked_few_shots',                            │ │
# │ │                    │   'predictions',                                    │ │
# │ │                    │   'input_tokens',                                   │ │
# │ │                    │   'cont_tokens',                                    │ │
# │ │                    │   'truncated',                                      │ │
# │ │                    │   'padded',                                         │ │
# │ │                    │   ... +6                                            │ │
# │ │                    ]                                                     │ │
# │ │   config_general = {                                                     │ │
# │ │                    │   'lighteval_sha': '?',                             │ │
# │ │                    │   'num_fewshot_seeds': 1,                           │ │
# │ │                    │   'override_batch_size': 16,                        │ │
# │ │                    │   'max_samples': None,                              │ │
# │ │                    │   'job_id': 0,                                      │ │
# │ │                    │   'start_time': 82662.11117918,                     │ │
# │ │                    │   'end_time': 82666.600546877,                      │ │
# │ │                    │   'total_evaluation_time_secondes':                 │ │
# │ │                    '4.489367696995032',                                  │ │
# │ │                    │   'model_name':                                     │ │
# │ │                    'akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel… │ │
# │ │                    │   'model_sha':                                      │ │
# │ │                    'dac3187866a397c41b9c0a8c26c74f374ab68174',           │ │
# │ │                    │   ... +2                                            │ │
# │ │                    }                                                     │ │
# │ │          dataset = Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 102                                     │ │
# │ │                    })                                                    │ │
# │ │          date_id = '2025-03-05T12-25-26.461558'                          │ │
# │ │ details_datasets = {                                                     │ │
# │ │                    │   'leaderboard|mmlu:college_physics|0': Dataset({   │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 102                                     │ │
# │ │                    })                                                    │ │
# │ │                    }                                                     │ │
# │ │     results_dict = {                                                     │ │
# │ │                    │   'config_general': {                               │ │
# │ │                    │   │   'lighteval_sha': '?',                         │ │
# │ │                    │   │   'num_fewshot_seeds': 1,                       │ │
# │ │                    │   │   'override_batch_size': 16,                    │ │
# │ │                    │   │   'max_samples': None,                          │ │
# │ │                    │   │   'job_id': 0,                                  │ │
# │ │                    │   │   'start_time': 82662.11117918,                 │ │
# │ │                    │   │   'end_time': 82666.600546877,                  │ │
# │ │                    │   │   'total_evaluation_time_secondes':             │ │
# │ │                    '4.489367696995032',                                  │ │
# │ │                    │   │   'model_name':                                 │ │
# │ │                    'akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel… │ │
# │ │                    │   │   'model_sha':                                  │ │
# │ │                    'dac3187866a397c41b9c0a8c26c74f374ab68174',           │ │
# │ │                    │   │   ... +2                                        │ │
# │ │                    │   },                                                │ │
# │ │                    │   'results': defaultdict(<function                  │ │
# │ │                    MetricsLogger.<lambda>.<locals>.<lambda> at           │ │
#                  0x77518116dcf0>, {                                    │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics|0':         │ │
# │ │                    defaultdict(<class 'float'>, {                        │ │
# │ │                    │   │   │   'acc': 0.19607843137254902,               │ │
# │ │                    │   │   │   'acc_stderr': 0.03950581861179963         │ │
# │ │                    │   │   }),                                           │ │
# │ │                    │   │   'all': {                                      │ │
# │ │                    │   │   │   'acc': 0.19607843137254902,               │ │
# │ │                    │   │   │   'acc_stderr': 0.03950581861179963         │ │
# │ │                    │   │   }                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'versions': {                                     │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics|0': 0       │ │
# │ │                    │   },                                                │ │
# │ │                    │   'config_tasks': {                                 │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics':           │ │
# │ │                    LightevalTaskConfig(                                  │ │
# │ │                    │   │   │   name='mmlu:college_physics',              │ │
# │ │                    │   │   │   prompt_function=<function mmlu_harness at │ │
# │ │                    0x775181bb45e0>,                                      │ │
# │ │                    │   │   │   hf_repo='lighteval/mmlu',                 │ │
# │ │                    │   │   │   hf_subset='college_physics',              │ │
# │ │                    │   │   │   metric=(                                  │ │
# │ │                    │   │   │   │   SampleLevelMetric(                    │ │
# │ │                    │   │   │   │   │   metric_name='acc',                │ │
# │ │                    │   │   │   │   │   higher_is_better=True,            │ │
# │ │                    │   │   │   │   │                                     │ │
# │ │                    category=<MetricCategory.MULTICHOICE: '8'>,           │ │
# │ │                    │   │   │   │   │   use_case=<MetricUseCase.ACCURACY: │ │
# │ │                    '1'>,                                                 │ │
# │ │                    │   │   │   │   │   sample_level_fn=<bound method     │ │
# │ │                    LoglikelihoodAcc.compute of                           │ │
# │ │                    <lighteval.metrics.metrics_sample.LoglikelihoodAcc    │ │
# │ │                    object at 0x775183948790>>,                           │ │
# │ │                    │   │   │   │   │   corpus_level_fn=<function mean at │ │
# │ │                    0x77537cf03830>                                       │ │
# │ │                    │   │   │   │   ),                                    │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   hf_revision=None,                         │ │
# │ │                    │   │   │   hf_filter=None,                           │ │
# │ │                    │   │   │   hf_avail_splits=(                         │ │
# │ │                    │   │   │   │   'auxiliary_train',                    │ │
# │ │                    │   │   │   │   'test',                               │ │
# │ │                    │   │   │   │   'validation',                         │ │
# │ │                    │   │   │   │   'dev'                                 │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   trust_dataset=True,                       │ │
# │ │                    │   │   │   evaluation_splits=('test',),              │ │
# │ │                    │   │   │   few_shots_split='dev',                    │ │
# │ │                    │   │   │   few_shots_select='sequential',            │ │
# │ │                    │   │   │   generation_size=1,                        │ │
# │ │                    │   │   │   generation_grammar=None,                  │ │
# │ │                    │   │   │   stop_sequence=('\n',),                    │ │
# │ │                    │   │   │   num_samples=None,                         │ │
# │ │                    │   │   │   suite=('leaderboard', 'mmlu'),            │ │
# │ │                    │   │   │   original_num_docs=102,                    │ │
# │ │                    │   │   │   effective_num_docs=102,                   │ │
# │ │                    │   │   │   must_remove_duplicate_docs=False,         │ │
# │ │                    │   │   │   version=0                                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   },                                                │ │
# │ │                    │   'summary_tasks': defaultdict(<class               │ │
# │ │                    'lighteval.logging.info_loggers.DetailsLogger.Compil… │ │
# │ │                    {                                                     │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics|0':         │ │
# │ │                    CompiledDetail(                                       │ │
# │ │                    │   │   │   hashes={                                  │ │
# │ │                    │   │   │   │   'hash_examples': 'ebdab1cdb7e555df',  │ │
# │ │                    │   │   │   │   'hash_full_prompts':                  │ │
# │ │                    'ebdab1cdb7e555df',                                   │ │
# │ │                    │   │   │   │   'hash_input_tokens':                  │ │
# │ │                    'f0c8814fdfd4ed8c',                                   │ │
# │ │                    │   │   │   │   'hash_cont_tokens':                   │ │
# │ │                    '928b22b6932f99ca'                                    │ │
# │ │                    │   │   │   },                                        │ │
# │ │                    │   │   │   truncated=0,                              │ │
# │ │                    │   │   │   non_truncated=102,                        │ │
# │ │                    │   │   │   padded=392,                               │ │
# │ │                    │   │   │   non_padded=16,                            │ │
# │ │                    │   │   │   effective_few_shots=0.0,                  │ │
# │ │                    │   │   │   num_truncated_few_shots=0                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'summary_general': {                              │ │
# │ │                    │   │   'hashes': {                                   │ │
# │ │                    │   │   │   'hash_examples': '51e0fc9d449f6a6d',      │ │
# │ │                    │   │   │   'hash_full_prompts': '51e0fc9d449f6a6d',  │ │
# │ │                    │   │   │   'hash_input_tokens': 'a4a57da07a18ea04',  │ │
# │ │                    │   │   │   'hash_cont_tokens': '0f55f6e6c4edd430'    │ │
# │ │                    │   │   },                                            │ │
# │ │                    │   │   'truncated': 0,                               │ │
# │ │                    │   │   'non_truncated': 102,                         │ │
# │ │                    │   │   'padded': 392,                                │ │
# │ │                    │   │   'non_padded': 16,                             │ │
# │ │                    │   │   'num_truncated_few_shots': 0                  │ │
# │ │                    │   }                                                 │ │
# │ │                    }                                                     │ │
# │ │             self = <lighteval.logging.evaluation_tracker.EvaluationTrac… │ │
# │ │                    object at 0x775181167fd0>                             │ │
# │ │     task_details = [                                                     │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about college physics'+346,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+3,                                           │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+346,                                         │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-0.97265625, True),                      │ │
# │ │                    │   │   │   (-2.09375, False),                        │ │
# │ │                    │   │   │   (-1.7265625, False),                      │ │
# │ │                    │   │   │   (-1.7265625, False)                       │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ]                                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   cont_tokens=[[330], [389], [340], [422]],     │ │
# │ │                    │   │   truncated=[0, 0, 0, 0],                       │ │
# │ │                    │   │   padded=[18, 18, 18, 18],                      │ │
# │ │                    │   │   gold=[],                                      │ │
# │ │                    │   │   pred_logits=[],                               │ │
# │ │                    │   │   choices=[' A', ' B', ' C', ' D'],             │ │
# │ │                    │   │   gold_index=[1],                               │ │
# │ │                    │   │   metrics={'acc': 0},                           │ │
# │ │                    │   │   specifics=None                                │ │
# │ │                    │   ),                                                │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about college physics'+216,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+3,                                           │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+216,                                         │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-0.84765625, True),                      │ │
# │ │                    │   │   │   (-1.71875, False),                        │ │
# │ │                    │   │   │   (-2.09375, False),                        │ │
# │ │                    │   │   │   (-2.34375, False)                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +75                               │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# ...
# │ │                      │   │   │   hf_filter=None,                         │ │
# │ │                      │   │   │   hf_avail_splits=(                       │ │
# │ │                      │   │   │   │   'auxiliary_train',                  │ │
# │ │                      │   │   │   │   'test',                             │ │
# │ │                      │   │   │   │   'validation',                       │ │
# │ │                      │   │   │   │   'dev'                               │ │
# │ │                      │   │   │   ),                                      │ │
# │ │                      │   │   │   trust_dataset=True,                     │ │
# │ │                      │   │   │   evaluation_splits=('test',),            │ │
# │ │                      │   │   │   few_shots_split='dev',                  │ │
# │ │                      │   │   │   few_shots_select='sequential',          │ │
# │ │                      │   │   │   generation_size=1,                      │ │
# │ │                      │   │   │   generation_grammar=None,                │ │
# │ │                      │   │   │   stop_sequence=('\n',),                  │ │
# │ │                      │   │   │   num_samples=None,                       │ │
# │ │                      │   │   │   suite=('leaderboard', 'mmlu'),          │ │
# │ │                      │   │   │   original_num_docs=102,                  │ │
# │ │                      │   │   │   effective_num_docs=102,                 │ │
# │ │                      │   │   │   must_remove_duplicate_docs=False,       │ │
# │ │                      │   │   │   version=0                               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   },                                              │ │
# │ │                      │   'summary_tasks': defaultdict(<class             │ │
# │ │                      'lighteval.logging.info_loggers.DetailsLogger.Comp… │ │
# │ │                      {                                                   │ │
# │ │                      │   │   'leaderboard|mmlu:college_physics|0':       │ │
# │ │                      CompiledDetail(                                     │ │
# │ │                      │   │   │   hashes={                                │ │
# │ │                      │   │   │   │   'hash_examples':                    │ │
# │ │                      'ebdab1cdb7e555df',                                 │ │
# │ │                      │   │   │   │   'hash_full_prompts':                │ │
# │ │                      'ebdab1cdb7e555df',                                 │ │
# │ │                      │   │   │   │   'hash_input_tokens':                │ │
# │ │                      'f0c8814fdfd4ed8c',                                 │ │
# │ │                      │   │   │   │   'hash_cont_tokens':                 │ │
# │ │                      '928b22b6932f99ca'                                  │ │
# │ │                      │   │   │   },                                      │ │
# │ │                      │   │   │   truncated=0,                            │ │
# │ │                      │   │   │   non_truncated=102,                      │ │
# │ │                      │   │   │   padded=392,                             │ │
# │ │                      │   │   │   non_padded=16,                          │ │
# │ │                      │   │   │   effective_few_shots=0.0,                │ │
# │ │                      │   │   │   num_truncated_few_shots=0               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   }),                                             │ │
# │ │                      │   'summary_general': {                            │ │
# │ │                      │   │   'hashes': {                                 │ │
# │ │                      │   │   │   'hash_examples': '51e0fc9d449f6a6d',    │ │
# │ │                      │   │   │   'hash_full_prompts':                    │ │
# │ │                      '51e0fc9d449f6a6d',                                 │ │
# │ │                      │   │   │   'hash_input_tokens':                    │ │
# │ │                      'a4a57da07a18ea04',                                 │ │
# │ │                      │   │   │   'hash_cont_tokens': '0f55f6e6c4edd430'  │ │
# │ │                      │   │   },                                          │ │
# │ │                      │   │   'truncated': 0,                             │ │
# │ │                      │   │   'non_truncated': 102,                       │ │
# │ │                      │   │   'padded': 392,                              │ │
# │ │                      │   │   'non_padded': 16,                           │ │
# │ │                      │   │   'num_truncated_few_shots': 0                │ │
# │ │                      │   }                                               │ │
# │ │                      }                                                   │ │
# │ │               self = <lighteval.logging.evaluation_tracker.EvaluationTr… │ │
# │ │                      object at 0x775181167fd0>                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /spec.py:1589 in mkdirs                                                      │
# │                                                                              │
# │   1586 │                                                                     │
# │   1587 │   def mkdirs(self, path, exist_ok=False):                           │
# │   1588 │   │   """Alias of `AbstractFileSystem.makedirs`."""                 │
# │ ❱ 1589 │   │   return self.makedirs(path, exist_ok=exist_ok)                 │
# │   1590 │                                                                     │
# │   1591 │   def listdir(self, path, detail=True, **kwargs):                   │
# │   1592 │   │   """Alias of `AbstractFileSystem.ls`."""                       │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = PosixPath('/content/360M_output/results/akhilfau/fine-tuned-… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x775181166710>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /implementations/local.py:52 in makedirs                                     │
# │                                                                              │
# │    49 │                                                                      │
# │    50 │   def makedirs(self, path, exist_ok=False):                          │
# │    51 │   │   path = self._strip_protocol(path)                              │
# │ ❱  52 │   │   os.makedirs(path, exist_ok=exist_ok)                           │
# │    53 │                                                                      │
# │    54 │   def rmdir(self, path):                                             │
# │    55 │   │   path = self._strip_protocol(path)                              │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = '/content/360M_output/results/akhilfau/fine-tuned-smolLM2-36… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x775181166710>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     head = '/content/360M_output/results/akhilfau'                       │ │
# │ │     mode = 511                                                           │ │
# │ │     name = '/content/360M_output/results/akhilfau/fine-tuned-smolLM2-36… │ │
# │ │     tail = 'fine-tuned-smolLM2-360M-with-LoRA-on-camel-ai-physics'       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭────────────────────── locals ──────────────────────╮                       │
# │ │ exist_ok = True                                    │                       │
# │ │     head = '/content/360M_output/results'          │                       │
# │ │     mode = 511                                     │                       │
# │ │     name = '/content/360M_output/results/akhilfau' │                       │
# │ │     tail = 'akhilfau'                              │                       │
# │ ╰────────────────────────────────────────────────────╯                       │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────── locals ──────────────────╮                                │
# │ │ exist_ok = True                           │                                │
# │ │     head = '/content/360M_output'         │                                │
# │ │     mode = 511                            │                                │
# │ │     name = '/content/360M_output/results' │                                │
# │ │     tail = 'results'                      │                                │
# │ ╰───────────────────────────────────────────╯                                │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────── locals ──────────────╮                                        │
# │ │ exist_ok = True                   │                                        │
# │ │     head = '/content'             │                                        │
# │ │     mode = 511                    │                                        │
# │ │     name = '/content/360M_output' │                                        │
# │ │     tail = '360M_output'          │                                        │
# │ ╰───────────────────────────────────╯                                        │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:225 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    222 │   │   if tail == cdir:           # xxx/newdir/. exists if xxx/newdi │
# │    223 │   │   │   return                                                    │
# │    224 │   try:                                                              │
# │ ❱  225 │   │   mkdir(name, mode)                                             │
# │    226 │   except OSError:                                                   │
# │    227 │   │   # Cannot rely on checking for EEXIST, since the operating sys │
# │    228 │   │   # could give priority to other errors like EACCES or EROFS    │
# │                                                                              │
# │ ╭─────── locals ────────╮                                                    │
# │ │ exist_ok = True       │                                                    │
# │ │     head = '/'        │                                                    │
# │ │     mode = 511        │                                                    │
# │ │     name = '/content' │                                                    │
# │ │     tail = 'content'  │                                                    │
# │ ╰───────────────────────╯                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
MODEL="akhilfau/Instruction_fine_tuned_on_camel_ai_physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:college_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [2025-03-05 12:26:29,913] [    INFO]: PyTorch version 2.4.1 available. (config.py:54)
# [2025-03-05 12:26:31,890] [    INFO]: Test gather tensor (parallelism.py:133)
# [2025-03-05 12:26:31,965] [    INFO]: gathered_tensor tensor([0], device='cuda:0'), should be [0] (parallelism.py:136)
# [2025-03-05 12:26:31,965] [    INFO]: --- LOADING MODEL --- (pipeline.py:168)
# [2025-03-05 12:26:32,162] [    INFO]: Tokenizer truncation and padding size set to the left side. (transformers_model.py:539)
# [2025-03-05 12:26:32,421] [    INFO]: Setting model parallel to True since the number of local processes is 1 and the number of GPUs is 4 (transformers_model.py:402)
# [2025-03-05 12:26:32,421] [    INFO]: Model parallel was set to True, setting max memory per GPU to {0: 10169221120, 1: 15557066752, 2: 15557066752, 3: 15573843968} and device map to auto (transformers_model.py:417)
# [2025-03-05 12:26:33,062] [    INFO]: --- LOADING TASKS --- (pipeline.py:195)
# [2025-03-05 12:26:33,062] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:136)
# [2025-03-05 12:26:33,064] [    INFO]: lighteval/mmlu college_physics (lighteval_task.py:187)
# [2025-03-05 12:26:33,895] [    INFO]: --- INIT SEEDS --- (pipeline.py:224)
# [2025-03-05 12:26:33,895] [    INFO]: --- RUNNING MODEL --- (pipeline.py:267)
# [2025-03-05 12:26:33,895] [    INFO]: Running RequestType.LOGLIKELIHOOD requests (pipeline.py:271)
# 0it [00:00, ?it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▍                                      | 1/7 [00:00<00:02,  2.54it/s]
#  29%|████████████▊                                | 2/7 [00:00<00:01,  3.93it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00,  4.77it/s]
#  57%|█████████████████████████▋                   | 4/7 [00:00<00:00,  5.28it/s]
#  71%|████████████████████████████████▏            | 5/7 [00:01<00:00,  5.62it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:01<00:00,  5.62it/s]
# 1it [00:01,  1.25s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▍                                      | 1/7 [00:00<00:00,  8.13it/s]
#  29%|████████████▊                                | 2/7 [00:00<00:00,  8.13it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00,  8.10it/s]
#  57%|█████████████████████████▋                   | 4/7 [00:00<00:00,  8.09it/s]
#  71%|████████████████████████████████▏            | 5/7 [00:00<00:00,  8.09it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00,  8.84it/s]
# 2it [00:02,  1.02it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▍                                      | 1/7 [00:00<00:00,  8.89it/s]
#  29%|████████████▊                                | 2/7 [00:00<00:00,  8.91it/s]
#  43%|███████████████████▎                         | 3/7 [00:00<00:00,  8.94it/s]
#  57%|█████████████████████████▋                   | 4/7 [00:00<00:00,  8.92it/s]
#  71%|████████████████████████████████▏            | 5/7 [00:00<00:00,  8.91it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00,  9.66it/s]
# 3it [00:02,  1.16it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  29%|████████████▊                                | 2/7 [00:00<00:00, 10.52it/s]
#  57%|█████████████████████████▋                   | 4/7 [00:00<00:00, 10.50it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 11.50it/s]
# 4it [00:03,  1.19it/s]
# [2025-03-05 12:26:37,381] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:299)
# [2025-03-05 12:26:37,385] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:342)
# [2025-03-05 12:26:37,385] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# |               Task               |Version|Metric|Value |   |Stderr|
# |----------------------------------|------:|------|-----:|---|-----:|
# |all                               |       |acc   |0.1961|±  |0.0395|
# |leaderboard:mmlu:college_physics:0|      0|acc   |0.1961|±  |0.0395|
#
# [2025-03-05 12:26:37,397] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:332)
# [2025-03-05 12:26:37,398] [    INFO]: Saving experiment tracker (evaluation_tracker.py:154)
# [2025-03-05 12:26:37,398] [    INFO]: Deep copying the `Accelerator` object, note that this will point to the same original object. (accelerator.py:3645)
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/main_accelerate.py:207 in accelerate                                     │
# │                                                                              │
# │   204 │                                                                      │
# │   205 │   results = pipeline.get_results()                                   │
# │   206 │                                                                      │
# │ ❱ 207 │   pipeline.save_and_push_results()                                   │
# │   208 │                                                                      │
# │   209 │   return results                                                     │
# │   210                                                                        │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │               accelerator = <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x749af73294b0>                           │ │
# │ │                 cache_dir = None                                         │ │
# │ │              custom_tasks = None                                         │ │
# │ │ dataset_loading_processes = 1                                            │ │
# │ │                env_config = EnvConfig(cache_dir=None, token=None)        │ │
# │ │        evaluation_tracker = <lighteval.logging.evaluation_tracker.Evalu… │ │
# │ │                             object at 0x749af4b5ffd0>                    │ │
# │ │                    job_id = 0                                            │ │
# │ │               max_samples = None                                         │ │
# │ │                model_args = 'pretrained=akhilfau/Instruction_fine_tuned… │ │
# │ │           model_args_dict = {                                            │ │
# │ │                             │   'pretrained':                            │ │
# │ │                             'akhilfau/Instruction_fine_tuned_on_camel_a… │ │
# │ │                             │   'accelerator':                           │ │
# │ │                             <accelerate.accelerator.Accelerator object   │ │
# │ │                             at 0x749af73294b0>,                          │ │
# │ │                             │   'use_chat_template': False,              │ │
# │ │                             │   'compile': False                         │ │
# │ │                             }                                            │ │
# │ │              model_config = TransformersModelConfig(                     │ │
# │ │                             │                                            │ │
# │ │                             pretrained='akhilfau/Instruction_fine_tuned… │ │
# │ │                             │                                            │ │
# │ │                             accelerator=<accelerate.accelerator.Acceler… │ │
# │ │                             object at 0x749af73294b0>,                   │ │
# │ │                             │   tokenizer=None,                          │ │
# │ │                             │                                            │ │
# │ │                             multichoice_continuations_start_space=None,  │ │
# │ │                             │   pairwise_tokenization=False,             │ │
# │ │                             │   subfolder=None,                          │ │
# │ │                             │   revision='main',                         │ │
# │ │                             │   batch_size=-1,                           │ │
# │ │                             │   max_gen_toks=256,                        │ │
# │ │                             │   max_length=None,                         │ │
# │ │                             │   add_special_tokens=True,                 │ │
# │ │                             │   model_parallel=True,                     │ │
# │ │                             │   dtype=None,                              │ │
# │ │                             │   device='cuda',                           │ │
# │ │                             │   quantization_config=None,                │ │
# │ │                             │   trust_remote_code=False,                 │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   compile=False,                           │ │
# │ │                             │                                            │ │
# │ │                             generation_parameters=GenerationParameters(  │ │
# │ │                             │   │   early_stopping=None,                 │ │
# │ │                             │   │   repetition_penalty=None,             │ │
# │ │                             │   │   frequency_penalty=None,              │ │
# │ │                             │   │   length_penalty=None,                 │ │
# │ │                             │   │   presence_penalty=None,               │ │
# │ │                             │   │   max_new_tokens=None,                 │ │
# │ │                             │   │   min_new_tokens=None,                 │ │
# │ │                             │   │   seed=None,                           │ │
# │ │                             │   │   stop_tokens=None,                    │ │
# │ │                             │   │   temperature=None,                    │ │
# │ │                             │   │   top_k=None,                          │ │
# │ │                             │   │   min_p=None,                          │ │
# │ │                             │   │   top_p=None,                          │ │
# │ │                             │   │   truncate_prompt=None                 │ │
# │ │                             │   ),                                       │ │
# │ │                             │   generation_config=None                   │ │
# │ │                             )                                            │ │
# │ │         num_fewshot_seeds = 1                                            │ │
# │ │                output_dir = '/content/360M_output'                       │ │
# │ │       override_batch_size = 16                                           │ │
# │ │                  pipeline = <lighteval.pipeline.Pipeline object at       │ │
# │ │                             0x749af4b5e6b0>                              │ │
# │ │           pipeline_params = PipelineParameters(                          │ │
# │ │                             │                                            │ │
# │ │                             launcher_type=<ParallelismManager.ACCELERAT… │ │
# │ │                             1>,                                          │ │
# │ │                             │   env_config=EnvConfig(                    │ │
# │ │                             │   │   cache_dir=None,                      │ │
# │ │                             │   │   token=None                           │ │
# │ │                             │   ),                                       │ │
# │ │                             │   job_id=0,                                │ │
# │ │                             │   dataset_loading_processes=1,             │ │
# │ │                             │   nanotron_checkpoint_path=None,           │ │
# │ │                             │   custom_tasks_directory=None,             │ │
# │ │                             │   override_batch_size=16,                  │ │
# │ │                             │   num_fewshot_seeds=1,                     │ │
# │ │                             │   max_samples=None,                        │ │
# │ │                             │   use_chat_template=False,                 │ │
# │ │                             │   system_prompt=None                       │ │
# │ │                             )                                            │ │
# │ │                public_run = False                                        │ │
# │ │               push_to_hub = False                                        │ │
# │ │       push_to_tensorboard = False                                        │ │
# │ │                   results = {                                            │ │
# │ │                             │   'config_general': {                      │ │
# │ │                             │   │   'lighteval_sha': '?',                │ │
# │ │                             │   │   'num_fewshot_seeds': 1,              │ │
# │ │                             │   │   'override_batch_size': 16,           │ │
# │ │                             │   │   'max_samples': None,                 │ │
# │ │                             │   │   'job_id': 0,                         │ │
# │ │                             │   │   'start_time': 82732.04107175,        │ │
# │ │                             │   │   'end_time': 82737.537201518,         │ │
# │ │                             │   │   'total_evaluation_time_secondes':    │ │
# │ │                             '5.4961297679983545',                        │ │
# │ │                             │   │   'model_name':                        │ │
# │ │                             'akhilfau/Instruction_fine_tuned_on_camel_a… │ │
# │ │                             │   │   'model_sha':                         │ │
# │ │                             '28a1c11b822b6210e111db9e153c1bae2491e76e',  │ │
# │ │                             │   │   ... +3                               │ │
# │ │                             │   },                                       │ │
# │ │                             │   'results': {                             │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:college_physics:0':        │ │
# │ │                             defaultdict(<class 'float'>, {               │ │
# │ │                             │   │   │   'acc': 0.19607843137254902,      │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.039505818611799616                         │ │
# │ │                             │   │   }),                                  │ │
# │ │                             │   │   'all': {                             │ │
# │ │                             │   │   │   'acc': 0.19607843137254902,      │ │
# │ │                             │   │   │   'acc_stderr':                    │ │
# │ │                             0.039505818611799616                         │ │
# │ │                             │   │   }                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'versions': {                            │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:college_physics:0': 0      │ │
# │ │                             │   },                                       │ │
# │ │                             │   'config_tasks': {                        │ │
# │ │                             │   │   'leaderboard:mmlu:college_physics':  │ │
# │ │                             LightevalTaskConfig(                         │ │
# │ │                             │   │   │   name='mmlu:college_physics',     │ │
# │ │                             │   │   │   prompt_function=<function        │ │
# │ │                             mmlu_harness at 0x749af55ac550>,             │ │
# │ │                             │   │   │   hf_repo='lighteval/mmlu',        │ │
# │ │                             │   │   │   hf_subset='college_physics',     │ │
# │ │                             │   │   │   metric=(                         │ │
# │ │                             │   │   │   │   SampleLevelMetric(           │ │
# │ │                             │   │   │   │   │   metric_name='acc',       │ │
# │ │                             │   │   │   │   │   higher_is_better=True,   │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             category=<MetricCategory.MULTICHOICE: '8'>,  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             use_case=<MetricUseCase.ACCURACY: '1'>,      │ │
# │ │                             │   │   │   │   │   sample_level_fn=<bound   │ │
# │ │                             method LoglikelihoodAcc.compute of           │ │
# │ │                             <lighteval.metrics.metrics_sample.Loglikeli… │ │
# │ │                             object at 0x749af733c7c0>>,                  │ │
# │ │                             │   │   │   │   │                            │ │
# │ │                             corpus_level_fn=<function mean at            │ │
# │ │                             0x749cf0800030>                              │ │
# │ │                             │   │   │   │   ),                           │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   hf_revision=None,                │ │
# │ │                             │   │   │   hf_filter=None,                  │ │
# │ │                             │   │   │   hf_avail_splits=(                │ │
# │ │                             │   │   │   │   'auxiliary_train',           │ │
# │ │                             │   │   │   │   'test',                      │ │
# │ │                             │   │   │   │   'validation',                │ │
# │ │                             │   │   │   │   'dev'                        │ │
# │ │                             │   │   │   ),                               │ │
# │ │                             │   │   │   trust_dataset=True,              │ │
# │ │                             │   │   │   evaluation_splits=('test',),     │ │
# │ │                             │   │   │   few_shots_split='dev',           │ │
# │ │                             │   │   │   few_shots_select='sequential',   │ │
# │ │                             │   │   │   generation_size=1,               │ │
# │ │                             │   │   │   generation_grammar=None,         │ │
# │ │                             │   │   │   stop_sequence=('\n',),           │ │
# │ │                             │   │   │   num_samples=None,                │ │
# │ │                             │   │   │   suite=('leaderboard', 'mmlu'),   │ │
# │ │                             │   │   │   original_num_docs=102,           │ │
# │ │                             │   │   │   effective_num_docs=102,          │ │
# │ │                             │   │   │                                    │ │
# │ │                             must_remove_duplicate_docs=False,            │ │
# │ │                             │   │   │   version=0                        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_tasks': {                       │ │
# │ │                             │   │                                        │ │
# │ │                             'leaderboard:mmlu:college_physics:0':        │ │
# │ │                             CompiledDetail(                              │ │
# │ │                             │   │   │   hashes={                         │ │
# │ │                             │   │   │   │   'hash_examples':             │ │
# │ │                             'ebdab1cdb7e555df',                          │ │
# │ │                             │   │   │   │   'hash_full_prompts':         │ │
# │ │                             'ebdab1cdb7e555df',                          │ │
# │ │                             │   │   │   │   'hash_input_tokens':         │ │
# │ │                             '3d7a1d081f7ca597',                          │ │
# │ │                             │   │   │   │   'hash_cont_tokens':          │ │
# │ │                             '928b22b6932f99ca'                           │ │
# │ │                             │   │   │   },                               │ │
# │ │                             │   │   │   truncated=0,                     │ │
# │ │                             │   │   │   non_truncated=102,               │ │
# │ │                             │   │   │   padded=392,                      │ │
# │ │                             │   │   │   non_padded=16,                   │ │
# │ │                             │   │   │   effective_few_shots=0.0,         │ │
# │ │                             │   │   │   num_truncated_few_shots=0        │ │
# │ │                             │   │   )                                    │ │
# │ │                             │   },                                       │ │
# │ │                             │   'summary_general': {                     │ │
# │ │                             │   │   'hashes': {                          │ │
# │ │                             │   │   │   'hash_examples':                 │ │
# │ │                             '51e0fc9d449f6a6d',                          │ │
# │ │                             │   │   │   'hash_full_prompts':             │ │
# │ │                             '51e0fc9d449f6a6d',                          │ │
# │ │                             │   │   │   'hash_input_tokens':             │ │
# │ │                             '29eea8aa1e15e18e',                          │ │
# │ │                             │   │   │   'hash_cont_tokens':              │ │
# │ │                             '0f55f6e6c4edd430'                           │ │
# │ │                             │   │   },                                   │ │
# │ │                             │   │   'truncated': 0,                      │ │
# │ │                             │   │   'non_truncated': 102,                │ │
# │ │                             │   │   'padded': 392,                       │ │
# │ │                             │   │   'non_padded': 16,                    │ │
# │ │                             │   │   'num_truncated_few_shots': 0         │ │
# │ │                             │   }                                        │ │
# │ │                             }                                            │ │
# │ │               results_org = None                                         │ │
# │ │              save_details = False                                        │ │
# │ │             system_prompt = None                                         │ │
# │ │                     tasks = 'leaderboard|mmlu:college_physics|0|0'       │ │
# │ │                     torch = <module 'torch' from                         │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ │         use_chat_template = False                                        │ │
# │ │                      yaml = <module 'yaml' from                          │ │
# │ │                             '/home/avallala2023/anaconda3/envs/Thesis/l… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/pipeline.py:334 in save_and_push_results                                 │
# │                                                                              │
# │   331 │   def save_and_push_results(self):                                   │
# │   332 │   │   logger.info("--- SAVING AND PUSHING RESULTS ---")              │
# │   333 │   │   if self.is_main_process():                                     │
# │ ❱ 334 │   │   │   self.evaluation_tracker.save()                             │
# │   335 │                                                                      │
# │   336 │   def _init_final_dict(self):                                        │
# │   337 │   │   if self.is_main_process():                                     │
# │                                                                              │
# │ ╭─────────────────────────── locals ────────────────────────────╮            │
# │ │ self = <lighteval.pipeline.Pipeline object at 0x749af4b5e6b0> │            │
# │ ╰───────────────────────────────────────────────────────────────╯            │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/lighte │
# │ val/logging/evaluation_tracker.py:187 in save                                │
# │                                                                              │
# │   184 │   │   │   details_datasets[task_name] = dataset                      │
# │   185 │   │                                                                  │
# │   186 │   │   # We save results at every case                                │
# │ ❱ 187 │   │   self.save_results(date_id, results_dict)                       │
# │   188 │   │                                                                  │
# │   189 │   │   if self.should_save_details:                                   │
# │   190 │   │   │   self.save_details(date_id, details_datasets)               │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │     column_names = [                                                     │ │
# │ │                    │   'example',                                        │ │
# │ │                    │   'instruction',                                    │ │
# │ │                    │   'full_prompt',                                    │ │
# │ │                    │   'num_effective_few_shots',                        │ │
# │ │                    │   'num_asked_few_shots',                            │ │
# │ │                    │   'predictions',                                    │ │
# │ │                    │   'input_tokens',                                   │ │
# │ │                    │   'cont_tokens',                                    │ │
# │ │                    │   'truncated',                                      │ │
# │ │                    │   'padded',                                         │ │
# │ │                    │   ... +6                                            │ │
# │ │                    ]                                                     │ │
# │ │   config_general = {                                                     │ │
# │ │                    │   'lighteval_sha': '?',                             │ │
# │ │                    │   'num_fewshot_seeds': 1,                           │ │
# │ │                    │   'override_batch_size': 16,                        │ │
# │ │                    │   'max_samples': None,                              │ │
# │ │                    │   'job_id': 0,                                      │ │
# │ │                    │   'start_time': 82732.04107175,                     │ │
# │ │                    │   'end_time': 82737.537201518,                      │ │
# │ │                    │   'total_evaluation_time_secondes':                 │ │
# │ │                    '5.4961297679983545',                                 │ │
# │ │                    │   'model_name':                                     │ │
# │ │                    'akhilfau/Instruction_fine_tuned_on_camel_ai_physics… │ │
# │ │                    │   'model_sha':                                      │ │
# │ │                    '28a1c11b822b6210e111db9e153c1bae2491e76e',           │ │
# │ │                    │   ... +2                                            │ │
# │ │                    }                                                     │ │
# │ │          dataset = Dataset({                                             │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 102                                     │ │
# │ │                    })                                                    │ │
# │ │          date_id = '2025-03-05T12-26-37.398114'                          │ │
# │ │ details_datasets = {                                                     │ │
# │ │                    │   'leaderboard|mmlu:college_physics|0': Dataset({   │ │
# │ │                    │   features: ['choices', 'cont_tokens', 'example',   │ │
# │ │                    'full_prompt', 'gold', 'gold_index', 'input_tokens',  │ │
# │ │                    'instruction', 'metrics', 'num_asked_few_shots',      │ │
# │ │                    'num_effective_few_shots', 'padded', 'pred_logits',   │ │
# │ │                    'predictions', 'specifics', 'truncated'],             │ │
# │ │                    │   num_rows: 102                                     │ │
# │ │                    })                                                    │ │
# │ │                    }                                                     │ │
# │ │     results_dict = {                                                     │ │
# │ │                    │   'config_general': {                               │ │
# │ │                    │   │   'lighteval_sha': '?',                         │ │
# │ │                    │   │   'num_fewshot_seeds': 1,                       │ │
# │ │                    │   │   'override_batch_size': 16,                    │ │
# │ │                    │   │   'max_samples': None,                          │ │
# │ │                    │   │   'job_id': 0,                                  │ │
# │ │                    │   │   'start_time': 82732.04107175,                 │ │
# │ │                    │   │   'end_time': 82737.537201518,                  │ │
# │ │                    │   │   'total_evaluation_time_secondes':             │ │
# │ │                    '5.4961297679983545',                                 │ │
# │ │                    │   │   'model_name':                                 │ │
# │ │                    'akhilfau/Instruction_fine_tuned_on_camel_ai_physics… │ │
# │ │                    │   │   'model_sha':                                  │ │
# │ │                    '28a1c11b822b6210e111db9e153c1bae2491e76e',           │ │
# │ │                    │   │   ... +2                                        │ │
# │ │                    │   },                                                │ │
# │ │                    │   'results': defaultdict(<function                  │ │
# │ │                    MetricsLogger.<lambda>.<locals>.<lambda> at           │ │
# │ │                    0x749af4b61cf0>, {                                    │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics|0':         │ │
# │ │                    defaultdict(<class 'float'>, {                        │ │
# │ │                    │   │   │   'acc': 0.19607843137254902,               │ │
# │ │                    │   │   │   'acc_stderr': 0.039505818611799616        │ │
# │ │                    │   │   }),                                           │ │
# │ │                    │   │   'all': {                                      │ │
# │ │                    │   │   │   'acc': 0.19607843137254902,               │ │
# │ │                    │   │   │   'acc_stderr': 0.039505818611799616        │ │
# │ │                    │   │   }                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'versions': {                                     │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics|0': 0       │ │
# │ │                    │   },                                                │ │
# │ │                    │   'config_tasks': {                                 │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics':           │ │
# │ │                    LightevalTaskConfig(                                  │ │
# │ │                    │   │   │   name='mmlu:college_physics',              │ │
# │ │                    │   │   │   prompt_function=<function mmlu_harness at │ │
# │ │                    0x749af55ac550>,                                      │ │
# │ │                    │   │   │   hf_repo='lighteval/mmlu',                 │ │
# │ │                    │   │   │   hf_subset='college_physics',              │ │
# │ │                    │   │   │   metric=(                                  │ │
# │ │                    │   │   │   │   SampleLevelMetric(                    │ │
# │ │                    │   │   │   │   │   metric_name='acc',                │ │
# │ │                    │   │   │   │   │   higher_is_better=True,            │ │
# │ │                    │   │   │   │   │                                     │ │
# │ │                    category=<MetricCategory.MULTICHOICE: '8'>,           │ │
# │ │                    │   │   │   │   │   use_case=<MetricUseCase.ACCURACY: │ │
# │ │                    '1'>,                                                 │ │
# │ │                    │   │   │   │   │   sample_level_fn=<bound method     │ │
# │ │                    LoglikelihoodAcc.compute of                           │ │
# │ │                    <lighteval.metrics.metrics_sample.LoglikelihoodAcc    │ │
# │ │                    object at 0x749af733c7c0>>,                           │ │
# │ │                    │   │   │   │   │   corpus_level_fn=<function mean at │ │
# │ │                    0x749cf0800030>                                       │ │
# │ │                    │   │   │   │   ),                                    │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   hf_revision=None,                         │ │
# │ │                    │   │   │   hf_filter=None,                           │ │
# │ │                    │   │   │   hf_avail_splits=(                         │ │
# │ │                    │   │   │   │   'auxiliary_train',                    │ │
# │ │                    │   │   │   │   'test',                               │ │
# │ │                    │   │   │   │   'validation',                         │ │
# │ │                    │   │   │   │   'dev'                                 │ │
# │ │                    │   │   │   ),                                        │ │
# │ │                    │   │   │   trust_dataset=True,                       │ │
# │ │                    │   │   │   evaluation_splits=('test',),              │ │
# │ │                    │   │   │   few_shots_split='dev',                    │ │
# │ │                    │   │   │   few_shots_select='sequential',            │ │
# │ │                    │   │   │   generation_size=1,                        │ │
# │ │                    │   │   │   generation_grammar=None,                  │ │
# │ │                    │   │   │   stop_sequence=('\n',),                    │ │
# │ │                    │   │   │   num_samples=None,                         │ │
# │ │                    │   │   │   suite=('leaderboard', 'mmlu'),            │ │
# │ │                    │   │   │   original_num_docs=102,                    │ │
# │ │                    │   │   │   effective_num_docs=102,                   │ │
# │ │                    │   │   │   must_remove_duplicate_docs=False,         │ │
# │ │                    │   │   │   version=0                                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   },                                                │ │
# │ │                    │   'summary_tasks': defaultdict(<class               │ │
# │ │                    'lighteval.logging.info_loggers.DetailsLogger.Compil… │ │
# │ │                    {                                                     │ │
# │ │                    │   │   'leaderboard|mmlu:college_physics|0':         │ │
# │ │                    CompiledDetail(                                       │ │
# │ │                    │   │   │   hashes={                                  │ │
# │ │                    │   │   │   │   'hash_examples': 'ebdab1cdb7e555df',  │ │
# │ │                    │   │   │   │   'hash_full_prompts':                  │ │
# │ │                    'ebdab1cdb7e555df',                                   │ │
# │ │                    │   │   │   │   'hash_input_tokens':                  │ │
# │ │                    '3d7a1d081f7ca597',                                   │ │
# │ │                    │   │   │   │   'hash_cont_tokens':                   │ │
# │ │                    '928b22b6932f99ca'                                    │ │
# │ │                    │   │   │   },                                        │ │
# │ │                    │   │   │   truncated=0,                              │ │
# │ │                    │   │   │   non_truncated=102,                        │ │
# │ │                    │   │   │   padded=392,                               │ │
# │ │                    │   │   │   non_padded=16,                            │ │
# │ │                    │   │   │   effective_few_shots=0.0,                  │ │
# │ │                    │   │   │   num_truncated_few_shots=0                 │ │
# │ │                    │   │   )                                             │ │
# │ │                    │   }),                                               │ │
# │ │                    │   'summary_general': {                              │ │
# │ │                    │   │   'hashes': {                                   │ │
# │ │                    │   │   │   'hash_examples': '51e0fc9d449f6a6d',      │ │
# │ │                    │   │   │   'hash_full_prompts': '51e0fc9d449f6a6d',  │ │
# │ │                    │   │   │   'hash_input_tokens': '29eea8aa1e15e18e',  │ │
# │ │                    │   │   │   'hash_cont_tokens': '0f55f6e6c4edd430'    │ │
# │ │                    │   │   },                                            │ │
# │ │                    │   │   'truncated': 0,                               │ │
# │ │                    │   │   'non_truncated': 102,                         │ │
# │ │                    │   │   'padded': 392,                                │ │
# │ │                    │   │   'non_padded': 16,                             │ │
# │ │                    │   │   'num_truncated_few_shots': 0                  │ │
# │ │                    │   }                                                 │ │
# │ │                    }                                                     │ │
# │ │             self = <lighteval.logging.evaluation_tracker.EvaluationTrac… │ │
# │ │                    object at 0x749af4b5ffd0>                             │ │
# │ │     task_details = [                                                     │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about college physics'+346,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+3,                                           │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+346,                                         │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-0.06990921497344971, True),             │ │
# │ │                    │   │   │   (-2.9381303787231445, False),             │ │
# │ │                    │   │   │   (-4.578007698059082, False),              │ │
# │ │                    │   │   │   (-5.454358100891113, False)               │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ],                                        │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# │ │                    │   │   │   │   359,                                  │ │
# │ │                    │   │   │   │   2701,                                 │ │
# │ │                    │   │   │   │   4187,                                 │ │
# │ │                    │   │   │   │   2029,                                 │ │
# │ │                    │   │   │   │   365,                                  │ │
# │ │                    │   │   │   │   3659,                                 │ │
# │ │                    │   │   │   │   5360,                                 │ │
# │ │                    │   │   │   │   25,                                   │ │
# │ │                    │   │   │   │   ... +144                              │ │
# │ │                    │   │   │   ]                                         │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   cont_tokens=[[330], [389], [340], [422]],     │ │
# │ │                    │   │   truncated=[0, 0, 0, 0],                       │ │
# │ │                    │   │   padded=[18, 18, 18, 18],                      │ │
# │ │                    │   │   gold=[],                                      │ │
# │ │                    │   │   pred_logits=[],                               │ │
# │ │                    │   │   choices=[' A', ' B', ' C', ' D'],             │ │
# │ │                    │   │   gold_index=[1],                               │ │
# │ │                    │   │   metrics={'acc': 0},                           │ │
# │ │                    │   │   specifics=None                                │ │
# │ │                    │   ),                                                │ │
# │ │                    │   Detail(                                           │ │
# │ │                    │   │   example='The following are multiple choice    │ │
# │ │                    questions (with answers) about college physics'+216,  │ │
# │ │                    │   │   instruction='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+3,                                           │ │
# │ │                    │   │   full_prompt='The following are multiple       │ │
# │ │                    choice questions (with answers) about college         │ │
# │ │                    physics'+216,                                         │ │
# │ │                    │   │   num_effective_few_shots=0,                    │ │
# │ │                    │   │   num_asked_few_shots=0,                        │ │
# │ │                    │   │   predictions=[                                 │ │
# │ │                    │   │   │   (-0.18109329044818878, True),             │ │
# │ │                    │   │   │   (-2.1998119354248047, False),             │ │
# │ │                    │   │   │   (-3.4728660583496094, False),             │ │
# │ │                    │   │   │   (-3.855344772338867, False)               │ │
# │ │                    │   │   ],                                            │ │
# │ │                    │   │   input_tokens=[                                │ │
# │ │                    │   │   │   [                                         │ │
# │ │                    │   │   │   │   504,                                  │ │
# │ │                    │   │   │   │   1695,                                 │ │
# ...
# │ │                      │   │   │   hf_filter=None,                         │ │
# │ │                      │   │   │   hf_avail_splits=(                       │ │
# │ │                      │   │   │   │   'auxiliary_train',                  │ │
# │ │                      │   │   │   │   'test',                             │ │
# │ │                      │   │   │   │   'validation',                       │ │
# │ │                      │   │   │   │   'dev'                               │ │
# │ │                      │   │   │   ),                                      │ │
# │ │                      │   │   │   trust_dataset=True,                     │ │
# │ │                      │   │   │   evaluation_splits=('test',),            │ │
# │ │                      │   │   │   few_shots_split='dev',                  │ │
# │ │                      │   │   │   few_shots_select='sequential',          │ │
# │ │                      │   │   │   generation_size=1,                      │ │
# │ │                      │   │   │   generation_grammar=None,                │ │
# │ │                      │   │   │   stop_sequence=('\n',),                  │ │
# │ │                      │   │   │   num_samples=None,                       │ │
# │ │                      │   │   │   suite=('leaderboard', 'mmlu'),          │ │
# │ │                      │   │   │   original_num_docs=102,                  │ │
# │ │                      │   │   │   effective_num_docs=102,                 │ │
# │ │                      │   │   │   must_remove_duplicate_docs=False,       │ │
# │ │                      │   │   │   version=0                               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   },                                              │ │
# │ │                      │   'summary_tasks': defaultdict(<class             │ │
# │ │                      'lighteval.logging.info_loggers.DetailsLogger.Comp… │ │
# │ │                      {                                                   │ │
# │ │                      │   │   'leaderboard|mmlu:college_physics|0':       │ │
# │ │                      CompiledDetail(                                     │ │
# │ │                      │   │   │   hashes={                                │ │
# │ │                      │   │   │   │   'hash_examples':                    │ │
# │ │                      'ebdab1cdb7e555df',                                 │ │
# │ │                      │   │   │   │   'hash_full_prompts':                │ │
# │ │                      'ebdab1cdb7e555df',                                 │ │
# │ │                      │   │   │   │   'hash_input_tokens':                │ │
# │ │                      '3d7a1d081f7ca597',                                 │ │
# │ │                      │   │   │   │   'hash_cont_tokens':                 │ │
# │ │                      '928b22b6932f99ca'                                  │ │
# │ │                      │   │   │   },                                      │ │
# │ │                      │   │   │   truncated=0,                            │ │
# │ │                      │   │   │   non_truncated=102,                      │ │
# │ │                      │   │   │   padded=392,                             │ │
# │ │                      │   │   │   non_padded=16,                          │ │
# │ │                      │   │   │   effective_few_shots=0.0,                │ │
# │ │                      │   │   │   num_truncated_few_shots=0               │ │
# │ │                      │   │   )                                           │ │
# │ │                      │   }),                                             │ │
# │ │                      │   'summary_general': {                            │ │
# │ │                      │   │   'hashes': {                                 │ │
# │ │                      │   │   │   'hash_examples': '51e0fc9d449f6a6d',    │ │
# │ │                      │   │   │   'hash_full_prompts':                    │ │
# │ │                      '51e0fc9d449f6a6d',                                 │ │
# │ │                      │   │   │   'hash_input_tokens':                    │ │
# │ │                      '29eea8aa1e15e18e',                                 │ │
# │ │                      │   │   │   'hash_cont_tokens': '0f55f6e6c4edd430'  │ │
# │ │                      │   │   },                                          │ │
# │ │                      │   │   'truncated': 0,                             │ │
# │ │                      │   │   'non_truncated': 102,                       │ │
# │ │                      │   │   'padded': 392,                              │ │
# │ │                      │   │   'non_padded': 16,                           │ │
# │ │                      │   │   'num_truncated_few_shots': 0                │ │
# │ │                      │   }                                               │ │
# │ │                      }                                                   │ │
# │ │               self = <lighteval.logging.evaluation_tracker.EvaluationTr… │ │
# │ │                      object at 0x749af4b5ffd0>                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /spec.py:1589 in mkdirs                                                      │
# │                                                                              │
# │   1586 │                                                                     │
# │   1587 │   def mkdirs(self, path, exist_ok=False):                           │
# │   1588 │   │   """Alias of `AbstractFileSystem.makedirs`."""                 │
# │ ❱ 1589 │   │   return self.makedirs(path, exist_ok=exist_ok)                 │
# │   1590 │                                                                     │
# │   1591 │   def listdir(self, path, detail=True, **kwargs):                   │
# │   1592 │   │   """Alias of `AbstractFileSystem.ls`."""                       │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = PosixPath('/content/360M_output/results/akhilfau/Instruction… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x749af4b5e740>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/fsspec │
# │ /implementations/local.py:52 in makedirs                                     │
# │                                                                              │
# │    49 │                                                                      │
# │    50 │   def makedirs(self, path, exist_ok=False):                          │
# │    51 │   │   path = self._strip_protocol(path)                              │
# │ ❱  52 │   │   os.makedirs(path, exist_ok=exist_ok)                           │
# │    53 │                                                                      │
# │    54 │   def rmdir(self, path):                                             │
# │    55 │   │   path = self._strip_protocol(path)                              │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     path = '/content/360M_output/results/akhilfau/Instruction_fine_tune… │ │
# │ │     self = <fsspec.implementations.local.LocalFileSystem object at       │ │
# │ │            0x749af4b5e740>                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────────────────────── locals ─────────────────────────────────╮ │
# │ │ exist_ok = True                                                          │ │
# │ │     head = '/content/360M_output/results/akhilfau'                       │ │
# │ │     mode = 511                                                           │ │
# │ │     name = '/content/360M_output/results/akhilfau/Instruction_fine_tune… │ │
# │ │     tail = 'Instruction_fine_tuned_on_camel_ai_physics'                  │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭────────────────────── locals ──────────────────────╮                       │
# │ │ exist_ok = True                                    │                       │
# │ │     head = '/content/360M_output/results'          │                       │
# │ │     mode = 511                                     │                       │
# │ │     name = '/content/360M_output/results/akhilfau' │                       │
# │ │     tail = 'akhilfau'                              │                       │
# │ ╰────────────────────────────────────────────────────╯                       │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────────── locals ──────────────────╮                                │
# │ │ exist_ok = True                           │                                │
# │ │     head = '/content/360M_output'         │                                │
# │ │     mode = 511                            │                                │
# │ │     name = '/content/360M_output/results' │                                │
# │ │     tail = 'results'                      │                                │
# │ ╰───────────────────────────────────────────╯                                │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:215 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    212 │   │   head, tail = path.split(head)                                 │
# │    213 │   if head and tail and not path.exists(head):                       │
# │    214 │   │   try:                                                          │
# │ ❱  215 │   │   │   makedirs(head, exist_ok=exist_ok)                         │
# │    216 │   │   except FileExistsError:                                       │
# │    217 │   │   │   # Defeats race condition when another thread created the  │
# │    218 │   │   │   pass                                                      │
# │                                                                              │
# │ ╭───────────── locals ──────────────╮                                        │
# │ │ exist_ok = True                   │                                        │
# │ │     head = '/content'             │                                        │
# │ │     mode = 511                    │                                        │
# │ │     name = '/content/360M_output' │                                        │
# │ │     tail = '360M_output'          │                                        │
# │ ╰───────────────────────────────────╯                                        │
# │                                                                              │
# │ /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/os.py:225 in         │
# │ makedirs                                                                     │
# │                                                                              │
# │    222 │   │   if tail == cdir:           # xxx/newdir/. exists if xxx/newdi │
# │    223 │   │   │   return                                                    │
# │    224 │   try:                                                              │
# │ ❱  225 │   │   mkdir(name, mode)                                             │
# │    226 │   except OSError:                                                   │
# │    227 │   │   # Cannot rely on checking for EEXIST, since the operating sys │
# │    228 │   │   # could give priority to other errors like EACCES or EROFS    │
# │                                                                              │
# │ ╭─────── locals ────────╮                                                    │
# │ │ exist_ok = True       │                                                    │
# │ │     head = '/'        │                                                    │
# │ │     mode = 511        │                                                    │
# │ │     name = '/content' │                                                    │
# │ │     tail = 'content'  │                                                    │
# │ ╰───────────────────────╯                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PermissionError: [Errno 13] Permission denied: '/content'
