# %%
# Install required libraries
# !pip install transformers datasets trl torch accelerate bitsandbytes wandb
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /home/avallala2023/anaconda3/lib/python3.12/site-packages (4.49.0)
# Requirement already satisfied: datasets in /home/avallala2023/anaconda3/lib/python3.12/site-packages (3.3.2)
# Requirement already satisfied: trl in /home/avallala2023/anaconda3/lib/python3.12/site-packages (0.15.2)
# Requirement already satisfied: torch in /home/avallala2023/anaconda3/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: accelerate in /home/avallala2023/anaconda3/lib/python3.12/site-packages (1.4.0)
# Requirement already satisfied: bitsandbytes in /home/avallala2023/anaconda3/lib/python3.12/site-packages (0.45.3)
# Requirement already satisfied: wandb in /home/avallala2023/anaconda3/lib/python3.12/site-packages (0.19.8)
# Requirement already satisfied: filelock in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from datasets) (3.10.5)
# Requirement already satisfied: rich in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from trl) (13.7.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: psutil in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from wandb) (3.10.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from wandb) (4.25.3)
# Requirement already satisfied: pydantic<3,>=2.6 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from wandb) (2.8.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from wandb) (2.22.0)
# Requirement already satisfied: setproctitle in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from wandb) (1.3.5)
# Requirement already satisfied: six>=1.4.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from rich->trl) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from rich->trl) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/avallala2023/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.0)

# %%
# Import necessary modules
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, pipeline
from datasets import load_dataset
from trl import SFTConfig, SFTTrainer, setup_chat_format
import torch
import os

# Detect device (GPU, MPS, or CPU)
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)

# %% [markdown]
# ***Quick Check For Resources - Runtime***

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Thu Mar 13 18:01:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.107.02             Driver Version: 550.107.02     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A5500               On  |   00000000:01:00.0 Off |                  Off |
# | 49%   64C    P2             79W /  230W |   15260MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A5500               On  |   00000000:2E:00.0 Off |                  Off |
# | 57%   68C    P8             25W /  230W |    9152MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA RTX A5500               On  |   00000000:41:00.0 Off |                  Off |
# | 59%   69C    P8             35W /  230W |    9152MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA RTX A5500               On  |   00000000:61:00.0 Off |                  Off |
# | 56%   67C    P8             22W /  230W |   17327MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      9404      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A     58857      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A    372698      C   ...23/anaconda3/envs/Thesis/bin/python      14966MiB |
# |    0   N/A  N/A   3486353      C   /usr/NX/bin/nxnode.bin                        266MiB |
# |    1   N/A  N/A      9404      G   /usr/lib/xorg/Xorg                              4MiB |
# |    1   N/A  N/A     58857      G   /usr/lib/xorg/Xorg                              4MiB |
# |    1   N/A  N/A    372698      C   ...23/anaconda3/envs/Thesis/bin/python       9128MiB |
# |    2   N/A  N/A      9404      G   /usr/lib/xorg/Xorg                              4MiB |
# |    2   N/A  N/A     58857      G   /usr/lib/xorg/Xorg                              4MiB |
# |    2   N/A  N/A    372698      C   ...23/anaconda3/envs/Thesis/bin/python       9128MiB |
# |    3   N/A  N/A      9404      G   /usr/lib/xorg/Xorg                              4MiB |
# |    3   N/A  N/A     58857      G   /usr/lib/xorg/Xorg                              4MiB |
# |    3   N/A  N/A    372698      C   ...23/anaconda3/envs/Thesis/bin/python       9112MiB |
# |    3   N/A  N/A   4068433      C   python                                       8186MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# Load the model and tokenizer
model_name = "HuggingFaceTB/SmolLM2-360M-Instruct"
model = AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path=model_name)
tokenizer = AutoTokenizer.from_pretrained(pretrained_model_name_or_path=model_name)

# Set up chat format for the model and tokenizer
#model, tokenizer = setup_chat_format(model=model, tokenizer=tokenizer)

# Test the base model with a simple prompt
prompt = "Explain AGI ?"
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0 if device == "cuda" else -1)
print(pipe(prompt, max_new_tokens=200))
# Out:
# Device set to use cuda:0
# [{'generated_text': 'Explain AGI ?\n\nArtificial General Intelligence (AGI) is a hypothetical AI system that possesses the ability to perform any intellectual task that a human can, with the same level of accuracy and effectiveness. This includes reasoning, problem-solving, learning, and understanding. AGI would be able to learn from experience, adapt to new situations, and apply its knowledge to a wide range of tasks, similar to humans.\n\nThe concept of AGI was first proposed by mathematician and computer scientist John McCarthy in 1956, and it has since become a topic of interest in the fields of artificial intelligence, cognitive science, and philosophy. AGI would be a significant breakthrough in the development of AI, as it would enable machines to perform tasks that were previously the exclusive domain of humans.\n\nHowever, the development of AGI is still a topic of debate and research, and there are many challenges and uncertainties associated with creating a truly intelligent AI system. Some of the key challenges include:\n\n*'}]

# %%
# Load the dataset
ds = load_dataset("akhilfau/Instruction_fine_tuning_camel_ai_physics")

# Tokenization function with batch handling
def tokenize_function(examples):
    # Apply strip to each string in the batch
    prompts = [p.strip() for p in examples["prompt"]]
    responses = [r.strip() for r in examples["response"]]

    # Apply chat template for each prompt-response pair
    texts = [
        tokenizer.apply_chat_template(
            [{"role": "system", "content": "You are a helpful physics tutor."},{"role": "user", "content": p}, {"role": "assistant", "content": r}],
            tokenize=False
        )
        for p, r in zip(prompts, responses)
    ]

    # Tokenize the combined texts
    return tokenizer(texts, truncation=True, padding="max_length", max_length=512)

# Apply the tokenization function to the dataset
ds = ds.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]

# %%
import torch
from transformers import TrainingArguments
from trl import SFTTrainer

# Check if bf16 is available
use_bf16 = torch.cuda.is_bf16_supported()

# Estimate total training steps
dataset_size = len(ds["train"])  # Adjust based on dataset size
batch_size = 4  # Adjust based on available GPU memory
grad_accum_steps = 4  # Simulate larger batch without using more memory
total_steps = (dataset_size // (batch_size * grad_accum_steps)) * 3  # 3 epochs

# Training Arguments
training_args = TrainingArguments(
    per_device_train_batch_size=batch_size,
    gradient_accumulation_steps=grad_accum_steps,
    warmup_steps=100,  # More warmup steps for stability
    max_steps=total_steps,  # Train across full dataset
    learning_rate=2e-4,
    fp16=not use_bf16,  # Use FP16 if bf16 is not available
    bf16=use_bf16,  # Use BF16 if supported
    logging_steps=100,  # Reduce logging frequency for better efficiency
    save_steps=1000,  # Save every 1000 steps
    save_total_limit=2,  # Keep last 2 checkpoints
    optim="adamw_8bit",  # Memory-efficient optimizer
    weight_decay=0.01,
    lr_scheduler_type="linear",
    seed=3407,
    output_dir="outputs",
    report_to="wandb",  # Log to W&B
)

# Initialize Trainer
trainer = SFTTrainer(
    model=model,
    processing_class=tokenizer,
    train_dataset=ds["train"],
    args=training_args,
)

# Train
trainer.train()
# Out:
# Converting train dataset to ChatML:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Applying chat template to train dataset:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/20000 [00:00<?, ? examples/s]
# /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='3750' max='3750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3750/3750 2:35:46, Epoch 11/13]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.212200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.178600</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.167400</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.143100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.139800</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.138300</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.116600</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.110900</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.112200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.094200</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.085600</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.087800</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.074900</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.062000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.064700</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.057100</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.042900</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.044700</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.041900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.028900</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.030100</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.029900</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.020000</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.020400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.020800</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.014700</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.014600</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.014800</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.011700</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.011200</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.011300</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.009800</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.008600</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.008200</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.008200</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /home/avallala2023/anaconda3/envs/Thesis/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# TrainOutput(global_step=3750, training_loss=0.06028011699517568, metrics={'train_runtime': 9349.373, 'train_samples_per_second': 25.67, 'train_steps_per_second': 0.401, 'total_flos': 2.316340113702912e+17, 'train_loss': 0.06028011699517568})

# %%
# Save model and tokenizer to a local directory
# save_directory = "/content/Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics"
# model.save_pretrained(save_directory)
# tokenizer.save_pretrained(save_directory)

# # Zip the directory
# import shutil
# shutil.make_archive(save_directory, 'zip', save_directory)

# # Download the zip file
# from google.colab import files
# files.download(f"{save_directory}.zip")

# %%
# Change to a directory in your home folder
save_directory = "./Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics"

# Save model and tokenizer
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)

print(f"✅ Model saved to {save_directory}")
# Out:
# ✅ Model saved to ./Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics

# %%
from huggingface_hub import login

# Replace 'your_huggingface_token' with your actual token
hf_token = "hf_token"

# Log in to Hugging Face
login(token=hf_token)

print("✅ Successfully logged in to Hugging Face!")
# Out:
# ✅ Successfully logged in to Hugging Face!

# %%
from huggingface_hub import create_repo, upload_folder, login
# Create the repository (if it doesn't exist)
# Define model repository name
repo_name = "akhilfau/Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics"
create_repo(repo_id=repo_name, repo_type="model", exist_ok=True)
# Out:
# RepoUrl('https://huggingface.co/akhilfau/Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics', endpoint='https://huggingface.co', repo_type='model', repo_id='akhilfau/Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics')

# %%
from huggingface_hub import upload_folder
from transformers import AutoModel, AutoTokenizer

# Define model repository name
repo_name = "akhilfau/Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics"

# Save model and tokenizer locally
save_directory = "./Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics"
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)

# Upload to Hugging Face Hub
upload_folder(
    folder_path=save_directory,  # Path to local model directory
    repo_id=repo_name,           # Your Hugging Face repository name
    repo_type="model"            # Specify it as a model repository
)

print(f"✅ Model successfully uploaded: https://huggingface.co/{repo_name}")
# Out:
# model.safetensors:   0%|          | 0.00/1.45G [00:00<?, ?B/s]
# ✅ Model successfully uploaded: https://huggingface.co/akhilfau/Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics

# %%
MODEL="akhilfau/Instruction_fine_tuned_on_smollm2_360M_Instruct_camel_ai_physics"  # Model name
OUTPUT_DIR="/content/360M_supervised"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:conceptual_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /bin/bash: line 1: lighteval: command not found

# %%
MODEL="HuggingFaceTB/SmolLM2-360M"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:conceptual_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"

# %%
MODEL="akhilfau/Instruction_fine_tuned_on_camel_ai_physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:conceptual_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"

# %%
#High School Physics

# %%
MODEL="HuggingFaceTB/SmolLM2-360M"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:high_school_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"

# %%
MODEL="akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel-ai-physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:high_school_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"

# %%
MODEL="akhilfau/Instruction_fine_tuned_on_camel_ai_physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:high_school_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"

# %%
#College_physics

# %%
MODEL="HuggingFaceTB/SmolLM2-360M"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:college_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"

# %%
MODEL="akhilfau/fine-tuned-smolLM2-360M-with-LoRA-on-camel-ai-physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:college_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"

# %%
MODEL="akhilfau/Instruction_fine_tuned_on_camel_ai_physics"  # Model name
OUTPUT_DIR="/content/360M_output"  # Change this if needed

# !lighteval accelerate \
    "pretrained=$MODEL" \
    "leaderboard|mmlu:college_physics|0|0" \
    --override-batch-size 16 \
    --output-dir "$OUTPUT_DIR"
